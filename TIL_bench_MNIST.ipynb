# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset, random_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, cohen_kappa_score
from PIL import Image
import random
import torch
from torch import autograd
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset
import numpy as np

# Define the transform for MNIST
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])


# Set random seeds for reproducibility
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# Load and transform the datasets
transform = transforms.Compose([transforms.ToTensor()])

# Standard MNIST for Task A (Digit Classification)
train_A_dataset = datasets.MNIST(root='./data', train=True, transform=transform, download=True)
test_A_dataset = datasets.MNIST(root='./data', train=False, transform=transform, download=True)

# Function to create a balanced subset
def create_balanced_subset(dataset, num_samples_per_class):
    class_indices = {i: [] for i in range(10)}  # Store indices for each class (0-9)

    # Sort dataset into classes
    for idx, (_, target) in enumerate(dataset):
        class_indices[target].append(idx)

    # Randomly select num_samples_per_class indices per class
    subset_indices = []
    for class_label, indices in class_indices.items():
        subset_indices.extend(np.random.choice(indices, num_samples_per_class, replace=False))

    # Create the subset
    subset = Subset(dataset, subset_indices)
    return subset

# Create a subset with 100 samples per digit
train_A_dataset = create_balanced_subset(train_A_dataset, num_samples_per_class=1500)
test_A_dataset = create_balanced_subset(test_A_dataset, num_samples_per_class=150)



# Custom dataset for Task B (Even-Odd Classification)
class EvenOddMNIST(Dataset):
    def __init__(self, mnist_dataset):
        self.mnist_dataset = mnist_dataset

    def __getitem__(self, index):
        img, target = self.mnist_dataset[index]
        even_odd_target = target % 2  # 0 for even, 1 for odd
        return img, even_odd_target

    def __len__(self):
        return len(self.mnist_dataset)

train_B_dataset = EvenOddMNIST(train_A_dataset)
test_B_dataset = EvenOddMNIST(test_A_dataset)

class TaskIdentifierDataset(Dataset):
    def __init__(self, dataset, task_id):
        self.dataset = dataset
        self.task_id = task_id

    def __getitem__(self, index):
        img, target = self.dataset[index]
        task_identifier = torch.tensor([self.task_id], dtype=torch.float32)
        return img, target, task_identifier

    def __len__(self):
        return len(self.dataset)

# Wrapping the original datasets with task identifiers
train_A_dataset_with_id = TaskIdentifierDataset(train_A_dataset, 1.0)
test_A_dataset_with_id = TaskIdentifierDataset(test_A_dataset, 1.0)
train_B_dataset_with_id = TaskIdentifierDataset(train_B_dataset, 0.0)
test_B_dataset_with_id = TaskIdentifierDataset(test_B_dataset, 0.0)

# Split into training and validation sets for Task A and Task B
train_size_A = int(0.8 * len(train_A_dataset_with_id))  # 80% for training
val_size_A = len(train_A_dataset_with_id) - train_size_A  # 20% for validation

train_size_B = int(0.8 * len(train_B_dataset_with_id))  # 80% for training
val_size_B = len(train_B_dataset_with_id) - train_size_B  # 20% for validation

train_A_dataset_with_id, val_A_dataset_with_id = random_split(train_A_dataset_with_id, [train_size_A, val_size_A])
train_B_dataset_with_id, val_B_dataset_with_id = random_split(train_B_dataset_with_id, [train_size_B, val_size_B])

# Create DataLoaders
train_A_loader = DataLoader(train_A_dataset_with_id, batch_size=64, shuffle=True)
val_A_loader = DataLoader(val_A_dataset_with_id, batch_size=64, shuffle=False)
test_A_loader = DataLoader(test_A_dataset_with_id, batch_size=64, shuffle=False)

train_B_loader = DataLoader(train_B_dataset_with_id, batch_size=64, shuffle=True)
val_B_loader = DataLoader(val_B_dataset_with_id, batch_size=64, shuffle=False)
test_B_loader = DataLoader(test_B_dataset_with_id, batch_size=64, shuffle=False)

# %%
# Check the size of the subset
print(f"train_A_dataset size: {len(train_A_dataset)}")
print(f"train_B_dataset size: {len(train_B_dataset)}")
print(f"test_B_dataset size: {len(test_B_dataset)}")
print(f"test_A_dataset size: {len(test_A_dataset)}")
# Out:
# train_A_dataset size: 15000
# train_B_dataset size: 15000
# test_B_dataset size: 1500
# test_A_dataset size: 1500

# %%
class ConvNet(nn.Module):
    def __init__(self, shared_dim=128, output_dim_A=10, output_dim_B=2):
        super(ConvNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(64 * 28 * 28 + 1, shared_dim)  # Adjusted to match the output size after conv layers + task identifier
        self.fc2_A = nn.Linear(shared_dim, output_dim_A)
        self.fc2_B = nn.Linear(shared_dim, output_dim_B)

    def forward(self, x, task_id):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = x.view(x.size(0), -1)  # Flatten the tensor
        task_id = task_id.view(-1, 1)  # Ensure task_id has shape (batch_size, 1)
        x = torch.cat((x, task_id), dim=1)  # Concatenate task identifier
        x = F.relu(self.fc1(x))

        # Generate outputs for both tasks
        output_A = self.fc2_A(x)
        output_B = self.fc2_B(x)

        # Combine the outputs into a single tensor with proper shape
        output = torch.zeros(x.size(0), max(output_A.size(1), output_B.size(1)), device=x.device)
        output[:, :output_A.size(1)] = output_A * (task_id == 1).float()
        output[:, :output_B.size(1)] += output_B * (task_id == 0).float()

        return output

# %%
# Training function
def train(model, loader, optimizer, criterion, epochs=20):
    model.train()
    for epoch in range(epochs):
        epoch_loss = 0
        for data, target, task_id in loader:  # Ensure the DataLoader returns three items
            optimizer.zero_grad()
            output = model(data, task_id)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        print(f'Epoch {epoch+1}/{epochs}, Loss: {epoch_loss/len(loader)}')

# Evaluation function
def evaluate(model, loader, criterion):
    model.eval()
    total_loss = 0
    all_targets = []
    all_predictions = []
    with torch.no_grad():
        for data, target, task_id in loader:  # Ensure the DataLoader returns three items
            output = model(data, task_id)
            loss = criterion(output, target)
            total_loss += loss.item()
            predictions = torch.argmax(output, dim=1)
            all_targets.extend(target.numpy())
            all_predictions.extend(predictions.numpy())

    accuracy = accuracy_score(all_targets, all_predictions)
    precision = precision_score(all_targets, all_predictions, average='weighted', zero_division=0)
    recall = recall_score(all_targets, all_predictions, average='weighted', zero_division=0)
    kappa = cohen_kappa_score(all_targets, all_predictions)
    
    return accuracy, precision, recall, kappa

# %%
def train_with_patience(model, loader, optimizer, criterion, epochs=20, patience=5):
    model.train()
    best_loss = float('inf')
    no_improvement = 0
    epoch_accuracy = []
    epochs_loss = []

    for epoch in range(epochs):
        epoch_loss = 0
        correct = 0
        total = 0
        for data, target, task_id in loader:  # Ensure the DataLoader returns three items
            optimizer.zero_grad()
            output = model(data, task_id)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
            _, predicted = torch.max(output, 1)
            correct += (predicted == target).sum().item()
            total += target.size(0)

        avg_loss = epoch_loss / len(loader)
        accuracy = correct / total
        epoch_accuracy.append(accuracy)
        epochs_loss.append(avg_loss)
        print(f'Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}')

        # Check for improvement
        if avg_loss < best_loss:
            best_loss = avg_loss
            no_improvement = 0
        else:
            no_improvement += 1

        # Early stopping criteria
        if no_improvement >= patience:
            print(f"Stopping early due to no improvement in loss for {patience} consecutive epochs.")
            break

    return epoch_accuracy, epochs_loss

# %%
import torch
import torch.nn.functional as F

class EWC:
    def __init__(self, model, dataloader, importance=10000):
        self.model = model
        self.dataloader = dataloader
        self.importance = importance
        self.initial_params = {n: p.clone() for n, p in self.model.named_parameters()}
        self.fisher_diagonal = self.compute_fisher_information()

    def compute_fisher_information(self):
        fisher_diagonal = {n: torch.zeros_like(p) for n, p in self.model.named_parameters()}
        self.model.eval()

        for i, (data, target, task_id) in enumerate(self.dataloader, 1):
            self.model.zero_grad()
            output = self.model(data, task_id)
            loss = F.nll_loss(F.log_softmax(output, dim=1), target)
            loss.backward()

            for n, p in self.model.named_parameters():
                if p.grad is not None:
                    grad_squared = p.grad ** 2
                    # Online update for Fisher diagonal using incremental average
                    fisher_diagonal[n] = fisher_diagonal[n] + (grad_squared - fisher_diagonal[n]) / i
                else:
                    print(f"Warning: Gradient for parameter {n} is None.")

        return fisher_diagonal

    def penalty(self):
        penalty = 0
        for n, p in self.model.named_parameters():
            penalty += (self.fisher_diagonal[n] * (p - self.initial_params[n]) ** 2).sum()
        return self.importance * penalty

# %%
def train_with_ewc(model, loader, ewc, optimizer, criterion, epochs=20):
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        total_penalty = 0
        for data, target, task_id in loader:
            optimizer.zero_grad()
            output = model(data, task_id)
            loss = criterion(output, target)
            penalty = ewc.penalty()
            total_loss += loss.item()
            total_penalty += penalty.item()
            loss += penalty
            loss.backward()
            optimizer.step()
        print(f'Epoch {epoch + 1}/{epochs}, Loss: {total_loss / len(loader):.4f}, Penalty: {total_penalty / len(loader):.4f}')

# %%
def train_with_ewc_with_patience(model, loader, ewc, optimizer, criterion, epochs=20, patience=5):
    model.train()
    best_loss = float('inf')
    no_improvement = 0
    epoch_accuracy = []
    epochs_loss = []

    for epoch in range(epochs):
        total_loss = 0
        total_penalty = 0
        total = 0
        correct = 0
        for data, target, task_id in loader:
            optimizer.zero_grad()
            output = model(data, task_id)
            loss = criterion(output, target)
            penalty = ewc.penalty()
            total_loss += loss.item()
            total_penalty += penalty.item()
            loss += penalty
            loss.backward()
            optimizer.step()
            _, predicted = torch.max(output, 1)
            correct += (predicted == target).sum().item()
            total += target.size(0)

        avg_loss = total_loss / len(loader)
        avg_penalty = total_penalty / len(loader)
        accuracy = correct / total
        epoch_accuracy.append(accuracy)
        epochs_loss.append(avg_loss)
        
        print(f'Epoch {epoch + 1}/{epochs}, Loss: {avg_loss:.4f}, Penalty: {avg_penalty:.4f}')

        # Check for improvement
        if avg_loss < best_loss:
            best_loss = avg_loss
            no_improvement = 0
        else:
            no_improvement += 1

        # Early stopping criteria
        if no_improvement >= patience:
            print(f"Stopping early due to no improvement in loss for {patience} consecutive epochs.")
            break


    return epoch_accuracy, epochs_loss

# %%
class SynapticIntelligence:
    def __init__(self, model, dataloader, importance=1000, device='cpu'):
        self.model = model
        self.dataloader = dataloader
        self.importance = importance
        self.device = device
        self.saved_params = {}
        self.omega = {}

        for n, p in self.model.named_parameters():
            if p.requires_grad:
                self.saved_params[n] = p.clone().detach().to(self.device)
                self.omega[n] = torch.zeros_like(p).to(self.device)

    def update_omega(self, batch_loss, lr):
        for n, p in self.model.named_parameters():
            if p.requires_grad:
                if p.grad is not None:
                    self.omega[n] += p.grad * (p.detach() - self.saved_params[n])
                    self.saved_params[n] = p.clone().detach()

    def penalty(self):
        loss = 0
        for n, p in self.model.named_parameters():
            if p.requires_grad:
                _loss = self.omega[n] * (p - self.saved_params[n]) ** 2
                loss += _loss.sum()
        return self.importance * loss

    def end_task(self):
        for n, p in self.model.named_parameters():
            if p.requires_grad:
                self.omega[n] /= len(self.dataloader)

# %%
def train_with_si(model, loader, si, optimizer, criterion, epochs=20):
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        for data, target, task_id in loader:
            optimizer.zero_grad()
            output = model(data, task_id)
            loss = criterion(output, target)
            loss += si.penalty()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            si.update_omega(loss, optimizer.param_groups[0]['lr'])
        print(f'Epoch {epoch + 1}/{epochs}, Loss: {total_loss / len(loader):.4f}')
    si.end_task()

# %%
def train_with_si(model, loader, optimizer, criterion, si, epochs=10):
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        total_penalty = 0
        for data, target,task_id in loader:
            optimizer.zero_grad()
            output = model(data,task_id)
            loss = criterion(output, target)
            penalty = si.penalty()
            total_loss += loss.item()
            total_penalty += penalty.item()
            loss += penalty
            loss.backward()
            optimizer.step()
        print(f'Epoch {epoch + 1}/{epochs}, Loss: {total_loss / len(loader)}, Penalty: {total_penalty / len(loader)}')

# %%
def train_with_si(model, optimizer, dataloaders, si=None, lambda_si=0.1, epochs=5):
    """
    Train the model with or without SI penalty.

    Args:
        model: Neural network model to train.
        optimizer: Optimizer for training.
        dataloaders: Dictionary containing 'train' and optionally 'val' dataloaders.
        si: Instance of the SynapticIntelligence class, or None if not using SI.
        lambda_si: Importance of the SI penalty (default is 0.1).
        epochs: Number of epochs to train.
    """
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        total_penalty = 0.0

        for inputs, targets,task_id in dataloaders['train']:
            optimizer.zero_grad()
            outputs = model(inputs,task_id)
            loss = criterion(outputs, targets)

            # Add SI penalty if applicable
            if si is not None:
                si_penalty = si.penalty(model)
                loss += lambda_si * si_penalty
                total_penalty += si_penalty.item()

            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        # Log losses
        avg_loss = running_loss / len(dataloaders['train'])
        avg_penalty = total_penalty / len(dataloaders['train'])
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}, Penalty: {avg_penalty:.4f}")

# %%
class SynapticIntelligence:
    def __init__(self, model, dataloader):
        """
        Synaptic Intelligence (SI) implementation.
        Args:
            model: Neural network model.
            dataloader: DataLoader for the current task.
        """
        self.model = model
        self.dataloader = dataloader
        self.omega = {}
        self.optimal_params = {}

        # Initialize omega and optimal_params
        self._initialize_params()

    def _initialize_params(self):
        """
        Initialize or reset omega and optimal_params to match the current model's parameters.
        """
        self.omega = {n: torch.zeros_like(p) for n, p in self.model.named_parameters() if p.requires_grad}
        self.optimal_params = {n: p.clone().detach() for n, p in self.model.named_parameters() if p.requires_grad}

    def update_omega(self):
        self.model.eval()
        fisher_diagonal = {n: torch.zeros_like(p) for n, p in self.model.named_parameters() if p.requires_grad}
        
        dataset_size = len(self.dataloader.dataset)  # Dataset size for normalization
        for i, (data, target,task_id) in enumerate(self.dataloader, 1):
            self.model.zero_grad()
            output = self.model(data,task_id)
            loss = F.nll_loss(F.log_softmax(output, dim=1), target)
            loss.backward()
            
            for n, p in self.model.named_parameters():
                if p.grad is not None:
                    fisher_diagonal[n] += (p.grad ** 2 - fisher_diagonal[n]) / i
        
        for n in fisher_diagonal:
            if n in self.omega:
                self.omega[n] += fisher_diagonal[n] / max(1e-10, fisher_diagonal[n].norm().item())
            else:
                self.omega[n] = fisher_diagonal[n] / max(1e-10, fisher_diagonal[n].norm().item())




    def store_optimal_params(self):
        """
        Store the current model parameters as the optimal parameters after training a task.
        """
        self.optimal_params = {n: p.clone().detach() for n, p in self.model.named_parameters() if p.requires_grad}

    def penalty(self, model):
        penalty = 0.0
        for n, p in model.named_parameters():
            if n in self.omega and n in self.optimal_params:
                diff = p - self.optimal_params[n]
                #print(f"{n} - Diff Max: {diff.max().item()}, Min: {diff.min().item()}")
                term = (self.omega[n] * diff ** 2).sum()
                #print(f"{n} - Term: {term.item()}")
                penalty += term
        return penalty

# %%
class RehearsalBuffer:
    def __init__(self, buffer_size=200):
        self.buffer_size = buffer_size
        self.buffer = []

    def add_to_buffer(self, data, target, task_id):
        for i in range(len(data)):
            if len(self.buffer) >= self.buffer_size:
                self.buffer.pop(0)
            self.buffer.append((data[i], target[i], task_id[i]))

    def get_buffer(self):
        data, target, task_id = zip(*self.buffer)
        return torch.stack(data), torch.tensor(target), torch.tensor(task_id)

# %%
def train_with_rehearsal(model, loader, buffer, optimizer, criterion, epochs=20):
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        for data, target, task_id in loader:
            buffer.add_to_buffer(data, target, task_id)
            optimizer.zero_grad()
            output = model(data, task_id)
            loss = criterion(output, target)
            if len(buffer.buffer) > 0:
                buffer_data, buffer_target, buffer_task_id = buffer.get_buffer()
                buffer_output = model(buffer_data, buffer_task_id)
                loss += criterion(buffer_output, buffer_target)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f'Epoch {epoch + 1}/{epochs}, Loss: {total_loss / len(loader):.4f}')

# %%
class PNN(nn.Module):
    def __init__(self, shared_dim=128, output_dim_A=10, output_dim_B=2):
        super(PNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.fc1_A = nn.Linear(64 * 28 * 28, shared_dim)
        self.fc2_A = nn.Linear(shared_dim, output_dim_A)
        self.fc1_B = nn.Linear(64 * 28 * 28, shared_dim)
        self.fc2_B = nn.Linear(shared_dim, output_dim_B)

    def forward(self, x, task_id):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = x.view(x.size(0), -1)  # Flatten the tensor
        if task_id[0] == 1:
            x = F.relu(self.fc1_A(x))
            output = self.fc2_A(x)
        else:
            x = F.relu(self.fc1_B(x))
            output = self.fc2_B(x)
        return output

# %%
def train_pnn(model, loader, optimizer, criterion, task_num, epochs=50):
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        for data, target, task_id in loader:
            optimizer.zero_grad()
            output = model(data, task_id)
            loss = criterion(output, target)
            total_loss += loss.item()
            loss.backward()
            optimizer.step()
        print(f'Epoch {epoch + 1}/{epochs}, Loss: {total_loss / len(loader):.4f}')

def evaluate_pnn(model, loader, criterion, task_num):
    model.eval()
    total_loss = 0
    all_targets = []
    all_predictions = []
    with torch.no_grad():
        for data, target, task_id in loader:
            output = model(data, task_id)
            loss = criterion(output, target)
            total_loss += loss.item()
            predictions = torch.argmax(output, dim=1)
            all_targets.extend(target.numpy())
            all_predictions.extend(predictions.numpy())

    accuracy = accuracy_score(all_targets, all_predictions)
    precision = precision_score(all_targets, all_predictions, average='weighted', zero_division=0)
    recall = recall_score(all_targets, all_predictions, average='weighted', zero_division=0)
    kappa = cohen_kappa_score(all_targets, all_predictions)
    
    return accuracy, precision, recall, kappa

# %%
epoch_stats_other = {
    "si": {"acc_B": [], "loss_B": [], "task_A_during_B":[],"task_A_during_B_loss":[],"val_task_A_during_B":[],"val_acc_B":[],"A_during_A":[],"B_during_A":[],"A_during_A_val":[],"B_during_A_val":[]},
    "pnn": {"acc_B": [], "loss_B": [], "task_A_during_B":[],"task_A_during_B_loss":[],"val_task_A_during_B":[],"val_acc_B":[],"A_during_A":[],"B_during_A":[],"A_during_A_val":[],"B_during_A_val":[]},
    "reh": {"acc_B": [], "loss_B": [], "task_A_during_B":[],"task_A_during_B_loss":[],"val_task_A_during_B":[],"val_acc_B":[],"A_during_A":[],"B_during_A":[],"A_during_A_val":[],"B_during_A_val":[]}
}

num_runs = 10
epochs = 100

# %%
for key in epoch_stats_other["si"]:
    epoch_stats_other["si"][key] = []

# %%
# Initialize models, optimizers, and criteria
shared_dim = 128
output_dim_A = 10
output_dim_B = 2
lr = 0.00001
criterion = nn.CrossEntropyLoss()
import json


num_runs = 2
epochs = 50
for run in range(num_runs):
    print(f"Run {run + 1}/{num_runs}")
    
    # SI
    model_si = ConvNet(shared_dim=shared_dim, output_dim_A=output_dim_A, output_dim_B=output_dim_B)
    optimizer_si = optim.Adam(model_si.parameters(), lr=lr)
    

    A_during_A_si_run = []
    A_during_A_si_run_val = []
    B_during_A_si_run = []
    B_during_A_si_run_val = []
    
    #model_si.load_state_dict(weights)

    si = SynapticIntelligence(model_si, train_A_loader)
    
    # Train and evaluate with SI
    print("Training with SI on Task A")
    for epoch in range(25):
        train_with_si(model_si, optimizer_si, {'train': train_A_loader, 'val': val_A_loader}, si=None, lambda_si=0, epochs=1)

        # Evaluate on test set for Domain B
        accuracy_taskB_during_A_si, _, _, _ = evaluate(model_si, test_B_loader, criterion)
        B_during_A_si_run.append(accuracy_taskB_during_A_si)

        # Evaluate on validation set for Domain B
        accuracy_taskB_during_A_si_val, _, _, _ = evaluate(model_si, val_B_loader, criterion)
        B_during_A_si_run_val.append(accuracy_taskB_during_A_si_val)

        # Evaluate performance on Domain A during training on Domain B (test and validation)
        accuracy_A_during_A_si, _, _, _ = evaluate(model_si, test_A_loader, criterion)
        A_during_A_si_run.append(accuracy_A_during_A_si)

        accuracy_A_during_A_si_val, _, _, _ = evaluate(model_si, val_A_loader, criterion)
        A_during_A_si_run_val.append(accuracy_A_during_A_si_val)

    epoch_stats_other["si"]["A_during_A"].append(A_during_A_si_run)
    epoch_stats_other["si"]["B_during_A"].append(B_during_A_si_run)

    # Store validation metrics for each run
    epoch_stats_other["si"]["A_during_A_val"].append(A_during_A_si_run_val)
    epoch_stats_other["si"]["B_during_A_val"].append(B_during_A_si_run_val)

    print("Evaluating on Task A with SI")
    accuracy_taskA_si, precision_taskA_si, recall_taskA_si, kappa_taskA_si = evaluate(model_si, test_A_loader, criterion)
    print(accuracy_taskA_si)
    
    task_A_during_B_si_run = []
    task_B_si_run = []
    val_A_during_B_si_run = []
    val_B_si_run = []
    
    
    si.update_omega()
    si.store_optimal_params()
    
    for epoch in range(epochs):
        train_with_si(model_si, optimizer_si, {'train': train_B_loader, 'val': val_B_loader}, si=si, lambda_si=2, epochs=1)

        # Evaluate on test set for Domain B
        accuracy_taskB_during_si, _, _, _ = evaluate(model_si, test_B_loader, criterion)
        task_B_si_run.append(accuracy_taskB_during_si)
        print(accuracy_taskB_during_si)

        # Evaluate on validation set for Domain B
        accuracy_taskB_during_si_val, _, _, _ = evaluate(model_si, val_B_loader, criterion)
        val_B_si_run.append(accuracy_taskB_during_si_val)

        # Evaluate performance on Domain A during training on Domain B (test and validation)
        accuracy_A_during_taskB_during_si, _, _, _ = evaluate(model_si, test_A_loader, criterion)
        task_A_during_B_si_run.append(accuracy_A_during_taskB_during_si)

        accuracy_A_during_taskB_during_si_val, _, _, _ = evaluate(model_si, val_A_loader, criterion)
        val_A_during_B_si_run.append(accuracy_A_during_taskB_during_si_val)
        print(accuracy_A_during_taskB_during_si_val)

    epoch_stats_other["si"]["task_A_during_B"].append(task_A_during_B_si_run)
    epoch_stats_other["si"]["acc_B"].append(task_B_si_run)

    # Store validation metrics for each run
    epoch_stats_other["si"]["val_task_A_during_B"].append(val_A_during_B_si_run)
    epoch_stats_other["si"]["val_acc_B"].append(val_B_si_run)
        
    print("Evaluating on Task B with SI")
    accuracy_taskB_si, precision_taskB_si, recall_taskB_si, kappa_taskB_si = evaluate(model_si, test_B_loader, criterion)
    accuracy_taskB_si_val, precision_taskB_si_val, recall_taskB_si_val, kappa_taskB_si_val = evaluate(model_si, val_B_loader, criterion)
    
    print("Evaluating on Task A after Task B with SI")
    accuracy_taskA_final_si, precision_taskA_final_si, recall_taskA_final_si, kappa_taskA_final_si = evaluate(model_si, test_A_loader, criterion)
    accuracy_taskA_final_si_val, precision_taskA_final_si_val, recall_taskA_final_si_val, kappa_taskA_final_si_val = evaluate(model_si, val_A_loader, criterion)
    
    with open('epoch_stats_other_til_bench_SI_final_test.json', 'w') as f:
        json.dump(epoch_stats_other, f, indent=4)
# Out:
# Run 1/2
# Training with SI on Task A
# Epoch 1/1, Loss: 1.8949, Penalty: 0.0000
# Epoch 1/1, Loss: 0.9789, Penalty: 0.0000
# Epoch 1/1, Loss: 0.5907, Penalty: 0.0000
# Epoch 1/1, Loss: 0.4593, Penalty: 0.0000
# Epoch 1/1, Loss: 0.3959, Penalty: 0.0000
# Epoch 1/1, Loss: 0.3561, Penalty: 0.0000
# Epoch 1/1, Loss: 0.3298, Penalty: 0.0000
# Epoch 1/1, Loss: 0.3096, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2946, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2801, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2674, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2557, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2463, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2372, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2278, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2200, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2107, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2041, Penalty: 0.0000
# Epoch 1/1, Loss: 0.1970, Penalty: 0.0000
# Epoch 1/1, Loss: 0.1897, Penalty: 0.0000
# Epoch 1/1, Loss: 0.1820, Penalty: 0.0000
# Epoch 1/1, Loss: 0.1751, Penalty: 0.0000
# Epoch 1/1, Loss: 0.1690, Penalty: 0.0000
# Epoch 1/1, Loss: 0.1626, Penalty: 0.0000
# Epoch 1/1, Loss: 0.1570, Penalty: 0.0000
# Evaluating on Task A with SI
# 0.9546666666666667
# Epoch 1/1, Loss: 0.4837, Penalty: 0.0004
# 0.8973333333333333
# 0.8506666666666667
# Epoch 1/1, Loss: 0.2383, Penalty: 0.0005
# 0.9186666666666666
# 0.838
# Epoch 1/1, Loss: 0.2058, Penalty: 0.0006
# 0.9313333333333333
# 0.8276666666666667
# Epoch 1/1, Loss: 0.1824, Penalty: 0.0007
# 0.9386666666666666
# 0.8273333333333334
# Epoch 1/1, Loss: 0.1660, Penalty: 0.0008
# 0.9486666666666667
# 0.8226666666666667
# Epoch 1/1, Loss: 0.1519, Penalty: 0.0010
# 0.9546666666666667
# 0.8253333333333334
# Epoch 1/1, Loss: 0.1399, Penalty: 0.0011
# 0.9573333333333334
# 0.8306666666666667
# Epoch 1/1, Loss: 0.1292, Penalty: 0.0013
# 0.9606666666666667
# 0.829
# Epoch 1/1, Loss: 0.1209, Penalty: 0.0014
# 0.9653333333333334
# 0.8303333333333334
# Epoch 1/1, Loss: 0.1136, Penalty: 0.0016
# 0.962
# 0.832
# Epoch 1/1, Loss: 0.1064, Penalty: 0.0017
# 0.964
# 0.8323333333333334
# Epoch 1/1, Loss: 0.1016, Penalty: 0.0019
# 0.97
# 0.8326666666666667
# Epoch 1/1, Loss: 0.0965, Penalty: 0.0020
# 0.9706666666666667
# 0.8316666666666667
# Epoch 1/1, Loss: 0.0906, Penalty: 0.0022
# 0.9733333333333334
# 0.8346666666666667
# Epoch 1/1, Loss: 0.0874, Penalty: 0.0023
# 0.974
# 0.8356666666666667
# Epoch 1/1, Loss: 0.0835, Penalty: 0.0025
# 0.9766666666666667
# 0.8313333333333334
# Epoch 1/1, Loss: 0.0803, Penalty: 0.0026
# 0.97
# 0.835
# Epoch 1/1, Loss: 0.0770, Penalty: 0.0027
# 0.976
# 0.838
# Epoch 1/1, Loss: 0.0748, Penalty: 0.0029
# 0.9773333333333334
# 0.838
# Epoch 1/1, Loss: 0.0719, Penalty: 0.0030
# 0.9786666666666667
# 0.8406666666666667
# Epoch 1/1, Loss: 0.0695, Penalty: 0.0031
# 0.9793333333333333
# 0.8416666666666667
# Epoch 1/1, Loss: 0.0676, Penalty: 0.0032
# 0.9813333333333333
# 0.8436666666666667
# Epoch 1/1, Loss: 0.0652, Penalty: 0.0033
# 0.9786666666666667
# 0.842
# Epoch 1/1, Loss: 0.0642, Penalty: 0.0034
# 0.98
# 0.8443333333333334
# Epoch 1/1, Loss: 0.0615, Penalty: 0.0035
# 0.9773333333333334
# 0.843
# Epoch 1/1, Loss: 0.0604, Penalty: 0.0036
# 0.9813333333333333
# 0.8456666666666667
# Epoch 1/1, Loss: 0.0591, Penalty: 0.0037
# 0.9806666666666667
# 0.848
# Epoch 1/1, Loss: 0.0575, Penalty: 0.0038
# 0.9813333333333333
# 0.8473333333333334
# Epoch 1/1, Loss: 0.0565, Penalty: 0.0038
# 0.9813333333333333
# 0.849
# Epoch 1/1, Loss: 0.0553, Penalty: 0.0039
# 0.9786666666666667
# 0.8523333333333334
# Epoch 1/1, Loss: 0.0541, Penalty: 0.0040
# 0.9813333333333333
# 0.848
# Epoch 1/1, Loss: 0.0532, Penalty: 0.0041
# 0.9813333333333333
# 0.8506666666666667
# Epoch 1/1, Loss: 0.0518, Penalty: 0.0041
# 0.978
# 0.856
# Epoch 1/1, Loss: 0.0510, Penalty: 0.0042
# 0.9833333333333333
# 0.8526666666666667
# Epoch 1/1, Loss: 0.0500, Penalty: 0.0043
# 0.982
# 0.8573333333333333
# Epoch 1/1, Loss: 0.0488, Penalty: 0.0043
# 0.9833333333333333
# 0.855
# Epoch 1/1, Loss: 0.0488, Penalty: 0.0044
# 0.984
# 0.8526666666666667
# Epoch 1/1, Loss: 0.0476, Penalty: 0.0044
# 0.982
# 0.855
# Epoch 1/1, Loss: 0.0473, Penalty: 0.0045
# 0.9833333333333333
# 0.856
# Epoch 1/1, Loss: 0.0483, Penalty: 0.0046
# 0.9833333333333333
# 0.8576666666666667
# Epoch 1/1, Loss: 0.0469, Penalty: 0.0046
# 0.9813333333333333
# 0.8576666666666667
# Epoch 1/1, Loss: 0.0481, Penalty: 0.0047
# 0.9833333333333333
# 0.8586666666666667
# Epoch 1/1, Loss: 0.0443, Penalty: 0.0047
# 0.984
# 0.8626666666666667
# Epoch 1/1, Loss: 0.0436, Penalty: 0.0048
# 0.984
# 0.8606666666666667
# Epoch 1/1, Loss: 0.0428, Penalty: 0.0048
# 0.9833333333333333
# 0.865
# Epoch 1/1, Loss: 0.0424, Penalty: 0.0048
# 0.9833333333333333
# 0.8593333333333333
# Epoch 1/1, Loss: 0.0417, Penalty: 0.0049
# 0.9846666666666667
# 0.8606666666666667
# Epoch 1/1, Loss: 0.0412, Penalty: 0.0049
# 0.9826666666666667
# 0.8596666666666667
# Epoch 1/1, Loss: 0.0411, Penalty: 0.0050
# 0.984
# 0.865
# Epoch 1/1, Loss: 0.0404, Penalty: 0.0050
# 0.9833333333333333
# 0.8643333333333333
# Evaluating on Task B with SI
# Evaluating on Task A after Task B with SI
# Run 2/2
# Training with SI on Task A
# Epoch 1/1, Loss: 1.9432, Penalty: 0.0000
# Epoch 1/1, Loss: 1.0448, Penalty: 0.0000
# Epoch 1/1, Loss: 0.6296, Penalty: 0.0000
# Epoch 1/1, Loss: 0.4836, Penalty: 0.0000
# Epoch 1/1, Loss: 0.4170, Penalty: 0.0000
# Epoch 1/1, Loss: 0.3749, Penalty: 0.0000
# Epoch 1/1, Loss: 0.3494, Penalty: 0.0000
# Epoch 1/1, Loss: 0.3315, Penalty: 0.0000
# Epoch 1/1, Loss: 0.3163, Penalty: 0.0000
# Epoch 1/1, Loss: 0.3036, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2926, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2833, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2750, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2665, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2599, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2515, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2448, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2377, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2305, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2234, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2185, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2127, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2047, Penalty: 0.0000
# Epoch 1/1, Loss: 0.2015, Penalty: 0.0000
# Epoch 1/1, Loss: 0.1955, Penalty: 0.0000
# Evaluating on Task A with SI
# 0.9406666666666667
# Epoch 1/1, Loss: 0.3577, Penalty: 0.0001
# 0.8986666666666666
# 0.8953333333333333
# Epoch 1/1, Loss: 0.2438, Penalty: 0.0002
# 0.9186666666666666
# 0.8836666666666667
# Epoch 1/1, Loss: 0.2121, Penalty: 0.0003
# 0.9266666666666666
# 0.8783333333333333
# Epoch 1/1, Loss: 0.1896, Penalty: 0.0005
# 0.942
# 0.8783333333333333
# Epoch 1/1, Loss: 0.1727, Penalty: 0.0006
# 0.9426666666666667
# 0.878
# Epoch 1/1, Loss: 0.1583, Penalty: 0.0008
# 0.9493333333333334
# 0.877
# Epoch 1/1, Loss: 0.1484, Penalty: 0.0009
# 0.956
# 0.8756666666666667
# Epoch 1/1, Loss: 0.1390, Penalty: 0.0011
# 0.956
# 0.8763333333333333
# Epoch 1/1, Loss: 0.1322, Penalty: 0.0013
# 0.956
# 0.873
# Epoch 1/1, Loss: 0.1245, Penalty: 0.0015
# 0.9633333333333334
# 0.8713333333333333
# Epoch 1/1, Loss: 0.1179, Penalty: 0.0017
# 0.968
# 0.872
# Epoch 1/1, Loss: 0.1117, Penalty: 0.0018
# 0.9666666666666667
# 0.871
# Epoch 1/1, Loss: 0.1099, Penalty: 0.0020
# 0.9673333333333334
# 0.8716666666666667
# Epoch 1/1, Loss: 0.1022, Penalty: 0.0022
# 0.9686666666666667
# 0.8693333333333333
# Epoch 1/1, Loss: 0.0997, Penalty: 0.0023
# 0.9666666666666667
# 0.871
# Epoch 1/1, Loss: 0.0947, Penalty: 0.0025
# 0.9713333333333334
# 0.8663333333333333
# Epoch 1/1, Loss: 0.0912, Penalty: 0.0026
# 0.9746666666666667
# 0.8653333333333333
# Epoch 1/1, Loss: 0.0884, Penalty: 0.0027
# 0.9733333333333334
# 0.8676666666666667
# Epoch 1/1, Loss: 0.0847, Penalty: 0.0029
# 0.974
# 0.8656666666666667
# Epoch 1/1, Loss: 0.0839, Penalty: 0.0030
# 0.976
# 0.8653333333333333
# Epoch 1/1, Loss: 0.0803, Penalty: 0.0031
# 0.9766666666666667
# 0.8676666666666667
# Epoch 1/1, Loss: 0.0775, Penalty: 0.0032
# 0.976
# 0.867
# Epoch 1/1, Loss: 0.0760, Penalty: 0.0033
# 0.9753333333333334
# 0.867
# Epoch 1/1, Loss: 0.0740, Penalty: 0.0034
# 0.9746666666666667
# 0.8663333333333333
# Epoch 1/1, Loss: 0.0722, Penalty: 0.0035
# 0.9766666666666667
# 0.8626666666666667
# Epoch 1/1, Loss: 0.0699, Penalty: 0.0036
# 0.9786666666666667
# 0.8686666666666667
# Epoch 1/1, Loss: 0.0685, Penalty: 0.0037
# 0.9746666666666667
# 0.8673333333333333
# Epoch 1/1, Loss: 0.0681, Penalty: 0.0038
# 0.978
# 0.8656666666666667
# Epoch 1/1, Loss: 0.0655, Penalty: 0.0038
# 0.9773333333333334
# 0.8643333333333333
# Epoch 1/1, Loss: 0.0644, Penalty: 0.0039
# 0.978
# 0.8623333333333333
# Epoch 1/1, Loss: 0.0632, Penalty: 0.0040
# 0.978
# 0.862
# Epoch 1/1, Loss: 0.0619, Penalty: 0.0041
# 0.9786666666666667
# 0.862
# Epoch 1/1, Loss: 0.0603, Penalty: 0.0041
# 0.9786666666666667
# 0.8636666666666667
# Epoch 1/1, Loss: 0.0606, Penalty: 0.0042
# 0.978
# 0.8643333333333333
# Epoch 1/1, Loss: 0.0579, Penalty: 0.0042
# 0.978
# 0.8633333333333333
# Epoch 1/1, Loss: 0.0583, Penalty: 0.0043
# 0.978
# 0.8636666666666667
# Epoch 1/1, Loss: 0.0572, Penalty: 0.0044
# 0.9793333333333333
# 0.862
# Epoch 1/1, Loss: 0.0546, Penalty: 0.0044
# 0.98
# 0.8623333333333333
# Epoch 1/1, Loss: 0.0545, Penalty: 0.0045
# 0.9806666666666667
# 0.8616666666666667
# Epoch 1/1, Loss: 0.0540, Penalty: 0.0045
# 0.9806666666666667
# 0.8593333333333333
# Epoch 1/1, Loss: 0.0525, Penalty: 0.0046
# 0.9786666666666667
# 0.863
# Epoch 1/1, Loss: 0.0531, Penalty: 0.0046
# 0.98
# 0.8616666666666667
# Epoch 1/1, Loss: 0.0505, Penalty: 0.0047
# 0.98
# 0.8606666666666667
# Epoch 1/1, Loss: 0.0503, Penalty: 0.0047
# 0.9786666666666667
# 0.863
# Epoch 1/1, Loss: 0.0497, Penalty: 0.0048
# 0.98
# 0.862
# Epoch 1/1, Loss: 0.0491, Penalty: 0.0048
# 0.982
# 0.8606666666666667
# Epoch 1/1, Loss: 0.0492, Penalty: 0.0048
# 0.9806666666666667
# 0.862
# Epoch 1/1, Loss: 0.0481, Penalty: 0.0049
# 0.9806666666666667
# 0.863
# Epoch 1/1, Loss: 0.0468, Penalty: 0.0049
# 0.9806666666666667
# 0.8633333333333333
# Epoch 1/1, Loss: 0.0475, Penalty: 0.0050
# 0.982
# 0.8606666666666667
# Evaluating on Task B with SI
# Evaluating on Task A after Task B with SI

# %%
shared_dim = 128
output_dim_A = 10
output_dim_B = 2
epochs = 100
num_runs = 10
for run in range(num_runs):
    print(f"Run {run + 1}/{num_runs}")
    
    # Rehearsal
    model_rehearsal = ConvNet(shared_dim=shared_dim, output_dim_A=output_dim_A, output_dim_B=output_dim_B)
    optimizer_rehearsal = optim.Adam(model_rehearsal.parameters(), lr=lr)
    model_rehearsal = RehearsalBuffer(buffer_size=2000)

    #model_si.load_state_dict(torch.load('C:/Users/gslax/OneDrive/Desktop/Wits/MastersResearchReport/TIL/Data/Bench/taskA_model.pth'))
    
    # Train and evaluate with Rehearsal
    print("Training with Rehearsal on Task A")
    #train(model_rehearsal, train_A_loader, optimizer_rehearsal, criterion, epochs=epochs)
    print("Evaluating on Task A with Rehearsal")
    accuracy_taskA_rehearsal, precision_taskA_rehearsal, recall_taskA_rehearsal, kappa_taskA_rehearsal = evaluate(model_rehearsal, test_A_loader, criterion)
    
    print("Training with Rehearsal on Task B")
    task_A_during_B_reh_run = []
    task_B_reh_run = []
    val_A_during_B_reh_run = []
    val_B_reh_run = []
    
    print("Training with Rehearsal on Task B")
    for epoch in range(epochs):
        train_with_rehearsal(model_rehearsal, train_B_loader, buffer, optimizer_rehearsal, criterion, epochs=1)
        
        # Evaluate on test set for Domain B
        accuracy_taskB_during_reh, _, _, _ = evaluate(model_rehearsal, test_B_loader, criterion)
        task_B_reh_run.append(accuracy_taskB_during_reh)

        # Evaluate on validation set for Domain B
        accuracy_taskB_during_reh_val, _, _, _ = evaluate(model_rehearsal, val_B_loader, criterion)
        val_B_reh_run.append(accuracy_taskB_during_reh_val)

        # Evaluate performance on Domain A during training on Domain B (test and validation)
        accuracy_A_during_taskB_during_reh, _, _, _ = evaluate(model_rehearsal, test_A_loader, criterion)
        task_A_during_B_reh_run.append(accuracy_A_during_taskB_during_reh)

        accuracy_A_during_taskB_during_reh_val, _, _, _ = evaluate(model_rehearsal, val_A_loader, criterion)
        val_A_during_B_reh_run.append(accuracy_A_during_taskB_during_reh_val)

    epoch_stats_other["reh"]["task_A_during_B"].append(task_A_during_B_reh_run)
    epoch_stats_other["reh"]["acc_B"].append(task_B_reh_run)

    # Store validation metrics for each run
    epoch_stats_other["reh"]["val_task_A_during_B"].append(val_A_during_B_reh_run)
    epoch_stats_other["reh"]["val_acc_B"].append(val_B_reh_run)
    
    
    print("Evaluating on Task B with Rehearsal")
    accuracy_taskB_rehearsal, precision_taskB_rehearsal, recall_taskB_rehearsal, kappa_taskB_rehearsal = evaluate(model_rehearsal, test_B_loader, criterion)
    accuracy_taskB_rehearsal_val, precision_taskB_rehearsal_val, recall_taskB_rehearsal_val, kappa_taskB_rehearsal_val = evaluate(model_rehearsal, val_B_loader, criterion)

    
    print("Evaluating on Task A after Task B with Rehearsal")
    accuracy_taskA_final_rehearsal, precision_taskA_final_rehearsal, recall_taskA_final_rehearsal, kappa_taskA_final_rehearsal = evaluate(model_rehearsal, test_B_loader, criterion)
    accuracy_taskA_final_rehearsal_val, precision_taskA_final_rehearsal_val, recall_taskA_final_rehearsal_val, kappa_taskA_final_rehearsal_val = evaluate(model_rehearsal, val_B_loader, criterion)

    with open('epoch_stats_other_REH_bench.json', 'w') as f:
        json.dump(epoch_stats_other, f, indent=4)

# %%
shared_dim = 128
output_dim_A = 10
output_dim_B = 2
criterion = nn.CrossEntropyLoss()
import json
num_runs = 10
epochs = 100
for run in range(num_runs):
    print(f"Run {run + 1}/{num_runs}")

    # Initialize the PNN model
    lr = 0.0001
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model_pnn = PNN(shared_dim=shared_dim, output_dim_A=output_dim_A, output_dim_B=output_dim_B).to(device)
    
    # Optimizers for tasks A and B
    optimizer_pnn_A = optim.Adam(list(model_pnn.fc1_A.parameters()) + list(model_pnn.fc2_A.parameters()), lr=lr)
    optimizer_pnn_B = optim.Adam(list(model_pnn.fc1_B.parameters()) + list(model_pnn.fc2_B.parameters()), lr=lr)


    task_B_during_A_pnn_run = []
    task_A_during_A_pnn_run = []
    
    # Train and evaluate on Task A
    print("Training with PNN on Task A")
    for epoch in range(25):
        train_pnn(model_pnn, train_A_loader, optimizer_pnn_A, criterion, task_num=0, epochs=1)
        # Evaluate on test set for Domain B
        accuracy_taskA_during_A, _, _, _ = evaluate_pnn(model_pnn, test_A_loader, criterion, task_num=0)
        task_A_during_A_pnn_run.append(accuracy_taskA_during_A)

        # Evaluate on validation set for Domain B
        accuracy_taskB_during_A, _, _, _ = evaluate_pnn(model_pnn, test_B_loader, criterion, task_num=1)
        task_B_during_A_pnn_run.append(accuracy_taskB_during_A)

    epoch_stats_other["pnn"]["A_during_A"].append(task_A_during_A_pnn_run)
    epoch_stats_other["pnn"]["B_during_A"].append(task_B_during_A_pnn_run)

    
    print("Evaluating on Task A with PNN")
    accuracy_taskA_pnn, precision_taskA_pnn, recall_taskA_pnn, kappa_taskA_pnn = evaluate_pnn(model_pnn, test_A_loader, criterion, task_num=0)
    print("Evaluating on Task A with PNN - validation Data")
    accuracy_taskA_pnn, precision_taskA_pnn, recall_taskA_pnn, kappa_taskA_pnn = evaluate_pnn(model_pnn, val_A_loader, criterion, task_num=0)

    
    # Train and evaluate on Task B
    print("Training with PNN on Task B")
    task_A_during_B_pnn_run = []
    task_B_pnn_run = []
    val_A_during_B_pnn_run = []
    val_B_pnn_run = []
    
    for epoch in range(epochs):
        train_pnn(model_pnn, train_B_loader, optimizer_pnn_B, criterion, task_num=1, epochs=1)
        
        # Evaluate on test set for Domain B
        accuracy_taskB_during_pnn, _, _, _ = evaluate_pnn(model_pnn, test_B_loader, criterion, task_num=1)
        task_B_pnn_run.append(accuracy_taskB_during_pnn)

        # Evaluate on validation set for Domain B
        accuracy_taskB_during_pnn_val, _, _, _ = evaluate_pnn(model_pnn, val_B_loader, criterion, task_num=1)
        val_B_pnn_run.append(accuracy_taskB_during_pnn_val)

        # Evaluate performance on Domain A during training on Domain B (test and validation)
        accuracy_A_during_taskB_during_pnn, _, _, _ = evaluate_pnn(model_pnn, test_A_loader, criterion, task_num=0)
        task_A_during_B_pnn_run.append(accuracy_A_during_taskB_during_pnn)

        accuracy_A_during_taskB_during_pnn_val, _, _, _ = evaluate_pnn(model_pnn, val_A_loader, criterion, task_num=0)
        val_A_during_B_pnn_run.append(accuracy_A_during_taskB_during_pnn_val)

    epoch_stats_other["pnn"]["task_A_during_B"].append(task_A_during_B_pnn_run)
    epoch_stats_other["pnn"]["acc_B"].append(task_B_pnn_run)

    # Store validation metrics for each run
    epoch_stats_other["pnn"]["val_task_A_during_B"].append(val_A_during_B_pnn_run)
    epoch_stats_other["pnn"]["val_acc_B"].append(val_B_pnn_run)
    
    print("Evaluating on Task B with PNN")
    accuracy_taskB_pnn, precision_taskB_pnn, recall_taskB_pnn, kappa_taskB_pnn = evaluate_pnn(model_pnn, test_B_loader, criterion, task_num=1)
    print("Evaluating on Task B with PNN - Validation")
    accuracy_taskB_pnn, precision_taskB_pnn, recall_taskB_pnn, kappa_taskB_pnn = evaluate_pnn(model_pnn, val_B_loader, criterion, task_num=1)
    
    
    # Evaluate on Task A after training on Task B
    print("Evaluating on Task A after training on Task B with PNN")
    accuracy_taskA_after_B_pnn, precision_taskA_after_B_pnn, recall_taskA_after_B_pnn, kappa_taskA_after_B_pnn = evaluate_pnn(model_pnn, test_A_loader, criterion, task_num=0)
    # Evaluate on Task A after training on Task B
    print("Evaluating on Task A after training on Task B with PNN - Validation")
    accuracy_taskA_after_B_pnn, precision_taskA_after_B_pnn, recall_taskA_after_B_pnn, kappa_taskA_after_B_pnn = evaluate_pnn(model_pnn, val_A_loader, criterion, task_num=0)

    with open('epoch_stats_other_PNN_TIL_bench_final.json', 'w') as f:
        json.dump(epoch_stats_other, f, indent=4)

# %%
import numpy as np

# Hyperparameters
learning_rate = 0.00001

# Initialize storage for results, including "Untrained_A"
results = {
    "untrained_A": {"accuracy": [], "precision": [], "recall": [], "kappa": []},
    "initial_A": {"accuracy": [], "precision": [], "recall": [], "kappa": []},
    "B_ewc": {"accuracy": [], "precision": [], "recall": [], "kappa": []},
    "A_after_B_ewc": {"accuracy": [], "precision": [], "recall": [], "kappa": []},
    "B_no_ewc": {"accuracy": [], "precision": [], "recall": [], "kappa": []},
    "A_after_B_no_ewc": {"accuracy": [], "precision": [], "recall": [], "kappa": []}
}

results_val = {
    "initial_A_val": {"accuracy": [], "precision": [], "recall": [], "kappa": []},
    "B_ewc_val": {"accuracy": [], "precision": [], "recall": [], "kappa": []},
    "A_after_B_ewc_val": {"accuracy": [], "precision": [], "recall": [], "kappa": []},
    "B_no_ewc_val": {"accuracy": [], "precision": [], "recall": [], "kappa": []},
    "A_after_B_no_ewc_val": {"accuracy": [], "precision": [], "recall": [], "kappa": []}
}

# Store per-epoch values for plotting
epoch_stats = {
    "Initial": {"accuracy": [], "loss": []},
    "ewc": {"accuracy": [], "loss": [], "task_A_during_B":[], "val_task_A_during_B": [], "val_acc": [], "val_loss": [],"val_task_B":[],"task_B":[],"B_during_A":[],"B_during_A_val":[],"A_during_A":[],"A_during_A_val":[]},
    "no_ewc": {"accuracy": [], "loss": [], "task_A_during_B": [], "val_task_A_during_B": [], "val_acc": [], "val_loss": [],"task_B":[],"val_task_B":[]}
}

epochs = 50
num_runs = 10

for run in range(num_runs):
    print(f"Run {run + 1}/{num_runs}")

    # Initialize the model for Task A
    modelA = ConvNet(shared_dim=128, output_dim_A=10, output_dim_B=2)
    optimizerA = optim.Adam(modelA.parameters(), lr=learning_rate)
    criterion = nn.CrossEntropyLoss()

    # Evaluate "Untrained_A" - performance on Task A before any training
    accuracy_untrained_A, precision_untrained_A, recall_untrained_A, kappa_untrained_A = evaluate(modelA, test_A_loader, criterion)
    print(f"Task A - Untrained: Accuracy: {accuracy_untrained_A}, Precision: {precision_untrained_A}, Recall: {recall_untrained_A}, Kappa: {kappa_untrained_A}")
    results["untrained_A"]["accuracy"].append(accuracy_untrained_A)
    results["untrained_A"]["precision"].append(precision_untrained_A)
    results["untrained_A"]["recall"].append(recall_untrained_A)
    results["untrained_A"]["kappa"].append(kappa_untrained_A)

    task_A_ewc_run = []
    val_task_A_ewc_run = []

    task_B_during_A_ewc_run = []
    val_task_B_during_A_ewc_run = []

    
    
    # # Train model on Task A (digit classification)
    for epoch in range(25):
        acc_A, loss_A = train_with_patience(modelA, train_A_loader, optimizerA, criterion, epochs = 1, patience=100)
        
        # Track performance on Task B
        accuracy_taskA, _, _, _ = evaluate(modelA, test_A_loader, criterion)
        print(f"Epoch {epoch + 1} - Task A performance during Task A (with EWC): {accuracy_taskA:.4f}")
        task_A_ewc_run.append(accuracy_taskA)
        
        # Track performance on Task B
        val_accuracy_taskA, _, _, _ = evaluate(modelA, val_A_loader, criterion)
        print(f"Epoch {epoch + 1} - Task A performance during Task A - validation set (with EWC): {val_accuracy_taskA:.4f}")
        val_task_A_ewc_run.append(val_accuracy_taskA)
        
        # Track performance on Task A while training on Task B
        accuracy_taskB_during_A_ewc, _, _, _ = evaluate(modelA, test_B_loader, criterion)
        print(f"Epoch {epoch + 1} - Task B performance during Task A (with EWC): {accuracy_taskB_during_A_ewc:.4f}")
        task_B_during_A_ewc_run.append(accuracy_taskB_during_A_ewc)
        
        # Track performance on Task A while training on Task B
        val_accuracy_taskB_during_A_ewc, _, _, _ = evaluate(modelA, val_B_loader, criterion)
        print(f"Epoch {epoch + 1} - Task B performance during Task A - validation set (with EWC): {val_accuracy_taskB_during_A_ewc:.4f}")
        val_task_B_during_A_ewc_run.append(val_accuracy_taskB_during_A_ewc)

    epoch_stats["ewc"]["B_during_A"].append(task_B_during_A_ewc_run)
    epoch_stats["ewc"]["B_during_A_val"].append(val_task_B_during_A_ewc_run)
    epoch_stats["ewc"]["A_during_A"].append(task_A_ewc_run)
    epoch_stats["ewc"]["A_during_A_val"].append(val_task_A_ewc_run)

     # Save model weights after Task A training
    task_a_weights.append(modelA.state_dict())
    #modelA.load_state_dict(weights)  # Directly load the state dict

    # Store epoch-wise results for plotting
    #epoch_stats["Initial"]["accuracy"].append(acc_A)
    #epoch_stats["Initial"]["loss"].append(loss_A)
    
    # Evaluate initial performance on Task A
    accuracy_taskA_initial, precision_taskA_initial, recall_taskA_initial, kappa_taskA_initial = evaluate(modelA, test_A_loader, criterion)
    print(f"Task A - Initial: Accuracy: {accuracy_taskA_initial}, Precision: {precision_taskA_initial}, Recall: {recall_taskA_initial}, Cohen's Kappa: {kappa_taskA_initial}")
    results["initial_A"]["accuracy"].append(accuracy_taskA_initial)
    results["initial_A"]["precision"].append(precision_taskA_initial)
    results["initial_A"]["recall"].append(recall_taskA_initial)
    results["initial_A"]["kappa"].append(kappa_taskA_initial)

    # Evaluate initial performance on Task A - validation set
    accuracy_taskA_initial_val, precision_taskA_initial_val, recall_taskA_initial_val, kappa_taskA_initial_val = evaluate(modelA, val_A_loader, criterion)
    print(f"Task A - Initial: Accuracy: {accuracy_taskA_initial_val:.4f}, Precision: {precision_taskA_initial_val:.4f}, Recall: {recall_taskA_initial_val:.4f}, Cohen's Kappa: {kappa_taskA_initial_val:.4f}")
    results_val["initial_A_val"]["accuracy"].append(accuracy_taskA_initial_val)
    results_val["initial_A_val"]["precision"].append(precision_taskA_initial_val)
    results_val["initial_A_val"]["recall"].append(recall_taskA_initial_val)
    results_val["initial_A_val"]["kappa"].append(kappa_taskA_initial_val)

    # Initialize EWC
    ewc = EWC(modelA, train_A_loader, importance=9999999999999999)

    # Store task_A_during_B as a list for this run
    task_A_during_B_ewc_run = []
    task_A_during_B_no_ewc_run = []

    task_B_ewc_run = []
    task_B_no_ewc_run = []

    val_task_B_ewc_run = []
    val_task_B_no_ewc_run = []

    val_task_A_during_B_ewc_run = []
    val_task_A_during_B_no_ewc_run = []

    
    for epoch in range(epochs):
        # Train model on Task B with EWC
        acc_B_ewc, loss_B_ewc = train_with_ewc_with_patience(modelA, train_B_loader, ewc, optimizerA, criterion, epochs=1, patience=20)
    
        # Store epoch-wise results for Task B
        #epoch_stats["ewc"]["accuracy"].append(acc_B_ewc)
        #epoch_stats["ewc"]["loss"].append(loss_B_ewc)

        # Track performance on Task B
        accuracy_taskB, _, _, _ = evaluate(modelA, test_B_loader, criterion)
        print(f"Epoch {epoch + 1} - Task B performance during Task B (with EWC): {accuracy_taskB:.4f}")
        task_B_ewc_run.append(accuracy_taskB)

        # Track performance on Task B
        val_accuracy_taskB, _, _, _ = evaluate(modelA, val_B_loader, criterion)
        print(f"Epoch {epoch + 1} - Task B performance during Task B - validation set (with EWC): {val_accuracy_taskB:.4f}")
        val_task_B_ewc_run.append(val_accuracy_taskB)
    
        # Track performance on Task A while training on Task B
        accuracy_taskA_during_B_ewc, _, _, _ = evaluate(modelA, test_A_loader, criterion)
        print(f"Epoch {epoch + 1} - Task A performance during Task B (with EWC): {accuracy_taskA_during_B_ewc:.4f}")
        task_A_during_B_ewc_run.append(accuracy_taskA_during_B_ewc)

        # Track performance on Task A while training on Task B
        val_accuracy_taskA_during_B_ewc, _, _, _ = evaluate(modelA, val_A_loader, criterion)
        print(f"Epoch {epoch + 1} - Task A performance during Task B - validation set (with EWC): {val_accuracy_taskA_during_B_ewc:.4f}")
        val_task_A_during_B_ewc_run.append(val_accuracy_taskA_during_B_ewc)
        
    epoch_stats["ewc"]["task_A_during_B"].append(task_A_during_B_ewc_run)
    epoch_stats["ewc"]["val_task_A_during_B"].append(val_task_A_during_B_ewc_run)
    epoch_stats["ewc"]["task_B"].append(task_B_ewc_run)
    epoch_stats["ewc"]["val_task_B"].append(val_task_B_ewc_run)

    # Evaluate performance on Task B with EWC
    accuracy_taskB_ewc, precision_taskB_ewc, recall_taskB_ewc, kappa_taskB_ewc = evaluate(modelA, test_B_loader, criterion)
    print(f"Task B with EWC: Accuracy: {accuracy_taskB_ewc}, Precision: {precision_taskB_ewc}, Recall: {recall_taskB_ewc}, Cohen's Kappa: {kappa_taskB_ewc}")
    results["B_ewc"]["accuracy"].append(accuracy_taskB_ewc)
    results["B_ewc"]["precision"].append(precision_taskB_ewc)
    results["B_ewc"]["recall"].append(recall_taskB_ewc)
    results["B_ewc"]["kappa"].append(kappa_taskB_ewc)

    # Evaluate on Task B - Validation
    accuracy_taskB_ewc_val, precision_taskB_ewc_val, recall_taskB_ewc_val, kappa_taskB_ewc_val = evaluate(modelA, val_B_loader, criterion)
    print(f"Task A after Task B with EWC: Accuracy: {accuracy_taskB_ewc_val:.4f}, Precision: {precision_taskB_ewc_val:.4f}, Recall: {recall_taskB_ewc_val:.4f}, Kappa: {kappa_taskB_ewc_val:.4f}")
    results_val["B_ewc_val"]["accuracy"].append(accuracy_taskB_ewc_val)
    results_val["B_ewc_val"]["precision"].append(precision_taskB_ewc_val)
    results_val["B_ewc_val"]["recall"].append(recall_taskB_ewc_val)
    results_val["B_ewc_val"]["kappa"].append(kappa_taskB_ewc_val)

    # Evaluate performance on Task A after training on Task B with EWC
    accuracy_taskA_final_ewc, precision_taskA_final_ewc, recall_taskA_final_ewc, kappa_taskA_final_ewc = evaluate(modelA, test_A_loader, criterion)
    print(f"Task A - Final with EWC: Accuracy: {accuracy_taskA_final_ewc}, Precision: {precision_taskA_final_ewc}, Recall: {recall_taskA_final_ewc}, Cohen's Kappa: {kappa_taskA_final_ewc}")
    results["A_after_B_ewc"]["accuracy"].append(accuracy_taskA_final_ewc)
    results["A_after_B_ewc"]["precision"].append(precision_taskA_final_ewc)
    results["A_after_B_ewc"]["recall"].append(recall_taskA_final_ewc)
    results["A_after_B_ewc"]["kappa"].append(kappa_taskA_final_ewc)

    # Evaluate performance on Task A after training on Task B with EWC - Validation
    accuracy_taskA_after_B_ewc_val, precision_taskA_after_B_ewc_val, recall_taskA_after_B_ewc_val, kappa_taskA_after_B_ewc_val = evaluate(modelA, val_A_loader, criterion)
    print(f"Task A after Task B with EWC: Accuracy: {accuracy_taskA_after_B_ewc_val:.4f}, Precision: {precision_taskA_after_B_ewc_val:.4f}, Recall: {recall_taskA_after_B_ewc_val:.4f}, Cohen's Kappa: {kappa_taskA_after_B_ewc_val:.4f}")
    results_val["A_after_B_ewc_val"]["accuracy"].append(accuracy_taskA_after_B_ewc_val)
    results_val["A_after_B_ewc_val"]["precision"].append(precision_taskA_after_B_ewc_val)
    results_val["A_after_B_ewc_val"]["recall"].append(recall_taskA_after_B_ewc_val)
    results_val["A_after_B_ewc_val"]["kappa"].append(kappa_taskA_after_B_ewc_val)

    with open('epoch_stats_TIL_Bench_smaller_sample_final_test.json', 'w') as f:
        json.dump(epoch_stats, f, indent=4)
    
        #torch.save(task_a_weights, 'task_a_weights_til_bench.pth')
# Out:
# Run 1/10
# Task A - Untrained: Accuracy: 0.10333333333333333, Precision: 0.02144229650824668, Recall: 0.10333333333333333, Kappa: 0.0037037037037036535
# Epoch 1/1, Loss: 1.9479
# Epoch 1 - Task A performance during Task A (with EWC): 0.7593
# Epoch 1 - Task A performance during Task A - validation set (with EWC): 0.7263
# Epoch 1 - Task B performance during Task A (with EWC): 0.3460
# Epoch 1 - Task B performance during Task A - validation set (with EWC): 0.3353
# Epoch 1/1, Loss: 1.0519
# Epoch 2 - Task A performance during Task A (with EWC): 0.8593
# Epoch 2 - Task A performance during Task A - validation set (with EWC): 0.8427
# Epoch 2 - Task B performance during Task A (with EWC): 0.4073
# Epoch 2 - Task B performance during Task A - validation set (with EWC): 0.3977
# Epoch 1/1, Loss: 0.6222
# Epoch 3 - Task A performance during Task A (with EWC): 0.8807
# Epoch 3 - Task A performance during Task A - validation set (with EWC): 0.8660
# Epoch 3 - Task B performance during Task A (with EWC): 0.4060
# Epoch 3 - Task B performance during Task A - validation set (with EWC): 0.3950
# Epoch 1/1, Loss: 0.4764
# Epoch 4 - Task A performance during Task A (with EWC): 0.8920
# Epoch 4 - Task A performance during Task A - validation set (with EWC): 0.8747
# Epoch 4 - Task B performance during Task A (with EWC): 0.4080
# Epoch 4 - Task B performance during Task A - validation set (with EWC): 0.3973
# Epoch 1/1, Loss: 0.4083
# Epoch 5 - Task A performance during Task A (with EWC): 0.9033
# Epoch 5 - Task A performance during Task A - validation set (with EWC): 0.8840
# Epoch 5 - Task B performance during Task A (with EWC): 0.3967
# Epoch 5 - Task B performance during Task A - validation set (with EWC): 0.3863
# Epoch 1/1, Loss: 0.3671
# Epoch 6 - Task A performance during Task A (with EWC): 0.9087
# Epoch 6 - Task A performance during Task A - validation set (with EWC): 0.8913
# Epoch 6 - Task B performance during Task A (with EWC): 0.3893
# Epoch 6 - Task B performance during Task A - validation set (with EWC): 0.3780
# Epoch 1/1, Loss: 0.3426
# Epoch 7 - Task A performance during Task A (with EWC): 0.9147
# Epoch 7 - Task A performance during Task A - validation set (with EWC): 0.8947
# Epoch 7 - Task B performance during Task A (with EWC): 0.3813
# Epoch 7 - Task B performance during Task A - validation set (with EWC): 0.3710
# Epoch 1/1, Loss: 0.3213
# Epoch 8 - Task A performance during Task A (with EWC): 0.9113
# Epoch 8 - Task A performance during Task A - validation set (with EWC): 0.9013
# Epoch 8 - Task B performance during Task A (with EWC): 0.3860
# Epoch 8 - Task B performance during Task A - validation set (with EWC): 0.3747
# Epoch 1/1, Loss: 0.3056
# Epoch 9 - Task A performance during Task A (with EWC): 0.9160
# Epoch 9 - Task A performance during Task A - validation set (with EWC): 0.9073
# Epoch 9 - Task B performance during Task A (with EWC): 0.3907
# Epoch 9 - Task B performance during Task A - validation set (with EWC): 0.3813
# Epoch 1/1, Loss: 0.2933
# Epoch 10 - Task A performance during Task A (with EWC): 0.9180
# Epoch 10 - Task A performance during Task A - validation set (with EWC): 0.9073
# Epoch 10 - Task B performance during Task A (with EWC): 0.3893
# Epoch 10 - Task B performance during Task A - validation set (with EWC): 0.3763
# Epoch 1/1, Loss: 0.2807
# Epoch 11 - Task A performance during Task A (with EWC): 0.9240
# Epoch 11 - Task A performance during Task A - validation set (with EWC): 0.9107
# Epoch 11 - Task B performance during Task A (with EWC): 0.3947
# Epoch 11 - Task B performance during Task A - validation set (with EWC): 0.3820
# Epoch 1/1, Loss: 0.2699
# Epoch 12 - Task A performance during Task A (with EWC): 0.9207
# Epoch 12 - Task A performance during Task A - validation set (with EWC): 0.9120
# Epoch 12 - Task B performance during Task A (with EWC): 0.3907
# Epoch 12 - Task B performance during Task A - validation set (with EWC): 0.3780
# Epoch 1/1, Loss: 0.2618
# Epoch 13 - Task A performance during Task A (with EWC): 0.9273
# Epoch 13 - Task A performance during Task A - validation set (with EWC): 0.9150
# Epoch 13 - Task B performance during Task A (with EWC): 0.3913
# Epoch 13 - Task B performance during Task A - validation set (with EWC): 0.3790
# Epoch 1/1, Loss: 0.2525
# Epoch 14 - Task A performance during Task A (with EWC): 0.9247
# Epoch 14 - Task A performance during Task A - validation set (with EWC): 0.9167
# Epoch 14 - Task B performance during Task A (with EWC): 0.3940
# Epoch 14 - Task B performance during Task A - validation set (with EWC): 0.3807
# Epoch 1/1, Loss: 0.2452
# Epoch 15 - Task A performance during Task A (with EWC): 0.9260
# Epoch 15 - Task A performance during Task A - validation set (with EWC): 0.9163
# Epoch 15 - Task B performance during Task A (with EWC): 0.3873
# Epoch 15 - Task B performance during Task A - validation set (with EWC): 0.3757
# Epoch 1/1, Loss: 0.2368
# Epoch 16 - Task A performance during Task A (with EWC): 0.9340
# Epoch 16 - Task A performance during Task A - validation set (with EWC): 0.9183
# Epoch 16 - Task B performance during Task A (with EWC): 0.3987
# Epoch 16 - Task B performance during Task A - validation set (with EWC): 0.3867
# Epoch 1/1, Loss: 0.2302
# Epoch 17 - Task A performance during Task A (with EWC): 0.9333
# Epoch 17 - Task A performance during Task A - validation set (with EWC): 0.9203
# Epoch 17 - Task B performance during Task A (with EWC): 0.3920
# Epoch 17 - Task B performance during Task A - validation set (with EWC): 0.3810
# Epoch 1/1, Loss: 0.2229
# Epoch 18 - Task A performance during Task A (with EWC): 0.9313
# Epoch 18 - Task A performance during Task A - validation set (with EWC): 0.9227
# Epoch 18 - Task B performance during Task A (with EWC): 0.3927
# Epoch 18 - Task B performance during Task A - validation set (with EWC): 0.3813
# Epoch 1/1, Loss: 0.2168
# Epoch 19 - Task A performance during Task A (with EWC): 0.9387
# Epoch 19 - Task A performance during Task A - validation set (with EWC): 0.9247
# Epoch 19 - Task B performance during Task A (with EWC): 0.3960
# Epoch 19 - Task B performance during Task A - validation set (with EWC): 0.3837
# Epoch 1/1, Loss: 0.2096
# Epoch 20 - Task A performance during Task A (with EWC): 0.9320
# Epoch 20 - Task A performance during Task A - validation set (with EWC): 0.9223
# Epoch 20 - Task B performance during Task A (with EWC): 0.3900
# Epoch 20 - Task B performance during Task A - validation set (with EWC): 0.3810
# Epoch 1/1, Loss: 0.2027
# Epoch 21 - Task A performance during Task A (with EWC): 0.9400
# Epoch 21 - Task A performance during Task A - validation set (with EWC): 0.9260
# Epoch 21 - Task B performance during Task A (with EWC): 0.3900
# Epoch 21 - Task B performance during Task A - validation set (with EWC): 0.3807
# Epoch 1/1, Loss: 0.1964
# Epoch 22 - Task A performance during Task A (with EWC): 0.9407
# Epoch 22 - Task A performance during Task A - validation set (with EWC): 0.9247
# Epoch 22 - Task B performance during Task A (with EWC): 0.3880
# Epoch 22 - Task B performance during Task A - validation set (with EWC): 0.3757
# Epoch 1/1, Loss: 0.1904
# Epoch 23 - Task A performance during Task A (with EWC): 0.9387
# Epoch 23 - Task A performance during Task A - validation set (with EWC): 0.9283
# Epoch 23 - Task B performance during Task A (with EWC): 0.3907
# Epoch 23 - Task B performance during Task A - validation set (with EWC): 0.3783
# Epoch 1/1, Loss: 0.1845
# Epoch 24 - Task A performance during Task A (with EWC): 0.9453
# Epoch 24 - Task A performance during Task A - validation set (with EWC): 0.9310
# Epoch 24 - Task B performance during Task A (with EWC): 0.3927
# Epoch 24 - Task B performance during Task A - validation set (with EWC): 0.3803
# Epoch 1/1, Loss: 0.1797
# Epoch 25 - Task A performance during Task A (with EWC): 0.9447
# Epoch 25 - Task A performance during Task A - validation set (with EWC): 0.9297
# Epoch 25 - Task B performance during Task A (with EWC): 0.3980
# Epoch 25 - Task B performance during Task A - validation set (with EWC): 0.3857
# Task A - Initial: Accuracy: 0.9446666666666667, Precision: 0.945010627894709, Recall: 0.9446666666666667, Cohen's Kappa: 0.9385185185185185
# Task A - Initial: Accuracy: 0.9297, Precision: 0.9301, Recall: 0.9297, Cohen's Kappa: 0.9218
# Epoch 1/1, Loss: 1.1693, Penalty: 675192529.1051
# Epoch 1 - Task B performance during Task B (with EWC): 0.6640
# Epoch 1 - Task B performance during Task B - validation set (with EWC): 0.6620
# Epoch 1 - Task A performance during Task B (with EWC): 0.9240
# Epoch 1 - Task A performance during Task B - validation set (with EWC): 0.9050
# Epoch 1/1, Loss: 0.7894, Penalty: 738445897.8723
# Epoch 2 - Task B performance during Task B (with EWC): 0.6887
# Epoch 2 - Task B performance during Task B - validation set (with EWC): 0.6773
# Epoch 2 - Task A performance during Task B (with EWC): 0.9240
# Epoch 2 - Task A performance during Task B - validation set (with EWC): 0.9050
# Epoch 1/1, Loss: 0.7028, Penalty: 738469906.7234
# Epoch 3 - Task B performance during Task B (with EWC): 0.7020
# Epoch 3 - Task B performance during Task B - validation set (with EWC): 0.6943
# Epoch 3 - Task A performance during Task B (with EWC): 0.9240
# Epoch 3 - Task A performance during Task B - validation set (with EWC): 0.9050
# Epoch 1/1, Loss: 0.6390, Penalty: 738491136.0000
# Epoch 4 - Task B performance during Task B (with EWC): 0.7100
# Epoch 4 - Task B performance during Task B - validation set (with EWC): 0.7050
# Epoch 4 - Task A performance during Task B (with EWC): 0.9240
# Epoch 4 - Task A performance during Task B - validation set (with EWC): 0.9050
# Epoch 1/1, Loss: 0.5885, Penalty: 738517608.1702
# Epoch 5 - Task B performance during Task B (with EWC): 0.7173
# Epoch 5 - Task B performance during Task B - validation set (with EWC): 0.7197
# Epoch 5 - Task A performance during Task B (with EWC): 0.9240
# Epoch 5 - Task A performance during Task B - validation set (with EWC): 0.9050
# Epoch 1/1, Loss: 0.5462, Penalty: 738556798.9787
# Epoch 6 - Task B performance during Task B (with EWC): 0.7333
# Epoch 6 - Task B performance during Task B - validation set (with EWC): 0.7373
# Epoch 6 - Task A performance during Task B (with EWC): 0.9240
# Epoch 6 - Task A performance during Task B - validation set (with EWC): 0.9047
# Epoch 1/1, Loss: 0.5124, Penalty: 738572937.5319
# Epoch 7 - Task B performance during Task B (with EWC): 0.7553
# Epoch 7 - Task B performance during Task B - validation set (with EWC): 0.7557
# Epoch 7 - Task A performance during Task B (with EWC): 0.9240
# Epoch 7 - Task A performance during Task B - validation set (with EWC): 0.9047
# Epoch 1/1, Loss: 0.4839, Penalty: 738602546.0426
# Epoch 8 - Task B performance during Task B (with EWC): 0.7680
# Epoch 8 - Task B performance during Task B - validation set (with EWC): 0.7713
# Epoch 8 - Task A performance during Task B (with EWC): 0.9240
# Epoch 8 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.4605, Penalty: 738637745.7021
# Epoch 9 - Task B performance during Task B (with EWC): 0.7847
# Epoch 9 - Task B performance during Task B - validation set (with EWC): 0.7897
# Epoch 9 - Task A performance during Task B (with EWC): 0.9233
# Epoch 9 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.4412, Penalty: 738691944.5106
# Epoch 10 - Task B performance during Task B (with EWC): 0.7973
# Epoch 10 - Task B performance during Task B - validation set (with EWC): 0.8057
# Epoch 10 - Task A performance during Task B (with EWC): 0.9233
# Epoch 10 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.4254, Penalty: 738758888.1702
# Epoch 11 - Task B performance during Task B (with EWC): 0.8080
# Epoch 11 - Task B performance during Task B - validation set (with EWC): 0.8200
# Epoch 11 - Task A performance during Task B (with EWC): 0.9233
# Epoch 11 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.4119, Penalty: 738803756.2553
# Epoch 12 - Task B performance during Task B (with EWC): 0.8160
# Epoch 12 - Task B performance during Task B - validation set (with EWC): 0.8287
# Epoch 12 - Task A performance during Task B (with EWC): 0.9240
# Epoch 12 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.4004, Penalty: 738828302.9787
# Epoch 13 - Task B performance during Task B (with EWC): 0.8200
# Epoch 13 - Task B performance during Task B - validation set (with EWC): 0.8367
# Epoch 13 - Task A performance during Task B (with EWC): 0.9233
# Epoch 13 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3910, Penalty: 738856332.9362
# Epoch 14 - Task B performance during Task B (with EWC): 0.8247
# Epoch 14 - Task B performance during Task B - validation set (with EWC): 0.8430
# Epoch 14 - Task A performance during Task B (with EWC): 0.9233
# Epoch 14 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3825, Penalty: 738881478.4681
# Epoch 15 - Task B performance during Task B (with EWC): 0.8300
# Epoch 15 - Task B performance during Task B - validation set (with EWC): 0.8480
# Epoch 15 - Task A performance during Task B (with EWC): 0.9233
# Epoch 15 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3749, Penalty: 738924445.6170
# Epoch 16 - Task B performance during Task B (with EWC): 0.8380
# Epoch 16 - Task B performance during Task B - validation set (with EWC): 0.8540
# Epoch 16 - Task A performance during Task B (with EWC): 0.9233
# Epoch 16 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3685, Penalty: 738953059.7447
# Epoch 17 - Task B performance during Task B (with EWC): 0.8427
# Epoch 17 - Task B performance during Task B - validation set (with EWC): 0.8580
# Epoch 17 - Task A performance during Task B (with EWC): 0.9233
# Epoch 17 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3627, Penalty: 738974862.6383
# Epoch 18 - Task B performance during Task B (with EWC): 0.8487
# Epoch 18 - Task B performance during Task B - validation set (with EWC): 0.8617
# Epoch 18 - Task A performance during Task B (with EWC): 0.9233
# Epoch 18 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3574, Penalty: 739029986.7234
# Epoch 19 - Task B performance during Task B (with EWC): 0.8513
# Epoch 19 - Task B performance during Task B - validation set (with EWC): 0.8657
# Epoch 19 - Task A performance during Task B (with EWC): 0.9233
# Epoch 19 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3528, Penalty: 739117044.0851
# Epoch 20 - Task B performance during Task B (with EWC): 0.8540
# Epoch 20 - Task B performance during Task B - validation set (with EWC): 0.8690
# Epoch 20 - Task A performance during Task B (with EWC): 0.9233
# Epoch 20 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3480, Penalty: 739165393.3617
# Epoch 21 - Task B performance during Task B (with EWC): 0.8587
# Epoch 21 - Task B performance during Task B - validation set (with EWC): 0.8700
# Epoch 21 - Task A performance during Task B (with EWC): 0.9233
# Epoch 21 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3444, Penalty: 739208469.4468
# Epoch 22 - Task B performance during Task B (with EWC): 0.8600
# Epoch 22 - Task B performance during Task B - validation set (with EWC): 0.8710
# Epoch 22 - Task A performance during Task B (with EWC): 0.9233
# Epoch 22 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3405, Penalty: 739293162.2128
# Epoch 23 - Task B performance during Task B (with EWC): 0.8620
# Epoch 23 - Task B performance during Task B - validation set (with EWC): 0.8717
# Epoch 23 - Task A performance during Task B (with EWC): 0.9233
# Epoch 23 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3371, Penalty: 739370316.2553
# Epoch 24 - Task B performance during Task B (with EWC): 0.8647
# Epoch 24 - Task B performance during Task B - validation set (with EWC): 0.8737
# Epoch 24 - Task A performance during Task B (with EWC): 0.9233
# Epoch 24 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3335, Penalty: 739392323.0638
# Epoch 25 - Task B performance during Task B (with EWC): 0.8667
# Epoch 25 - Task B performance during Task B - validation set (with EWC): 0.8737
# Epoch 25 - Task A performance during Task B (with EWC): 0.9233
# Epoch 25 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3307, Penalty: 739416521.5319
# Epoch 26 - Task B performance during Task B (with EWC): 0.8660
# Epoch 26 - Task B performance during Task B - validation set (with EWC): 0.8750
# Epoch 26 - Task A performance during Task B (with EWC): 0.9233
# Epoch 26 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3287, Penalty: 739431848.1702
# Epoch 27 - Task B performance during Task B (with EWC): 0.8673
# Epoch 27 - Task B performance during Task B - validation set (with EWC): 0.8763
# Epoch 27 - Task A performance during Task B (with EWC): 0.9233
# Epoch 27 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3255, Penalty: 739452257.7021
# Epoch 28 - Task B performance during Task B (with EWC): 0.8693
# Epoch 28 - Task B performance during Task B - validation set (with EWC): 0.8760
# Epoch 28 - Task A performance during Task B (with EWC): 0.9233
# Epoch 28 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3226, Penalty: 739479743.6596
# Epoch 29 - Task B performance during Task B (with EWC): 0.8707
# Epoch 29 - Task B performance during Task B - validation set (with EWC): 0.8770
# Epoch 29 - Task A performance during Task B (with EWC): 0.9233
# Epoch 29 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3201, Penalty: 739493775.3191
# Epoch 30 - Task B performance during Task B (with EWC): 0.8707
# Epoch 30 - Task B performance during Task B - validation set (with EWC): 0.8797
# Epoch 30 - Task A performance during Task B (with EWC): 0.9233
# Epoch 30 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3179, Penalty: 739511078.4681
# Epoch 31 - Task B performance during Task B (with EWC): 0.8707
# Epoch 31 - Task B performance during Task B - validation set (with EWC): 0.8793
# Epoch 31 - Task A performance during Task B (with EWC): 0.9233
# Epoch 31 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3156, Penalty: 739547409.0213
# Epoch 32 - Task B performance during Task B (with EWC): 0.8733
# Epoch 32 - Task B performance during Task B - validation set (with EWC): 0.8817
# Epoch 32 - Task A performance during Task B (with EWC): 0.9233
# Epoch 32 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3135, Penalty: 739566455.4894
# Epoch 33 - Task B performance during Task B (with EWC): 0.8753
# Epoch 33 - Task B performance during Task B - validation set (with EWC): 0.8823
# Epoch 33 - Task A performance during Task B (with EWC): 0.9233
# Epoch 33 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3116, Penalty: 739594536.1702
# Epoch 34 - Task B performance during Task B (with EWC): 0.8760
# Epoch 34 - Task B performance during Task B - validation set (with EWC): 0.8827
# Epoch 34 - Task A performance during Task B (with EWC): 0.9233
# Epoch 34 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3093, Penalty: 739610205.9574
# Epoch 35 - Task B performance during Task B (with EWC): 0.8793
# Epoch 35 - Task B performance during Task B - validation set (with EWC): 0.8840
# Epoch 35 - Task A performance during Task B (with EWC): 0.9233
# Epoch 35 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3077, Penalty: 739621781.7872
# Epoch 36 - Task B performance during Task B (with EWC): 0.8787
# Epoch 36 - Task B performance during Task B - validation set (with EWC): 0.8867
# Epoch 36 - Task A performance during Task B (with EWC): 0.9233
# Epoch 36 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3059, Penalty: 739636996.7660
# Epoch 37 - Task B performance during Task B (with EWC): 0.8787
# Epoch 37 - Task B performance during Task B - validation set (with EWC): 0.8877
# Epoch 37 - Task A performance during Task B (with EWC): 0.9233
# Epoch 37 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3043, Penalty: 739651056.6809
# Epoch 38 - Task B performance during Task B (with EWC): 0.8793
# Epoch 38 - Task B performance during Task B - validation set (with EWC): 0.8887
# Epoch 38 - Task A performance during Task B (with EWC): 0.9233
# Epoch 38 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3027, Penalty: 739723461.1064
# Epoch 39 - Task B performance during Task B (with EWC): 0.8807
# Epoch 39 - Task B performance during Task B - validation set (with EWC): 0.8877
# Epoch 39 - Task A performance during Task B (with EWC): 0.9233
# Epoch 39 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.3011, Penalty: 739779240.5106
# Epoch 40 - Task B performance during Task B (with EWC): 0.8793
# Epoch 40 - Task B performance during Task B - validation set (with EWC): 0.8887
# Epoch 40 - Task A performance during Task B (with EWC): 0.9233
# Epoch 40 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.2997, Penalty: 739808922.2128
# Epoch 41 - Task B performance during Task B (with EWC): 0.8820
# Epoch 41 - Task B performance during Task B - validation set (with EWC): 0.8880
# Epoch 41 - Task A performance during Task B (with EWC): 0.9233
# Epoch 41 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.2987, Penalty: 739822952.5106
# Epoch 42 - Task B performance during Task B (with EWC): 0.8827
# Epoch 42 - Task B performance during Task B - validation set (with EWC): 0.8887
# Epoch 42 - Task A performance during Task B (with EWC): 0.9233
# Epoch 42 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.2966, Penalty: 739839690.2128
# Epoch 43 - Task B performance during Task B (with EWC): 0.8833
# Epoch 43 - Task B performance during Task B - validation set (with EWC): 0.8897
# Epoch 43 - Task A performance during Task B (with EWC): 0.9233
# Epoch 43 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.2952, Penalty: 739872053.1064
# Epoch 44 - Task B performance during Task B (with EWC): 0.8833
# Epoch 44 - Task B performance during Task B - validation set (with EWC): 0.8903
# Epoch 44 - Task A performance during Task B (with EWC): 0.9233
# Epoch 44 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.2940, Penalty: 739889464.1702
# Epoch 45 - Task B performance during Task B (with EWC): 0.8853
# Epoch 45 - Task B performance during Task B - validation set (with EWC): 0.8907
# Epoch 45 - Task A performance during Task B (with EWC): 0.9233
# Epoch 45 - Task A performance during Task B - validation set (with EWC): 0.9043
# Epoch 1/1, Loss: 0.2929, Penalty: 739919830.4681
# Epoch 46 - Task B performance during Task B (with EWC): 0.8853
# Epoch 46 - Task B performance during Task B - validation set (with EWC): 0.8910
# Epoch 46 - Task A performance during Task B (with EWC): 0.9233
# Epoch 46 - Task A performance during Task B - validation set (with EWC): 0.9047
# Epoch 1/1, Loss: 0.2913, Penalty: 739946284.2553
# Epoch 47 - Task B performance during Task B (with EWC): 0.8867
# Epoch 47 - Task B performance during Task B - validation set (with EWC): 0.8927
# Epoch 47 - Task A performance during Task B (with EWC): 0.9233
# Epoch 47 - Task A performance during Task B - validation set (with EWC): 0.9047
# Epoch 1/1, Loss: 0.2901, Penalty: 739955066.8936
# Epoch 48 - Task B performance during Task B (with EWC): 0.8880
# Epoch 48 - Task B performance during Task B - validation set (with EWC): 0.8923
# Epoch 48 - Task A performance during Task B (with EWC): 0.9233
# Epoch 48 - Task A performance during Task B - validation set (with EWC): 0.9047
# Epoch 1/1, Loss: 0.2894, Penalty: 739977630.2979
# Epoch 49 - Task B performance during Task B (with EWC): 0.8880
# Epoch 49 - Task B performance during Task B - validation set (with EWC): 0.8933
# Epoch 49 - Task A performance during Task B (with EWC): 0.9233
# Epoch 49 - Task A performance during Task B - validation set (with EWC): 0.9047
# Epoch 1/1, Loss: 0.2881, Penalty: 740007183.6596
# Epoch 50 - Task B performance during Task B (with EWC): 0.8887
# Epoch 50 - Task B performance during Task B - validation set (with EWC): 0.8937
# Epoch 50 - Task A performance during Task B (with EWC): 0.9233
# Epoch 50 - Task A performance during Task B - validation set (with EWC): 0.9047
# Task B with EWC: Accuracy: 0.8886666666666667, Precision: 0.889098998887653, Recall: 0.8886666666666667, Cohen's Kappa: 0.7773333333333333
# Task A after Task B with EWC: Accuracy: 0.8937, Precision: 0.8938, Recall: 0.8937, Kappa: 0.7874
# Task A - Final with EWC: Accuracy: 0.9233333333333333, Precision: 0.9292382147114772, Recall: 0.9233333333333333, Cohen's Kappa: 0.9148148148148149
# Task A after Task B with EWC: Accuracy: 0.9047, Precision: 0.9123, Recall: 0.9047, Cohen's Kappa: 0.8940
# Run 2/10
# Task A - Untrained: Accuracy: 0.12333333333333334, Precision: 0.028877250409165302, Recall: 0.12333333333333334, Kappa: 0.025925925925925908
# Epoch 1/1, Loss: 1.9522
# Epoch 1 - Task A performance during Task A (with EWC): 0.7753
# Epoch 1 - Task A performance during Task A - validation set (with EWC): 0.7427
# Epoch 1 - Task B performance during Task A (with EWC): 0.3973
# Epoch 1 - Task B performance during Task A - validation set (with EWC): 0.4053
# Epoch 1/1, Loss: 1.0179
# Epoch 2 - Task A performance during Task A (with EWC): 0.8507
# Epoch 2 - Task A performance during Task A - validation set (with EWC): 0.8387
# Epoch 2 - Task B performance during Task A (with EWC): 0.4187
# Epoch 2 - Task B performance during Task A - validation set (with EWC): 0.4297
# Epoch 1/1, Loss: 0.5909
# Epoch 3 - Task A performance during Task A (with EWC): 0.8913
# Epoch 3 - Task A performance during Task A - validation set (with EWC): 0.8687
# Epoch 3 - Task B performance during Task A (with EWC): 0.4227
# Epoch 3 - Task B performance during Task A - validation set (with EWC): 0.4347
# Epoch 1/1, Loss: 0.4495
# Epoch 4 - Task A performance during Task A (with EWC): 0.9033
# Epoch 4 - Task A performance during Task A - validation set (with EWC): 0.8797
# Epoch 4 - Task B performance during Task A (with EWC): 0.4400
# Epoch 4 - Task B performance during Task A - validation set (with EWC): 0.4477
# Epoch 1/1, Loss: 0.3859
# Epoch 5 - Task A performance during Task A (with EWC): 0.9107
# Epoch 5 - Task A performance during Task A - validation set (with EWC): 0.8897
# Epoch 5 - Task B performance during Task A (with EWC): 0.4387
# Epoch 5 - Task B performance during Task A - validation set (with EWC): 0.4470
# Epoch 1/1, Loss: 0.3473
# Epoch 6 - Task A performance during Task A (with EWC): 0.9127
# Epoch 6 - Task A performance during Task A - validation set (with EWC): 0.8953
# Epoch 6 - Task B performance during Task A (with EWC): 0.4247
# Epoch 6 - Task B performance during Task A - validation set (with EWC): 0.4403
# Epoch 1/1, Loss: 0.3208
# Epoch 7 - Task A performance during Task A (with EWC): 0.9187
# Epoch 7 - Task A performance during Task A - validation set (with EWC): 0.9003
# Epoch 7 - Task B performance during Task A (with EWC): 0.4260
# Epoch 7 - Task B performance during Task A - validation set (with EWC): 0.4400
# Epoch 1/1, Loss: 0.3026
# Epoch 8 - Task A performance during Task A (with EWC): 0.9153
# Epoch 8 - Task A performance during Task A - validation set (with EWC): 0.9027
# Epoch 8 - Task B performance during Task A (with EWC): 0.4480
# Epoch 8 - Task B performance during Task A - validation set (with EWC): 0.4570
# Epoch 1/1, Loss: 0.2865
# Epoch 9 - Task A performance during Task A (with EWC): 0.9247
# Epoch 9 - Task A performance during Task A - validation set (with EWC): 0.9077
# Epoch 9 - Task B performance during Task A (with EWC): 0.4500
# Epoch 9 - Task B performance during Task A - validation set (with EWC): 0.4527
# Epoch 1/1, Loss: 0.2751
# Epoch 10 - Task A performance during Task A (with EWC): 0.9267
# Epoch 10 - Task A performance during Task A - validation set (with EWC): 0.9100
# Epoch 10 - Task B performance during Task A (with EWC): 0.4440
# Epoch 10 - Task B performance during Task A - validation set (with EWC): 0.4503
# Epoch 1/1, Loss: 0.2628
# Epoch 11 - Task A performance during Task A (with EWC): 0.9273
# Epoch 11 - Task A performance during Task A - validation set (with EWC): 0.9153
# Epoch 11 - Task B performance during Task A (with EWC): 0.4547
# Epoch 11 - Task B performance during Task A - validation set (with EWC): 0.4587
# Epoch 1/1, Loss: 0.2530
# Epoch 12 - Task A performance during Task A (with EWC): 0.9307
# Epoch 12 - Task A performance during Task A - validation set (with EWC): 0.9183
# Epoch 12 - Task B performance during Task A (with EWC): 0.4587
# Epoch 12 - Task B performance during Task A - validation set (with EWC): 0.4627
# Epoch 1/1, Loss: 0.2438
# Epoch 13 - Task A performance during Task A (with EWC): 0.9347
# Epoch 13 - Task A performance during Task A - validation set (with EWC): 0.9203
# Epoch 13 - Task B performance during Task A (with EWC): 0.4613
# Epoch 13 - Task B performance during Task A - validation set (with EWC): 0.4660
# Epoch 1/1, Loss: 0.2355
# Epoch 14 - Task A performance during Task A (with EWC): 0.9347
# Epoch 14 - Task A performance during Task A - validation set (with EWC): 0.9243
# Epoch 14 - Task B performance during Task A (with EWC): 0.4640
# Epoch 14 - Task B performance during Task A - validation set (with EWC): 0.4667
# Epoch 1/1, Loss: 0.2265
# Epoch 15 - Task A performance during Task A (with EWC): 0.9353
# Epoch 15 - Task A performance during Task A - validation set (with EWC): 0.9237
# Epoch 15 - Task B performance during Task A (with EWC): 0.4693
# Epoch 15 - Task B performance during Task A - validation set (with EWC): 0.4777
# Epoch 1/1, Loss: 0.2191
# Epoch 16 - Task A performance during Task A (with EWC): 0.9353
# Epoch 16 - Task A performance during Task A - validation set (with EWC): 0.9240
# Epoch 16 - Task B performance during Task A (with EWC): 0.4747
# Epoch 16 - Task B performance during Task A - validation set (with EWC): 0.4800
# Epoch 1/1, Loss: 0.2117
# Epoch 17 - Task A performance during Task A (with EWC): 0.9367
# Epoch 17 - Task A performance during Task A - validation set (with EWC): 0.9290
# Epoch 17 - Task B performance during Task A (with EWC): 0.4787
# Epoch 17 - Task B performance during Task A - validation set (with EWC): 0.4830
# Epoch 1/1, Loss: 0.2041
# Epoch 18 - Task A performance during Task A (with EWC): 0.9420
# Epoch 18 - Task A performance during Task A - validation set (with EWC): 0.9280
# Epoch 18 - Task B performance during Task A (with EWC): 0.4740
# Epoch 18 - Task B performance during Task A - validation set (with EWC): 0.4813
# Epoch 1/1, Loss: 0.1976
# Epoch 19 - Task A performance during Task A (with EWC): 0.9447
# Epoch 19 - Task A performance during Task A - validation set (with EWC): 0.9303
# Epoch 19 - Task B performance during Task A (with EWC): 0.4733
# Epoch 19 - Task B performance during Task A - validation set (with EWC): 0.4810
# Epoch 1/1, Loss: 0.1913
# Epoch 20 - Task A performance during Task A (with EWC): 0.9440
# Epoch 20 - Task A performance during Task A - validation set (with EWC): 0.9327
# Epoch 20 - Task B performance during Task A (with EWC): 0.4713
# Epoch 20 - Task B performance during Task A - validation set (with EWC): 0.4767
# Epoch 1/1, Loss: 0.1860
# Epoch 21 - Task A performance during Task A (with EWC): 0.9487
# Epoch 21 - Task A performance during Task A - validation set (with EWC): 0.9310
# Epoch 21 - Task B performance during Task A (with EWC): 0.4753
# Epoch 21 - Task B performance during Task A - validation set (with EWC): 0.4807
# Epoch 1/1, Loss: 0.1796
# Epoch 22 - Task A performance during Task A (with EWC): 0.9440
# Epoch 22 - Task A performance during Task A - validation set (with EWC): 0.9317
# Epoch 22 - Task B performance during Task A (with EWC): 0.4673
# Epoch 22 - Task B performance during Task A - validation set (with EWC): 0.4697
# Epoch 1/1, Loss: 0.1733
# Epoch 23 - Task A performance during Task A (with EWC): 0.9487
# Epoch 23 - Task A performance during Task A - validation set (with EWC): 0.9350
# Epoch 23 - Task B performance during Task A (with EWC): 0.4760
# Epoch 23 - Task B performance during Task A - validation set (with EWC): 0.4777
# Epoch 1/1, Loss: 0.1691
# Epoch 24 - Task A performance during Task A (with EWC): 0.9500
# Epoch 24 - Task A performance during Task A - validation set (with EWC): 0.9337
# Epoch 24 - Task B performance during Task A (with EWC): 0.4687
# Epoch 24 - Task B performance during Task A - validation set (with EWC): 0.4703
# Epoch 1/1, Loss: 0.1630
# Epoch 25 - Task A performance during Task A (with EWC): 0.9527
# Epoch 25 - Task A performance during Task A - validation set (with EWC): 0.9370
# Epoch 25 - Task B performance during Task A (with EWC): 0.4727
# Epoch 25 - Task B performance during Task A - validation set (with EWC): 0.4753
# Task A - Initial: Accuracy: 0.9526666666666667, Precision: 0.9531780555313903, Recall: 0.9526666666666667, Cohen's Kappa: 0.9474074074074074
# Task A - Initial: Accuracy: 0.9370, Precision: 0.9372, Recall: 0.9370, Cohen's Kappa: 0.9300
# Epoch 1/1, Loss: 0.8842, Penalty: 427427638.1582
# Epoch 1 - Task B performance during Task B (with EWC): 0.7007
# Epoch 1 - Task B performance during Task B - validation set (with EWC): 0.7037
# Epoch 1 - Task A performance during Task B (with EWC): 0.9367
# Epoch 1 - Task A performance during Task B - validation set (with EWC): 0.9230
# Epoch 1/1, Loss: 0.6372, Penalty: 469195334.2979
# Epoch 2 - Task B performance during Task B (with EWC): 0.7400
# Epoch 2 - Task B performance during Task B - validation set (with EWC): 0.7440
# Epoch 2 - Task A performance during Task B (with EWC): 0.9367
# Epoch 2 - Task A performance during Task B - validation set (with EWC): 0.9230
# Epoch 1/1, Loss: 0.5742, Penalty: 469471329.3617
# Epoch 3 - Task B performance during Task B (with EWC): 0.7613
# Epoch 3 - Task B performance during Task B - validation set (with EWC): 0.7733
# Epoch 3 - Task A performance during Task B (with EWC): 0.9367
# Epoch 3 - Task A performance during Task B - validation set (with EWC): 0.9230
# Epoch 1/1, Loss: 0.5327, Penalty: 469606712.5106
# Epoch 4 - Task B performance during Task B (with EWC): 0.7760
# Epoch 4 - Task B performance during Task B - validation set (with EWC): 0.7923
# Epoch 4 - Task A performance during Task B (with EWC): 0.9367
# Epoch 4 - Task A performance during Task B - validation set (with EWC): 0.9230
# Epoch 1/1, Loss: 0.5024, Penalty: 469713161.0213
# Epoch 5 - Task B performance during Task B (with EWC): 0.7827
# Epoch 5 - Task B performance during Task B - validation set (with EWC): 0.8050
# Epoch 5 - Task A performance during Task B (with EWC): 0.9367
# Epoch 5 - Task A performance during Task B - validation set (with EWC): 0.9230
# Epoch 1/1, Loss: 0.4782, Penalty: 469801779.2340
# Epoch 6 - Task B performance during Task B (with EWC): 0.7980
# Epoch 6 - Task B performance during Task B - validation set (with EWC): 0.8133
# Epoch 6 - Task A performance during Task B (with EWC): 0.9367
# Epoch 6 - Task A performance during Task B - validation set (with EWC): 0.9230
# Epoch 1/1, Loss: 0.4593, Penalty: 469865922.8936
# Epoch 7 - Task B performance during Task B (with EWC): 0.8033
# Epoch 7 - Task B performance during Task B - validation set (with EWC): 0.8217
# Epoch 7 - Task A performance during Task B (with EWC): 0.9367
# Epoch 7 - Task A performance during Task B - validation set (with EWC): 0.9230
# Epoch 1/1, Loss: 0.4423, Penalty: 469923896.6809
# Epoch 8 - Task B performance during Task B (with EWC): 0.8127
# Epoch 8 - Task B performance during Task B - validation set (with EWC): 0.8287
# Epoch 8 - Task A performance during Task B (with EWC): 0.9367
# Epoch 8 - Task A performance during Task B - validation set (with EWC): 0.9230
# Epoch 1/1, Loss: 0.4289, Penalty: 469964264.5106
# Epoch 9 - Task B performance during Task B (with EWC): 0.8167
# Epoch 9 - Task B performance during Task B - validation set (with EWC): 0.8327
# Epoch 9 - Task A performance during Task B (with EWC): 0.9367
# Epoch 9 - Task A performance during Task B - validation set (with EWC): 0.9230
# Epoch 1/1, Loss: 0.4167, Penalty: 470048303.8298
# Epoch 10 - Task B performance during Task B (with EWC): 0.8227
# Epoch 10 - Task B performance during Task B - validation set (with EWC): 0.8373
# Epoch 10 - Task A performance during Task B (with EWC): 0.9367
# Epoch 10 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.4061, Penalty: 470121424.1702
# Epoch 11 - Task B performance during Task B (with EWC): 0.8293
# Epoch 11 - Task B performance during Task B - validation set (with EWC): 0.8427
# Epoch 11 - Task A performance during Task B (with EWC): 0.9367
# Epoch 11 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3971, Penalty: 470161038.1277
# Epoch 12 - Task B performance during Task B (with EWC): 0.8367
# Epoch 12 - Task B performance during Task B - validation set (with EWC): 0.8470
# Epoch 12 - Task A performance during Task B (with EWC): 0.9367
# Epoch 12 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3886, Penalty: 470194473.5319
# Epoch 13 - Task B performance during Task B (with EWC): 0.8373
# Epoch 13 - Task B performance during Task B - validation set (with EWC): 0.8480
# Epoch 13 - Task A performance during Task B (with EWC): 0.9367
# Epoch 13 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3805, Penalty: 470222347.2340
# Epoch 14 - Task B performance during Task B (with EWC): 0.8433
# Epoch 14 - Task B performance during Task B - validation set (with EWC): 0.8550
# Epoch 14 - Task A performance during Task B (with EWC): 0.9367
# Epoch 14 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3736, Penalty: 470255098.8936
# Epoch 15 - Task B performance during Task B (with EWC): 0.8453
# Epoch 15 - Task B performance during Task B - validation set (with EWC): 0.8580
# Epoch 15 - Task A performance during Task B (with EWC): 0.9367
# Epoch 15 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3671, Penalty: 470289575.8298
# Epoch 16 - Task B performance during Task B (with EWC): 0.8473
# Epoch 16 - Task B performance during Task B - validation set (with EWC): 0.8613
# Epoch 16 - Task A performance during Task B (with EWC): 0.9367
# Epoch 16 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3610, Penalty: 470319398.1277
# Epoch 17 - Task B performance during Task B (with EWC): 0.8487
# Epoch 17 - Task B performance during Task B - validation set (with EWC): 0.8633
# Epoch 17 - Task A performance during Task B (with EWC): 0.9367
# Epoch 17 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3550, Penalty: 470358085.9574
# Epoch 18 - Task B performance during Task B (with EWC): 0.8527
# Epoch 18 - Task B performance during Task B - validation set (with EWC): 0.8643
# Epoch 18 - Task A performance during Task B (with EWC): 0.9367
# Epoch 18 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3503, Penalty: 470424720.5106
# Epoch 19 - Task B performance during Task B (with EWC): 0.8540
# Epoch 19 - Task B performance during Task B - validation set (with EWC): 0.8660
# Epoch 19 - Task A performance during Task B (with EWC): 0.9367
# Epoch 19 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3448, Penalty: 470502282.3830
# Epoch 20 - Task B performance during Task B (with EWC): 0.8573
# Epoch 20 - Task B performance during Task B - validation set (with EWC): 0.8693
# Epoch 20 - Task A performance during Task B (with EWC): 0.9360
# Epoch 20 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3402, Penalty: 470546392.8511
# Epoch 21 - Task B performance during Task B (with EWC): 0.8607
# Epoch 21 - Task B performance during Task B - validation set (with EWC): 0.8713
# Epoch 21 - Task A performance during Task B (with EWC): 0.9360
# Epoch 21 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3355, Penalty: 470578026.8936
# Epoch 22 - Task B performance during Task B (with EWC): 0.8627
# Epoch 22 - Task B performance during Task B - validation set (with EWC): 0.8740
# Epoch 22 - Task A performance during Task B (with EWC): 0.9360
# Epoch 22 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3314, Penalty: 470616979.4043
# Epoch 23 - Task B performance during Task B (with EWC): 0.8653
# Epoch 23 - Task B performance during Task B - validation set (with EWC): 0.8757
# Epoch 23 - Task A performance during Task B (with EWC): 0.9360
# Epoch 23 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3278, Penalty: 470653766.8085
# Epoch 24 - Task B performance during Task B (with EWC): 0.8687
# Epoch 24 - Task B performance during Task B - validation set (with EWC): 0.8773
# Epoch 24 - Task A performance during Task B (with EWC): 0.9360
# Epoch 24 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3237, Penalty: 470687777.5319
# Epoch 25 - Task B performance during Task B (with EWC): 0.8687
# Epoch 25 - Task B performance during Task B - validation set (with EWC): 0.8767
# Epoch 25 - Task A performance during Task B (with EWC): 0.9360
# Epoch 25 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3204, Penalty: 470729767.8298
# Epoch 26 - Task B performance during Task B (with EWC): 0.8700
# Epoch 26 - Task B performance during Task B - validation set (with EWC): 0.8807
# Epoch 26 - Task A performance during Task B (with EWC): 0.9360
# Epoch 26 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3170, Penalty: 470777848.8511
# Epoch 27 - Task B performance during Task B (with EWC): 0.8720
# Epoch 27 - Task B performance during Task B - validation set (with EWC): 0.8830
# Epoch 27 - Task A performance during Task B (with EWC): 0.9360
# Epoch 27 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3134, Penalty: 470831764.2553
# Epoch 28 - Task B performance during Task B (with EWC): 0.8733
# Epoch 28 - Task B performance during Task B - validation set (with EWC): 0.8833
# Epoch 28 - Task A performance during Task B (with EWC): 0.9367
# Epoch 28 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3105, Penalty: 470880579.0638
# Epoch 29 - Task B performance during Task B (with EWC): 0.8740
# Epoch 29 - Task B performance during Task B - validation set (with EWC): 0.8857
# Epoch 29 - Task A performance during Task B (with EWC): 0.9360
# Epoch 29 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3074, Penalty: 470919100.5957
# Epoch 30 - Task B performance during Task B (with EWC): 0.8753
# Epoch 30 - Task B performance during Task B - validation set (with EWC): 0.8880
# Epoch 30 - Task A performance during Task B (with EWC): 0.9360
# Epoch 30 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3049, Penalty: 470965955.9149
# Epoch 31 - Task B performance during Task B (with EWC): 0.8760
# Epoch 31 - Task B performance during Task B - validation set (with EWC): 0.8887
# Epoch 31 - Task A performance during Task B (with EWC): 0.9360
# Epoch 31 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.3020, Penalty: 471016083.7447
# Epoch 32 - Task B performance during Task B (with EWC): 0.8767
# Epoch 32 - Task B performance during Task B - validation set (with EWC): 0.8897
# Epoch 32 - Task A performance during Task B (with EWC): 0.9360
# Epoch 32 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.2992, Penalty: 471062916.7660
# Epoch 33 - Task B performance during Task B (with EWC): 0.8787
# Epoch 33 - Task B performance during Task B - validation set (with EWC): 0.8913
# Epoch 33 - Task A performance during Task B (with EWC): 0.9360
# Epoch 33 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.2973, Penalty: 471109198.8085
# Epoch 34 - Task B performance during Task B (with EWC): 0.8800
# Epoch 34 - Task B performance during Task B - validation set (with EWC): 0.8917
# Epoch 34 - Task A performance during Task B (with EWC): 0.9360
# Epoch 34 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.2944, Penalty: 471202816.0000
# Epoch 35 - Task B performance during Task B (with EWC): 0.8807
# Epoch 35 - Task B performance during Task B - validation set (with EWC): 0.8917
# Epoch 35 - Task A performance during Task B (with EWC): 0.9360
# Epoch 35 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.2921, Penalty: 471278572.5957
# Epoch 36 - Task B performance during Task B (with EWC): 0.8820
# Epoch 36 - Task B performance during Task B - validation set (with EWC): 0.8950
# Epoch 36 - Task A performance during Task B (with EWC): 0.9367
# Epoch 36 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.2896, Penalty: 471364958.6383
# Epoch 37 - Task B performance during Task B (with EWC): 0.8813
# Epoch 37 - Task B performance during Task B - validation set (with EWC): 0.8943
# Epoch 37 - Task A performance during Task B (with EWC): 0.9367
# Epoch 37 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.2877, Penalty: 471405553.0213
# Epoch 38 - Task B performance during Task B (with EWC): 0.8833
# Epoch 38 - Task B performance during Task B - validation set (with EWC): 0.8967
# Epoch 38 - Task A performance during Task B (with EWC): 0.9360
# Epoch 38 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.2854, Penalty: 471453943.3191
# Epoch 39 - Task B performance during Task B (with EWC): 0.8853
# Epoch 39 - Task B performance during Task B - validation set (with EWC): 0.8973
# Epoch 39 - Task A performance during Task B (with EWC): 0.9360
# Epoch 39 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.2843, Penalty: 471493181.1064
# Epoch 40 - Task B performance during Task B (with EWC): 0.8860
# Epoch 40 - Task B performance during Task B - validation set (with EWC): 0.8983
# Epoch 40 - Task A performance during Task B (with EWC): 0.9360
# Epoch 40 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.2817, Penalty: 471576199.8298
# Epoch 41 - Task B performance during Task B (with EWC): 0.8853
# Epoch 41 - Task B performance during Task B - validation set (with EWC): 0.8993
# Epoch 41 - Task A performance during Task B (with EWC): 0.9360
# Epoch 41 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.2797, Penalty: 471635835.7447
# Epoch 42 - Task B performance during Task B (with EWC): 0.8893
# Epoch 42 - Task B performance during Task B - validation set (with EWC): 0.9000
# Epoch 42 - Task A performance during Task B (with EWC): 0.9360
# Epoch 42 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.2779, Penalty: 471681535.8298
# Epoch 43 - Task B performance during Task B (with EWC): 0.8900
# Epoch 43 - Task B performance during Task B - validation set (with EWC): 0.9010
# Epoch 43 - Task A performance during Task B (with EWC): 0.9360
# Epoch 43 - Task A performance during Task B - validation set (with EWC): 0.9227
# Epoch 1/1, Loss: 0.2759, Penalty: 471721872.1702
# Epoch 44 - Task B performance during Task B (with EWC): 0.8900
# Epoch 44 - Task B performance during Task B - validation set (with EWC): 0.9023
# ...
# Epoch 4 - Task A performance during Task B - validation set (with EWC): 0.9127
# Epoch 1/1, Loss: 0.4706, Penalty: 506971330.8936
# Epoch 5 - Task B performance during Task B (with EWC): 0.7760
# Epoch 5 - Task B performance during Task B - validation set (with EWC): 0.7883
# Epoch 5 - Task A performance during Task B (with EWC): 0.9273
# Epoch 5 - Task A performance during Task B - validation set (with EWC): 0.9127
# Epoch 1/1, Loss: 0.4535, Penalty: 506987559.8298
# Epoch 6 - Task B performance during Task B (with EWC): 0.7887
# Epoch 6 - Task B performance during Task B - validation set (with EWC): 0.8010
# Epoch 6 - Task A performance during Task B (with EWC): 0.9273
# Epoch 6 - Task A performance during Task B - validation set (with EWC): 0.9127
# Epoch 1/1, Loss: 0.4384, Penalty: 507004962.0426
# Epoch 7 - Task B performance during Task B (with EWC): 0.7960
# Epoch 7 - Task B performance during Task B - validation set (with EWC): 0.8133
# Epoch 7 - Task A performance during Task B (with EWC): 0.9273
# Epoch 7 - Task A performance during Task B - validation set (with EWC): 0.9127
# Epoch 1/1, Loss: 0.4272, Penalty: 507024615.8298
# Epoch 8 - Task B performance during Task B (with EWC): 0.8020
# Epoch 8 - Task B performance during Task B - validation set (with EWC): 0.8223
# Epoch 8 - Task A performance during Task B (with EWC): 0.9273
# Epoch 8 - Task A performance during Task B - validation set (with EWC): 0.9127
# Epoch 1/1, Loss: 0.4172, Penalty: 507040643.5745
# Epoch 9 - Task B performance during Task B (with EWC): 0.8087
# Epoch 9 - Task B performance during Task B - validation set (with EWC): 0.8277
# Epoch 9 - Task A performance during Task B (with EWC): 0.9273
# Epoch 9 - Task A performance during Task B - validation set (with EWC): 0.9127
# Epoch 1/1, Loss: 0.4082, Penalty: 507049251.7447
# Epoch 10 - Task B performance during Task B (with EWC): 0.8173
# Epoch 10 - Task B performance during Task B - validation set (with EWC): 0.8343
# Epoch 10 - Task A performance during Task B (with EWC): 0.9273
# Epoch 10 - Task A performance during Task B - validation set (with EWC): 0.9127
# Epoch 1/1, Loss: 0.4003, Penalty: 507077251.4043
# Epoch 11 - Task B performance during Task B (with EWC): 0.8247
# Epoch 11 - Task B performance during Task B - validation set (with EWC): 0.8390
# Epoch 11 - Task A performance during Task B (with EWC): 0.9273
# Epoch 11 - Task A performance during Task B - validation set (with EWC): 0.9127
# Epoch 1/1, Loss: 0.3931, Penalty: 507088442.7234
# Epoch 12 - Task B performance during Task B (with EWC): 0.8267
# Epoch 12 - Task B performance during Task B - validation set (with EWC): 0.8423
# Epoch 12 - Task A performance during Task B (with EWC): 0.9273
# Epoch 12 - Task A performance during Task B - validation set (with EWC): 0.9127
# Epoch 1/1, Loss: 0.3874, Penalty: 507100437.9574
# Epoch 13 - Task B performance during Task B (with EWC): 0.8267
# Epoch 13 - Task B performance during Task B - validation set (with EWC): 0.8453
# Epoch 13 - Task A performance during Task B (with EWC): 0.9273
# Epoch 13 - Task A performance during Task B - validation set (with EWC): 0.9127
# Epoch 1/1, Loss: 0.3815, Penalty: 507113566.1277
# Epoch 14 - Task B performance during Task B (with EWC): 0.8293
# Epoch 14 - Task B performance during Task B - validation set (with EWC): 0.8490
# Epoch 14 - Task A performance during Task B (with EWC): 0.9273
# Epoch 14 - Task A performance during Task B - validation set (with EWC): 0.9127
# Epoch 1/1, Loss: 0.3766, Penalty: 507131893.4468
# Epoch 15 - Task B performance during Task B (with EWC): 0.8313
# Epoch 15 - Task B performance during Task B - validation set (with EWC): 0.8530
# Epoch 15 - Task A performance during Task B (with EWC): 0.9273
# Epoch 15 - Task A performance during Task B - validation set (with EWC): 0.9127
# Epoch 1/1, Loss: 0.3716, Penalty: 507149489.3617
# Epoch 16 - Task B performance during Task B (with EWC): 0.8320
# Epoch 16 - Task B performance during Task B - validation set (with EWC): 0.8553
# Epoch 16 - Task A performance during Task B (with EWC): 0.9273
# Epoch 16 - Task A performance during Task B - validation set (with EWC): 0.9127
# Epoch 1/1, Loss: 0.3675, Penalty: 507157769.3617
# Epoch 17 - Task B performance during Task B (with EWC): 0.8367
# Epoch 17 - Task B performance during Task B - validation set (with EWC): 0.8563
# Epoch 17 - Task A performance during Task B (with EWC): 0.9273
# Epoch 17 - Task A performance during Task B - validation set (with EWC): 0.9127
# Epoch 1/1, Loss: 0.3632, Penalty: 507196259.0638
# Epoch 18 - Task B performance during Task B (with EWC): 0.8387
# Epoch 18 - Task B performance during Task B - validation set (with EWC): 0.8577
# Epoch 18 - Task A performance during Task B (with EWC): 0.9273
# Epoch 18 - Task A performance during Task B - validation set (with EWC): 0.9127
# Epoch 1/1, Loss: 0.3590, Penalty: 507224076.0851
# Epoch 19 - Task B performance during Task B (with EWC): 0.8387
# Epoch 19 - Task B performance during Task B - validation set (with EWC): 0.8600
# Epoch 19 - Task A performance during Task B (with EWC): 0.9273
# Epoch 19 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3560, Penalty: 507244054.2979
# Epoch 20 - Task B performance during Task B (with EWC): 0.8420
# Epoch 20 - Task B performance during Task B - validation set (with EWC): 0.8620
# Epoch 20 - Task A performance during Task B (with EWC): 0.9273
# Epoch 20 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3522, Penalty: 507303779.2340
# Epoch 21 - Task B performance during Task B (with EWC): 0.8440
# Epoch 21 - Task B performance during Task B - validation set (with EWC): 0.8640
# Epoch 21 - Task A performance during Task B (with EWC): 0.9273
# Epoch 21 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3481, Penalty: 507320879.8298
# Epoch 22 - Task B performance during Task B (with EWC): 0.8427
# Epoch 22 - Task B performance during Task B - validation set (with EWC): 0.8670
# Epoch 22 - Task A performance during Task B (with EWC): 0.9273
# Epoch 22 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3453, Penalty: 507346425.1915
# Epoch 23 - Task B performance during Task B (with EWC): 0.8473
# Epoch 23 - Task B performance during Task B - validation set (with EWC): 0.8690
# Epoch 23 - Task A performance during Task B (with EWC): 0.9273
# Epoch 23 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3430, Penalty: 507367918.2979
# Epoch 24 - Task B performance during Task B (with EWC): 0.8473
# Epoch 24 - Task B performance during Task B - validation set (with EWC): 0.8707
# Epoch 24 - Task A performance during Task B (with EWC): 0.9273
# Epoch 24 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3397, Penalty: 507424157.7872
# Epoch 25 - Task B performance during Task B (with EWC): 0.8513
# Epoch 25 - Task B performance during Task B - validation set (with EWC): 0.8723
# Epoch 25 - Task A performance during Task B (with EWC): 0.9273
# Epoch 25 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3369, Penalty: 507445540.5957
# Epoch 26 - Task B performance during Task B (with EWC): 0.8493
# Epoch 26 - Task B performance during Task B - validation set (with EWC): 0.8737
# Epoch 26 - Task A performance during Task B (with EWC): 0.9273
# Epoch 26 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3345, Penalty: 507456898.0426
# Epoch 27 - Task B performance during Task B (with EWC): 0.8533
# Epoch 27 - Task B performance during Task B - validation set (with EWC): 0.8757
# Epoch 27 - Task A performance during Task B (with EWC): 0.9273
# Epoch 27 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3320, Penalty: 507470474.8936
# Epoch 28 - Task B performance during Task B (with EWC): 0.8527
# Epoch 28 - Task B performance during Task B - validation set (with EWC): 0.8763
# Epoch 28 - Task A performance during Task B (with EWC): 0.9273
# Epoch 28 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3297, Penalty: 507497901.2766
# Epoch 29 - Task B performance during Task B (with EWC): 0.8553
# Epoch 29 - Task B performance during Task B - validation set (with EWC): 0.8763
# Epoch 29 - Task A performance during Task B (with EWC): 0.9273
# Epoch 29 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3280, Penalty: 507516741.4468
# Epoch 30 - Task B performance during Task B (with EWC): 0.8587
# Epoch 30 - Task B performance during Task B - validation set (with EWC): 0.8777
# Epoch 30 - Task A performance during Task B (with EWC): 0.9273
# Epoch 30 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3256, Penalty: 507546043.9149
# Epoch 31 - Task B performance during Task B (with EWC): 0.8607
# Epoch 31 - Task B performance during Task B - validation set (with EWC): 0.8780
# Epoch 31 - Task A performance during Task B (with EWC): 0.9273
# Epoch 31 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3239, Penalty: 507591146.2128
# Epoch 32 - Task B performance during Task B (with EWC): 0.8600
# Epoch 32 - Task B performance during Task B - validation set (with EWC): 0.8783
# Epoch 32 - Task A performance during Task B (with EWC): 0.9273
# Epoch 32 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3214, Penalty: 507612334.8085
# Epoch 33 - Task B performance during Task B (with EWC): 0.8613
# Epoch 33 - Task B performance during Task B - validation set (with EWC): 0.8790
# Epoch 33 - Task A performance during Task B (with EWC): 0.9273
# Epoch 33 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3198, Penalty: 507628446.6383
# Epoch 34 - Task B performance during Task B (with EWC): 0.8607
# Epoch 34 - Task B performance during Task B - validation set (with EWC): 0.8787
# Epoch 34 - Task A performance during Task B (with EWC): 0.9273
# Epoch 34 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3181, Penalty: 507646016.8511
# Epoch 35 - Task B performance during Task B (with EWC): 0.8640
# Epoch 35 - Task B performance during Task B - validation set (with EWC): 0.8793
# Epoch 35 - Task A performance during Task B (with EWC): 0.9273
# Epoch 35 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3164, Penalty: 507673909.7872
# Epoch 36 - Task B performance during Task B (with EWC): 0.8640
# Epoch 36 - Task B performance during Task B - validation set (with EWC): 0.8797
# Epoch 36 - Task A performance during Task B (with EWC): 0.9273
# Epoch 36 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3150, Penalty: 507696830.4681
# Epoch 37 - Task B performance during Task B (with EWC): 0.8647
# Epoch 37 - Task B performance during Task B - validation set (with EWC): 0.8813
# Epoch 37 - Task A performance during Task B (with EWC): 0.9273
# Epoch 37 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3134, Penalty: 507724914.2128
# Epoch 38 - Task B performance during Task B (with EWC): 0.8680
# Epoch 38 - Task B performance during Task B - validation set (with EWC): 0.8817
# Epoch 38 - Task A performance during Task B (with EWC): 0.9273
# Epoch 38 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3119, Penalty: 507746981.4468
# Epoch 39 - Task B performance during Task B (with EWC): 0.8680
# Epoch 39 - Task B performance during Task B - validation set (with EWC): 0.8810
# Epoch 39 - Task A performance during Task B (with EWC): 0.9267
# Epoch 39 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3105, Penalty: 507807703.4894
# Epoch 40 - Task B performance during Task B (with EWC): 0.8693
# Epoch 40 - Task B performance during Task B - validation set (with EWC): 0.8823
# Epoch 40 - Task A performance during Task B (with EWC): 0.9267
# Epoch 40 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3090, Penalty: 507834920.3404
# Epoch 41 - Task B performance during Task B (with EWC): 0.8713
# Epoch 41 - Task B performance during Task B - validation set (with EWC): 0.8827
# Epoch 41 - Task A performance during Task B (with EWC): 0.9267
# Epoch 41 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3077, Penalty: 507855067.0638
# Epoch 42 - Task B performance during Task B (with EWC): 0.8713
# Epoch 42 - Task B performance during Task B - validation set (with EWC): 0.8850
# Epoch 42 - Task A performance during Task B (with EWC): 0.9267
# Epoch 42 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3064, Penalty: 507876835.2340
# Epoch 43 - Task B performance during Task B (with EWC): 0.8707
# Epoch 43 - Task B performance during Task B - validation set (with EWC): 0.8853
# Epoch 43 - Task A performance during Task B (with EWC): 0.9267
# Epoch 43 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3052, Penalty: 507906131.2340
# Epoch 44 - Task B performance during Task B (with EWC): 0.8727
# Epoch 44 - Task B performance during Task B - validation set (with EWC): 0.8850
# Epoch 44 - Task A performance during Task B (with EWC): 0.9267
# Epoch 44 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3040, Penalty: 507971720.6809
# Epoch 45 - Task B performance during Task B (with EWC): 0.8727
# Epoch 45 - Task B performance during Task B - validation set (with EWC): 0.8857
# Epoch 45 - Task A performance during Task B (with EWC): 0.9267
# Epoch 45 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3030, Penalty: 508014532.9362
# Epoch 46 - Task B performance during Task B (with EWC): 0.8733
# Epoch 46 - Task B performance during Task B - validation set (with EWC): 0.8860
# Epoch 46 - Task A performance during Task B (with EWC): 0.9267
# Epoch 46 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3016, Penalty: 508057268.5957
# Epoch 47 - Task B performance during Task B (with EWC): 0.8760
# Epoch 47 - Task B performance during Task B - validation set (with EWC): 0.8870
# Epoch 47 - Task A performance during Task B (with EWC): 0.9267
# Epoch 47 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.3011, Penalty: 508079829.9574
# Epoch 48 - Task B performance during Task B (with EWC): 0.8773
# Epoch 48 - Task B performance during Task B - validation set (with EWC): 0.8883
# Epoch 48 - Task A performance during Task B (with EWC): 0.9267
# Epoch 48 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.2995, Penalty: 508093343.6596
# Epoch 49 - Task B performance during Task B (with EWC): 0.8780
# Epoch 49 - Task B performance during Task B - validation set (with EWC): 0.8870
# Epoch 49 - Task A performance during Task B (with EWC): 0.9267
# Epoch 49 - Task A performance during Task B - validation set (with EWC): 0.9123
# Epoch 1/1, Loss: 0.2986, Penalty: 508110856.6809
# Epoch 50 - Task B performance during Task B (with EWC): 0.8793
# Epoch 50 - Task B performance during Task B - validation set (with EWC): 0.8867
# Epoch 50 - Task A performance during Task B (with EWC): 0.9267
# Epoch 50 - Task A performance during Task B - validation set (with EWC): 0.9123
# Task B with EWC: Accuracy: 0.8793333333333333, Precision: 0.8798255872944669, Recall: 0.8793333333333333, Cohen's Kappa: 0.7586666666666666
# Task A after Task B with EWC: Accuracy: 0.8867, Precision: 0.8869, Recall: 0.8867, Kappa: 0.7734
# Task A - Final with EWC: Accuracy: 0.9266666666666666, Precision: 0.9286440591312282, Recall: 0.9266666666666666, Cohen's Kappa: 0.9185185185185185
# Task A after Task B with EWC: Accuracy: 0.9123, Precision: 0.9155, Recall: 0.9123, Cohen's Kappa: 0.9026

# %%
# Reuse Task A weights for initializing Task B models
for i, weights in enumerate(task_a_weights):

    epochs = 50
    num_runs = 1
    for run in range(num_runs):
        print(f"Run {run + 1}/{num_runs}")
        # Initialize the model for Task B without EWC
        modelB = ConvNet(shared_dim=128, output_dim_A=10, output_dim_B=2)
        modelB.load_state_dict(weights)  # Directly load the state dict
    
    
        optimizerB = optim.Adam(modelB.parameters(), lr=learning_rate)
        criterionB = nn.CrossEntropyLoss()

        # Track performance on Task A while training on Task B
        accuracy_taskA_during_B_no_ewc, _, _, _ = evaluate(modelB, test_A_loader, criterion)
        print(f"Epoch {epoch + 1} - Task A performance during Task B (without EWC): {accuracy_taskA_during_B_no_ewc:.4f}")
    
        #acc_A, loss_A = train_with_patience(modelB, train_A_loader, optimizerB, criterionB, epochs=1, patience=20)
    
        for epoch in range(epochs):
            # Train model on Task B without EWC
            acc_B_no_ewc, loss_B_no_ewc = train_with_patience(modelB, train_B_loader, optimizerB, criterion, epochs=1, patience=100)
        
            # Store epoch-wise results for Task B
            #epoch_stats["no_ewc"]["accuracy"].append(acc_B_no_ewc)
            #epoch_stats["no_ewc"]["loss"].append(loss_B_no_ewc)
    
            # Track performance on Task B
            accuracy_taskB_no_ewc, _, _, _ = evaluate(modelB, test_B_loader, criterion)
            print(f"Epoch {epoch + 1} - Task B performance during Task B (without EWC): {accuracy_taskB_no_ewc:.4f}")
            task_B_no_ewc_run.append(accuracy_taskB_no_ewc)
    
            # Track performance on Task B
            val_accuracy_taskB_no_ewc, _, _, _ = evaluate(modelB, val_B_loader, criterion)
            print(f"Epoch {epoch + 1} - Task B performance during Task B - validation set (without EWC): {val_accuracy_taskB_no_ewc:.4f}")
            val_task_B_no_ewc_run.append(val_accuracy_taskB_no_ewc)
        
            # Track performance on Task A while training on Task B
            accuracy_taskA_during_B_no_ewc, _, _, _ = evaluate(modelB, test_A_loader, criterion)
            print(f"Epoch {epoch + 1} - Task A performance during Task B (without EWC): {accuracy_taskA_during_B_no_ewc:.4f}")
            task_A_during_B_no_ewc_run.append(accuracy_taskA_during_B_no_ewc)
    
            # Track performance on Task A while training on Task B
            val_accuracy_taskA_during_B_no_ewc, _, _, _ = evaluate(modelB, val_A_loader, criterion)
            print(f"Epoch {epoch + 1} - Task A performance during Task B - validation set (without EWC): {val_accuracy_taskA_during_B_no_ewc:.4f}")
            val_task_A_during_B_no_ewc_run.append(val_accuracy_taskA_during_B_no_ewc)
            
        epoch_stats["no_ewc"]["task_A_during_B"].append(task_A_during_B_no_ewc_run)
        epoch_stats["no_ewc"]["val_task_A_during_B"].append(val_task_A_during_B_no_ewc_run)
        epoch_stats["no_ewc"]["task_B"].append(task_B_no_ewc_run)
        epoch_stats["no_ewc"]["val_task_B"].append(val_task_B_no_ewc_run)
    
        # Evaluate performance on Task B without EWC
        accuracy_taskB_no_ewc, precision_taskB_no_ewc, recall_taskB_no_ewc, kappa_taskB_no_ewc = evaluate(modelB, test_B_loader, criterion)
        print(f"Task B without EWC: Accuracy: {accuracy_taskB_no_ewc}, Precision: {precision_taskB_no_ewc}, Recall: {recall_taskB_no_ewc}, Cohen's Kappa: {kappa_taskB_no_ewc}")
        results["B_no_ewc"]["accuracy"].append(accuracy_taskB_no_ewc)
        results["B_no_ewc"]["precision"].append(precision_taskB_no_ewc)
        results["B_no_ewc"]["recall"].append(recall_taskB_no_ewc)
        results["B_no_ewc"]["kappa"].append(kappa_taskB_no_ewc)
    
        # Evaluate on Task B - validation
        accuracy_taskB_no_ewc_val, precision_taskB_no_ewc_val, recall_taskB_no_ewc_val, kappa_taskB_no_ewc_val = evaluate(modelB, val_B_loader, criterion)
        print(f"Task A after Task B without EWC: Accuracy: {accuracy_taskB_no_ewc_val:.4f}, Precision: {precision_taskB_no_ewc_val:.4f}, Recall: {recall_taskB_no_ewc_val:.4f}, Kappa: {kappa_taskB_no_ewc_val:.4f}")
        results_val["B_no_ewc_val"]["accuracy"].append(accuracy_taskB_no_ewc_val)
        results_val["B_no_ewc_val"]["precision"].append(precision_taskB_no_ewc_val)
        results_val["B_no_ewc_val"]["recall"].append(recall_taskB_no_ewc_val)
        results_val["B_no_ewc_val"]["kappa"].append(kappa_taskB_no_ewc_val)
    
        # Evaluate performance on Task A after training on Task B without EWC
        accuracy_taskA_final_no_ewc, precision_taskA_final_no_ewc, recall_taskA_final_no_ewc, kappa_taskA_final_no_ewc = evaluate(modelB, test_A_loader, criterion)
        print(f"Task A - Final without EWC: Accuracy: {accuracy_taskA_final_no_ewc}, Precision: {precision_taskA_final_no_ewc}, Recall: {recall_taskA_final_no_ewc}, Cohen's Kappa: {kappa_taskA_final_no_ewc}")
        results["A_after_B_no_ewc"]["accuracy"].append(accuracy_taskA_final_no_ewc)
        results["A_after_B_no_ewc"]["precision"].append(precision_taskA_final_no_ewc)
        results["A_after_B_no_ewc"]["recall"].append(recall_taskA_final_no_ewc)
        results["A_after_B_no_ewc"]["kappa"].append(kappa_taskA_final_no_ewc)
    
        # Evaluate performance on Task A after training on Task B without EWC - validation
        accuracy_taskA_after_B_no_ewc_val, precision_taskA_after_B_no_ewc_val, recall_taskA_after_B_no_ewc_val, kappa_taskA_after_B_no_ewc_val = evaluate(modelB, val_A_loader, criterion)
        print(f"Task A after Task B without EWC: Accuracy: {accuracy_taskA_after_B_no_ewc_val:.4f}, Precision: {precision_taskA_after_B_no_ewc_val:.4f}, Recall: {recall_taskA_after_B_no_ewc_val:.4f}, Cohen's Kappa: {kappa_taskA_after_B_no_ewc_val:.4f}")
        results_val["A_after_B_no_ewc_val"]["accuracy"].append(accuracy_taskA_after_B_no_ewc_val)
        results_val["A_after_B_no_ewc_val"]["precision"].append(precision_taskA_after_B_no_ewc_val)
        results_val["A_after_B_no_ewc_val"]["recall"].append(recall_taskA_after_B_no_ewc_val)
        results_val["A_after_B_no_ewc_val"]["kappa"].append(kappa_taskA_after_B_no_ewc_val)
    
        with open('epoch_stats__no_ewc_TIL_Bench_smaller_sample_2.json', 'w') as f:
            json.dump(epoch_stats, f, indent=4)
        
# # Calculate statistics: mean, variance, min, and max
# statistics_results = {
#     key: {
#         metric: {
#             "mean": np.mean(values),
#             "variance": np.var(values),
#             "min": np.min(values),
#             "max": np.max(values)
#         }
#         for metric, values in metrics.items()
#     }
#     for key, metrics in results.items()
# }

# # Print results with statistics
# print("\nResults with Statistics:")
# for key, metrics in statistics_results.items():
#     print(f"{key}:")
#     for metric, stats in metrics.items():
#         print(f"  {metric} - Mean: {stats['mean']:.4f}, Variance: {stats['variance']:.4f}, Min: {stats['min']:.4f}, Max: {stats['max']:.4f}")
# Out:
# Run 1/1
# Epoch 50 - Task A performance during Task B (without EWC): 0.9233
# Epoch 1/1, Loss: 0.2356
# Epoch 1 - Task B performance during Task B (without EWC): 0.9280
# Epoch 1 - Task B performance during Task B - validation set (without EWC): 0.9433
# Epoch 1 - Task A performance during Task B (without EWC): 0.8673
# Epoch 1 - Task A performance during Task B - validation set (without EWC): 0.8520
# Epoch 1/1, Loss: 0.1826
# Epoch 2 - Task B performance during Task B (without EWC): 0.9460
# Epoch 2 - Task B performance during Task B - validation set (without EWC): 0.9580
# Epoch 2 - Task A performance during Task B (without EWC): 0.8160
# Epoch 2 - Task A performance during Task B - validation set (without EWC): 0.8080
# Epoch 1/1, Loss: 0.1553
# Epoch 3 - Task B performance during Task B (without EWC): 0.9533
# Epoch 3 - Task B performance during Task B - validation set (without EWC): 0.9600
# Epoch 3 - Task A performance during Task B (without EWC): 0.7973
# Epoch 3 - Task A performance during Task B - validation set (without EWC): 0.7907
# Epoch 1/1, Loss: 0.1367
# Epoch 4 - Task B performance during Task B (without EWC): 0.9580
# Epoch 4 - Task B performance during Task B - validation set (without EWC): 0.9607
# Epoch 4 - Task A performance during Task B (without EWC): 0.7807
# Epoch 4 - Task A performance during Task B - validation set (without EWC): 0.7727
# Epoch 1/1, Loss: 0.1227
# Epoch 5 - Task B performance during Task B (without EWC): 0.9600
# Epoch 5 - Task B performance during Task B - validation set (without EWC): 0.9670
# Epoch 5 - Task A performance during Task B (without EWC): 0.7767
# Epoch 5 - Task A performance during Task B - validation set (without EWC): 0.7673
# Epoch 1/1, Loss: 0.1124
# Epoch 6 - Task B performance during Task B (without EWC): 0.9647
# Epoch 6 - Task B performance during Task B - validation set (without EWC): 0.9660
# Epoch 6 - Task A performance during Task B (without EWC): 0.7753
# Epoch 6 - Task A performance during Task B - validation set (without EWC): 0.7647
# Epoch 1/1, Loss: 0.1035
# Epoch 7 - Task B performance during Task B (without EWC): 0.9667
# Epoch 7 - Task B performance during Task B - validation set (without EWC): 0.9687
# Epoch 7 - Task A performance during Task B (without EWC): 0.7700
# Epoch 7 - Task A performance during Task B - validation set (without EWC): 0.7590
# Epoch 1/1, Loss: 0.0957
# Epoch 8 - Task B performance during Task B (without EWC): 0.9707
# Epoch 8 - Task B performance during Task B - validation set (without EWC): 0.9710
# Epoch 8 - Task A performance during Task B (without EWC): 0.7713
# Epoch 8 - Task A performance during Task B - validation set (without EWC): 0.7583
# Epoch 1/1, Loss: 0.0904
# Epoch 9 - Task B performance during Task B (without EWC): 0.9687
# Epoch 9 - Task B performance during Task B - validation set (without EWC): 0.9680
# Epoch 9 - Task A performance during Task B (without EWC): 0.7733
# Epoch 9 - Task A performance during Task B - validation set (without EWC): 0.7650
# Epoch 1/1, Loss: 0.0845
# Epoch 10 - Task B performance during Task B (without EWC): 0.9720
# Epoch 10 - Task B performance during Task B - validation set (without EWC): 0.9720
# Epoch 10 - Task A performance during Task B (without EWC): 0.7727
# Epoch 10 - Task A performance during Task B - validation set (without EWC): 0.7623
# Epoch 1/1, Loss: 0.0805
# Epoch 11 - Task B performance during Task B (without EWC): 0.9747
# Epoch 11 - Task B performance during Task B - validation set (without EWC): 0.9733
# Epoch 11 - Task A performance during Task B (without EWC): 0.7740
# Epoch 11 - Task A performance during Task B - validation set (without EWC): 0.7610
# Epoch 1/1, Loss: 0.0773
# Epoch 12 - Task B performance during Task B (without EWC): 0.9760
# Epoch 12 - Task B performance during Task B - validation set (without EWC): 0.9730
# Epoch 12 - Task A performance during Task B (without EWC): 0.7760
# Epoch 12 - Task A performance during Task B - validation set (without EWC): 0.7607
# Epoch 1/1, Loss: 0.0736
# Epoch 13 - Task B performance during Task B (without EWC): 0.9733
# Epoch 13 - Task B performance during Task B - validation set (without EWC): 0.9720
# Epoch 13 - Task A performance during Task B (without EWC): 0.7813
# Epoch 13 - Task A performance during Task B - validation set (without EWC): 0.7663
# Epoch 1/1, Loss: 0.0703
# Epoch 14 - Task B performance during Task B (without EWC): 0.9760
# Epoch 14 - Task B performance during Task B - validation set (without EWC): 0.9740
# Epoch 14 - Task A performance during Task B (without EWC): 0.7760
# Epoch 14 - Task A performance during Task B - validation set (without EWC): 0.7623
# Epoch 1/1, Loss: 0.0674
# Epoch 15 - Task B performance during Task B (without EWC): 0.9747
# Epoch 15 - Task B performance during Task B - validation set (without EWC): 0.9730
# Epoch 15 - Task A performance during Task B (without EWC): 0.7807
# Epoch 15 - Task A performance during Task B - validation set (without EWC): 0.7680
# Epoch 1/1, Loss: 0.0639
# Epoch 16 - Task B performance during Task B (without EWC): 0.9780
# Epoch 16 - Task B performance during Task B - validation set (without EWC): 0.9753
# Epoch 16 - Task A performance during Task B (without EWC): 0.7753
# Epoch 16 - Task A performance during Task B - validation set (without EWC): 0.7617
# Epoch 1/1, Loss: 0.0619
# Epoch 17 - Task B performance during Task B (without EWC): 0.9793
# Epoch 17 - Task B performance during Task B - validation set (without EWC): 0.9757
# Epoch 17 - Task A performance during Task B (without EWC): 0.7753
# Epoch 17 - Task A performance during Task B - validation set (without EWC): 0.7630
# Epoch 1/1, Loss: 0.0587
# Epoch 18 - Task B performance during Task B (without EWC): 0.9793
# Epoch 18 - Task B performance during Task B - validation set (without EWC): 0.9757
# Epoch 18 - Task A performance during Task B (without EWC): 0.7760
# Epoch 18 - Task A performance during Task B - validation set (without EWC): 0.7633
# Epoch 1/1, Loss: 0.0583
# Epoch 19 - Task B performance during Task B (without EWC): 0.9800
# Epoch 19 - Task B performance during Task B - validation set (without EWC): 0.9763
# Epoch 19 - Task A performance during Task B (without EWC): 0.7793
# Epoch 19 - Task A performance during Task B - validation set (without EWC): 0.7657
# Epoch 1/1, Loss: 0.0556
# Epoch 20 - Task B performance during Task B (without EWC): 0.9840
# Epoch 20 - Task B performance during Task B - validation set (without EWC): 0.9767
# Epoch 20 - Task A performance during Task B (without EWC): 0.7780
# Epoch 20 - Task A performance during Task B - validation set (without EWC): 0.7623
# Epoch 1/1, Loss: 0.0528
# Epoch 21 - Task B performance during Task B (without EWC): 0.9773
# Epoch 21 - Task B performance during Task B - validation set (without EWC): 0.9753
# Epoch 21 - Task A performance during Task B (without EWC): 0.7760
# Epoch 21 - Task A performance during Task B - validation set (without EWC): 0.7673
# Epoch 1/1, Loss: 0.0516
# Epoch 22 - Task B performance during Task B (without EWC): 0.9773
# Epoch 22 - Task B performance during Task B - validation set (without EWC): 0.9780
# Epoch 22 - Task A performance during Task B (without EWC): 0.7787
# Epoch 22 - Task A performance during Task B - validation set (without EWC): 0.7673
# Epoch 1/1, Loss: 0.0492
# Epoch 23 - Task B performance during Task B (without EWC): 0.9787
# Epoch 23 - Task B performance during Task B - validation set (without EWC): 0.9780
# Epoch 23 - Task A performance during Task B (without EWC): 0.7793
# Epoch 23 - Task A performance during Task B - validation set (without EWC): 0.7660
# Epoch 1/1, Loss: 0.0485
# Epoch 24 - Task B performance during Task B (without EWC): 0.9807
# Epoch 24 - Task B performance during Task B - validation set (without EWC): 0.9780
# Epoch 24 - Task A performance during Task B (without EWC): 0.7787
# Epoch 24 - Task A performance during Task B - validation set (without EWC): 0.7660
# Epoch 1/1, Loss: 0.0463
# Epoch 25 - Task B performance during Task B (without EWC): 0.9827
# Epoch 25 - Task B performance during Task B - validation set (without EWC): 0.9780
# Epoch 25 - Task A performance during Task B (without EWC): 0.7807
# Epoch 25 - Task A performance during Task B - validation set (without EWC): 0.7667
# Epoch 1/1, Loss: 0.0464
# Epoch 26 - Task B performance during Task B (without EWC): 0.9793
# Epoch 26 - Task B performance during Task B - validation set (without EWC): 0.9760
# Epoch 26 - Task A performance during Task B (without EWC): 0.7833
# Epoch 26 - Task A performance during Task B - validation set (without EWC): 0.7707
# Epoch 1/1, Loss: 0.0444
# Epoch 27 - Task B performance during Task B (without EWC): 0.9833
# Epoch 27 - Task B performance during Task B - validation set (without EWC): 0.9760
# Epoch 27 - Task A performance during Task B (without EWC): 0.7800
# Epoch 27 - Task A performance during Task B - validation set (without EWC): 0.7667
# Epoch 1/1, Loss: 0.0427
# Epoch 28 - Task B performance during Task B (without EWC): 0.9813
# Epoch 28 - Task B performance during Task B - validation set (without EWC): 0.9773
# Epoch 28 - Task A performance during Task B (without EWC): 0.7813
# Epoch 28 - Task A performance during Task B - validation set (without EWC): 0.7667
# Epoch 1/1, Loss: 0.0424
# Epoch 29 - Task B performance during Task B (without EWC): 0.9813
# Epoch 29 - Task B performance during Task B - validation set (without EWC): 0.9770
# Epoch 29 - Task A performance during Task B (without EWC): 0.7787
# Epoch 29 - Task A performance during Task B - validation set (without EWC): 0.7653
# Epoch 1/1, Loss: 0.0398
# Epoch 30 - Task B performance during Task B (without EWC): 0.9833
# Epoch 30 - Task B performance during Task B - validation set (without EWC): 0.9783
# Epoch 30 - Task A performance during Task B (without EWC): 0.7807
# Epoch 30 - Task A performance during Task B - validation set (without EWC): 0.7687
# Epoch 1/1, Loss: 0.0389
# Epoch 31 - Task B performance during Task B (without EWC): 0.9813
# Epoch 31 - Task B performance during Task B - validation set (without EWC): 0.9750
# Epoch 31 - Task A performance during Task B (without EWC): 0.7773
# Epoch 31 - Task A performance during Task B - validation set (without EWC): 0.7633
# Epoch 1/1, Loss: 0.0383
# Epoch 32 - Task B performance during Task B (without EWC): 0.9813
# Epoch 32 - Task B performance during Task B - validation set (without EWC): 0.9790
# Epoch 32 - Task A performance during Task B (without EWC): 0.7793
# Epoch 32 - Task A performance during Task B - validation set (without EWC): 0.7683
# Epoch 1/1, Loss: 0.0368
# Epoch 33 - Task B performance during Task B (without EWC): 0.9813
# Epoch 33 - Task B performance during Task B - validation set (without EWC): 0.9787
# Epoch 33 - Task A performance during Task B (without EWC): 0.7847
# Epoch 33 - Task A performance during Task B - validation set (without EWC): 0.7693
# Epoch 1/1, Loss: 0.0360
# Epoch 34 - Task B performance during Task B (without EWC): 0.9813
# Epoch 34 - Task B performance during Task B - validation set (without EWC): 0.9793
# Epoch 34 - Task A performance during Task B (without EWC): 0.7827
# Epoch 34 - Task A performance during Task B - validation set (without EWC): 0.7683
# Epoch 1/1, Loss: 0.0346
# Epoch 35 - Task B performance during Task B (without EWC): 0.9853
# Epoch 35 - Task B performance during Task B - validation set (without EWC): 0.9743
# Epoch 35 - Task A performance during Task B (without EWC): 0.7813
# Epoch 35 - Task A performance during Task B - validation set (without EWC): 0.7650
# Epoch 1/1, Loss: 0.0348
# Epoch 36 - Task B performance during Task B (without EWC): 0.9807
# Epoch 36 - Task B performance during Task B - validation set (without EWC): 0.9810
# Epoch 36 - Task A performance during Task B (without EWC): 0.7847
# Epoch 36 - Task A performance during Task B - validation set (without EWC): 0.7720
# Epoch 1/1, Loss: 0.0334
# Epoch 37 - Task B performance during Task B (without EWC): 0.9807
# Epoch 37 - Task B performance during Task B - validation set (without EWC): 0.9803
# Epoch 37 - Task A performance during Task B (without EWC): 0.7867
# Epoch 37 - Task A performance during Task B - validation set (without EWC): 0.7710
# Epoch 1/1, Loss: 0.0321
# Epoch 38 - Task B performance during Task B (without EWC): 0.9827
# Epoch 38 - Task B performance during Task B - validation set (without EWC): 0.9783
# Epoch 38 - Task A performance during Task B (without EWC): 0.7860
# Epoch 38 - Task A performance during Task B - validation set (without EWC): 0.7707
# Epoch 1/1, Loss: 0.0315
# Epoch 39 - Task B performance during Task B (without EWC): 0.9833
# Epoch 39 - Task B performance during Task B - validation set (without EWC): 0.9787
# Epoch 39 - Task A performance during Task B (without EWC): 0.7827
# Epoch 39 - Task A performance during Task B - validation set (without EWC): 0.7687
# Epoch 1/1, Loss: 0.0306
# Epoch 40 - Task B performance during Task B (without EWC): 0.9840
# Epoch 40 - Task B performance during Task B - validation set (without EWC): 0.9783
# Epoch 40 - Task A performance during Task B (without EWC): 0.7847
# Epoch 40 - Task A performance during Task B - validation set (without EWC): 0.7693
# Epoch 1/1, Loss: 0.0305
# Epoch 41 - Task B performance during Task B (without EWC): 0.9827
# Epoch 41 - Task B performance during Task B - validation set (without EWC): 0.9823
# Epoch 41 - Task A performance during Task B (without EWC): 0.7900
# Epoch 41 - Task A performance during Task B - validation set (without EWC): 0.7723
# Epoch 1/1, Loss: 0.0290
# Epoch 42 - Task B performance during Task B (without EWC): 0.9840
# Epoch 42 - Task B performance during Task B - validation set (without EWC): 0.9803
# Epoch 42 - Task A performance during Task B (without EWC): 0.7893
# Epoch 42 - Task A performance during Task B - validation set (without EWC): 0.7737
# Epoch 1/1, Loss: 0.0284
# Epoch 43 - Task B performance during Task B (without EWC): 0.9820
# Epoch 43 - Task B performance during Task B - validation set (without EWC): 0.9737
# Epoch 43 - Task A performance during Task B (without EWC): 0.7847
# Epoch 43 - Task A performance during Task B - validation set (without EWC): 0.7710
# Epoch 1/1, Loss: 0.0281
# Epoch 44 - Task B performance during Task B (without EWC): 0.9833
# Epoch 44 - Task B performance during Task B - validation set (without EWC): 0.9797
# Epoch 44 - Task A performance during Task B (without EWC): 0.7840
# Epoch 44 - Task A performance during Task B - validation set (without EWC): 0.7720
# Epoch 1/1, Loss: 0.0259
# Epoch 45 - Task B performance during Task B (without EWC): 0.9813
# Epoch 45 - Task B performance during Task B - validation set (without EWC): 0.9820
# Epoch 45 - Task A performance during Task B (without EWC): 0.7913
# Epoch 45 - Task A performance during Task B - validation set (without EWC): 0.7750
# Epoch 1/1, Loss: 0.0267
# Epoch 46 - Task B performance during Task B (without EWC): 0.9827
# Epoch 46 - Task B performance during Task B - validation set (without EWC): 0.9800
# Epoch 46 - Task A performance during Task B (without EWC): 0.7853
# Epoch 46 - Task A performance during Task B - validation set (without EWC): 0.7723
# Epoch 1/1, Loss: 0.0246
# Epoch 47 - Task B performance during Task B (without EWC): 0.9833
# Epoch 47 - Task B performance during Task B - validation set (without EWC): 0.9807
# Epoch 47 - Task A performance during Task B (without EWC): 0.7900
# Epoch 47 - Task A performance during Task B - validation set (without EWC): 0.7730
# Epoch 1/1, Loss: 0.0250
# Epoch 48 - Task B performance during Task B (without EWC): 0.9827
# Epoch 48 - Task B performance during Task B - validation set (without EWC): 0.9800
# Epoch 48 - Task A performance during Task B (without EWC): 0.7900
# Epoch 48 - Task A performance during Task B - validation set (without EWC): 0.7743
# Epoch 1/1, Loss: 0.0240
# Epoch 49 - Task B performance during Task B (without EWC): 0.9827
# Epoch 49 - Task B performance during Task B - validation set (without EWC): 0.9813
# Epoch 49 - Task A performance during Task B (without EWC): 0.7913
# Epoch 49 - Task A performance during Task B - validation set (without EWC): 0.7753
# Epoch 1/1, Loss: 0.0245
# Epoch 50 - Task B performance during Task B (without EWC): 0.9833
# Epoch 50 - Task B performance during Task B - validation set (without EWC): 0.9817
# Epoch 50 - Task A performance during Task B (without EWC): 0.7913
# Epoch 50 - Task A performance during Task B - validation set (without EWC): 0.7753
# Task B without EWC: Accuracy: 0.9833333333333333, Precision: 0.9834029433571768, Recall: 0.9833333333333333, Cohen's Kappa: 0.9666666666666667
# Task A after Task B without EWC: Accuracy: 0.9817, Precision: 0.9817, Recall: 0.9817, Kappa: 0.9633
# Task A - Final without EWC: Accuracy: 0.7913333333333333, Precision: 0.857708513100238, Recall: 0.7913333333333333, Cohen's Kappa: 0.7681481481481481
# Task A after Task B without EWC: Accuracy: 0.7753, Precision: 0.8398, Recall: 0.7753, Cohen's Kappa: 0.7504
# Run 1/1
# Epoch 50 - Task A performance during Task B (without EWC): 0.9360
# Epoch 1/1, Loss: 0.2151
# Epoch 1 - Task B performance during Task B (without EWC): 0.9407
# Epoch 1 - Task B performance during Task B - validation set (without EWC): 0.9460
# Epoch 1 - Task A performance during Task B (without EWC): 0.8980
# Epoch 1 - Task A performance during Task B - validation set (without EWC): 0.8863
# Epoch 1/1, Loss: 0.1675
# Epoch 2 - Task B performance during Task B (without EWC): 0.9513
# Epoch 2 - Task B performance during Task B - validation set (without EWC): 0.9567
# Epoch 2 - Task A performance during Task B (without EWC): 0.8747
# Epoch 2 - Task A performance during Task B - validation set (without EWC): 0.8587
# Epoch 1/1, Loss: 0.1427
# Epoch 3 - Task B performance during Task B (without EWC): 0.9553
# Epoch 3 - Task B performance during Task B - validation set (without EWC): 0.9580
# Epoch 3 - Task A performance during Task B (without EWC): 0.8560
# Epoch 3 - Task A performance during Task B - validation set (without EWC): 0.8353
# Epoch 1/1, Loss: 0.1287
# Epoch 4 - Task B performance during Task B (without EWC): 0.9587
# Epoch 4 - Task B performance during Task B - validation set (without EWC): 0.9593
# Epoch 4 - Task A performance during Task B (without EWC): 0.8513
# Epoch 4 - Task A performance during Task B - validation set (without EWC): 0.8297
# Epoch 1/1, Loss: 0.1153
# Epoch 5 - Task B performance during Task B (without EWC): 0.9653
# Epoch 5 - Task B performance during Task B - validation set (without EWC): 0.9640
# Epoch 5 - Task A performance during Task B (without EWC): 0.8393
# Epoch 5 - Task A performance during Task B - validation set (without EWC): 0.8193
# Epoch 1/1, Loss: 0.1060
# Epoch 6 - Task B performance during Task B (without EWC): 0.9680
# Epoch 6 - Task B performance during Task B - validation set (without EWC): 0.9663
# Epoch 6 - Task A performance during Task B (without EWC): 0.8287
# Epoch 6 - Task A performance during Task B - validation set (without EWC): 0.8117
# Epoch 1/1, Loss: 0.0979
# Epoch 7 - Task B performance during Task B (without EWC): 0.9647
# Epoch 7 - Task B performance during Task B - validation set (without EWC): 0.9630
# Epoch 7 - Task A performance during Task B (without EWC): 0.8193
# Epoch 7 - Task A performance during Task B - validation set (without EWC): 0.8033
# Epoch 1/1, Loss: 0.0898
# Epoch 8 - Task B performance during Task B (without EWC): 0.9753
# Epoch 8 - Task B performance during Task B - validation set (without EWC): 0.9703
# Epoch 8 - Task A performance during Task B (without EWC): 0.8113
# Epoch 8 - Task A performance during Task B - validation set (without EWC): 0.7937
# Epoch 1/1, Loss: 0.0850
# Epoch 9 - Task B performance during Task B (without EWC): 0.9713
# Epoch 9 - Task B performance during Task B - validation set (without EWC): 0.9683
# Epoch 9 - Task A performance during Task B (without EWC): 0.8127
# Epoch 9 - Task A performance during Task B - validation set (without EWC): 0.7903
# Epoch 1/1, Loss: 0.0793
# Epoch 10 - Task B performance during Task B (without EWC): 0.9740
# Epoch 10 - Task B performance during Task B - validation set (without EWC): 0.9693
# Epoch 10 - Task A performance during Task B (without EWC): 0.8047
# Epoch 10 - Task A performance during Task B - validation set (without EWC): 0.7867
# Epoch 1/1, Loss: 0.0749
# Epoch 11 - Task B performance during Task B (without EWC): 0.9747
# Epoch 11 - Task B performance during Task B - validation set (without EWC): 0.9687
# Epoch 11 - Task A performance during Task B (without EWC): 0.8020
# Epoch 11 - Task A performance during Task B - validation set (without EWC): 0.7817
# Epoch 1/1, Loss: 0.0722
# Epoch 12 - Task B performance during Task B (without EWC): 0.9740
# Epoch 12 - Task B performance during Task B - validation set (without EWC): 0.9710
# Epoch 12 - Task A performance during Task B (without EWC): 0.7920
# Epoch 12 - Task A performance during Task B - validation set (without EWC): 0.7797
# Epoch 1/1, Loss: 0.0670
# Epoch 13 - Task B performance during Task B (without EWC): 0.9753
# Epoch 13 - Task B performance during Task B - validation set (without EWC): 0.9693
# Epoch 13 - Task A performance during Task B (without EWC): 0.7913
# Epoch 13 - Task A performance during Task B - validation set (without EWC): 0.7733
# Epoch 1/1, Loss: 0.0644
# Epoch 14 - Task B performance during Task B (without EWC): 0.9780
# Epoch 14 - Task B performance during Task B - validation set (without EWC): 0.9757
# Epoch 14 - Task A performance during Task B (without EWC): 0.7900
# Epoch 14 - Task A performance during Task B - validation set (without EWC): 0.7740
# Epoch 1/1, Loss: 0.0610
# Epoch 15 - Task B performance during Task B (without EWC): 0.9773
# Epoch 15 - Task B performance during Task B - validation set (without EWC): 0.9743
# Epoch 15 - Task A performance during Task B (without EWC): 0.7853
# Epoch 15 - Task A performance during Task B - validation set (without EWC): 0.7670
# Epoch 1/1, Loss: 0.0588
# Epoch 16 - Task B performance during Task B (without EWC): 0.9800
# Epoch 16 - Task B performance during Task B - validation set (without EWC): 0.9733
# Epoch 16 - Task A performance during Task B (without EWC): 0.7833
# Epoch 16 - Task A performance during Task B - validation set (without EWC): 0.7657
# Epoch 1/1, Loss: 0.0564
# Epoch 17 - Task B performance during Task B (without EWC): 0.9767
# Epoch 17 - Task B performance during Task B - validation set (without EWC): 0.9743
# Epoch 17 - Task A performance during Task B (without EWC): 0.7820
# Epoch 17 - Task A performance during Task B - validation set (without EWC): 0.7647
# Epoch 1/1, Loss: 0.0536
# Epoch 18 - Task B performance during Task B (without EWC): 0.9780
# Epoch 18 - Task B performance during Task B - validation set (without EWC): 0.9760
# Epoch 18 - Task A performance during Task B (without EWC): 0.7873
# Epoch 18 - Task A performance during Task B - validation set (without EWC): 0.7670
# Epoch 1/1, Loss: 0.0509
# Epoch 19 - Task B performance during Task B (without EWC): 0.9807
# Epoch 19 - Task B performance during Task B - validation set (without EWC): 0.9757
# Epoch 19 - Task A performance during Task B (without EWC): 0.7780
# Epoch 19 - Task A performance during Task B - validation set (without EWC): 0.7620
# Epoch 1/1, Loss: 0.0488
# Epoch 20 - Task B performance during Task B (without EWC): 0.9800
# Epoch 20 - Task B performance during Task B - validation set (without EWC): 0.9770
# Epoch 20 - Task A performance during Task B (without EWC): 0.7753
# Epoch 20 - Task A performance during Task B - validation set (without EWC): 0.7590
# Epoch 1/1, Loss: 0.0476
# Epoch 21 - Task B performance during Task B (without EWC): 0.9800
# Epoch 21 - Task B performance during Task B - validation set (without EWC): 0.9763
# Epoch 21 - Task A performance during Task B (without EWC): 0.7720
# Epoch 21 - Task A performance during Task B - validation set (without EWC): 0.7590
# Epoch 1/1, Loss: 0.0459
# Epoch 22 - Task B performance during Task B (without EWC): 0.9813
# Epoch 22 - Task B performance during Task B - validation set (without EWC): 0.9780
# Epoch 22 - Task A performance during Task B (without EWC): 0.7780
# Epoch 22 - Task A performance during Task B - validation set (without EWC): 0.7613
# Epoch 1/1, Loss: 0.0443
# Epoch 23 - Task B performance during Task B (without EWC): 0.9820
# Epoch 23 - Task B performance during Task B - validation set (without EWC): 0.9763
# Epoch 23 - Task A performance during Task B (without EWC): 0.7767
# Epoch 23 - Task A performance during Task B - validation set (without EWC): 0.7593
# Epoch 1/1, Loss: 0.0424
# Epoch 24 - Task B performance during Task B (without EWC): 0.9807
# Epoch 24 - Task B performance during Task B - validation set (without EWC): 0.9733
# Epoch 24 - Task A performance during Task B (without EWC): 0.7707
# Epoch 24 - Task A performance during Task B - validation set (without EWC): 0.7590
# Epoch 1/1, Loss: 0.0411
# Epoch 25 - Task B performance during Task B (without EWC): 0.9820
# Epoch 25 - Task B performance during Task B - validation set (without EWC): 0.9770
# Epoch 25 - Task A performance during Task B (without EWC): 0.7740
# Epoch 25 - Task A performance during Task B - validation set (without EWC): 0.7583
# Epoch 1/1, Loss: 0.0398
# Epoch 26 - Task B performance during Task B (without EWC): 0.9827
# Epoch 26 - Task B performance during Task B - validation set (without EWC): 0.9757
# Epoch 26 - Task A performance during Task B (without EWC): 0.7773
# Epoch 26 - Task A performance during Task B - validation set (without EWC): 0.7610
# Epoch 1/1, Loss: 0.0391
# Epoch 27 - Task B performance during Task B (without EWC): 0.9813
# Epoch 27 - Task B performance during Task B - validation set (without EWC): 0.9760
# Epoch 27 - Task A performance during Task B (without EWC): 0.7760
# Epoch 27 - Task A performance during Task B - validation set (without EWC): 0.7600
# Epoch 1/1, Loss: 0.0370
# Epoch 28 - Task B performance during Task B (without EWC): 0.9807
# Epoch 28 - Task B performance during Task B - validation set (without EWC): 0.9740
# Epoch 28 - Task A performance during Task B (without EWC): 0.7747
# Epoch 28 - Task A performance during Task B - validation set (without EWC): 0.7590
# Epoch 1/1, Loss: 0.0359
# Epoch 29 - Task B performance during Task B (without EWC): 0.9827
# Epoch 29 - Task B performance during Task B - validation set (without EWC): 0.9763
# Epoch 29 - Task A performance during Task B (without EWC): 0.7733
# Epoch 29 - Task A performance during Task B - validation set (without EWC): 0.7577
# Epoch 1/1, Loss: 0.0358
# Epoch 30 - Task B performance during Task B (without EWC): 0.9807
# Epoch 30 - Task B performance during Task B - validation set (without EWC): 0.9773
# Epoch 30 - Task A performance during Task B (without EWC): 0.7740
# Epoch 30 - Task A performance during Task B - validation set (without EWC): 0.7590
# Epoch 1/1, Loss: 0.0339
# Epoch 31 - Task B performance during Task B (without EWC): 0.9813
# Epoch 31 - Task B performance during Task B - validation set (without EWC): 0.9777
# Epoch 31 - Task A performance during Task B (without EWC): 0.7780
# Epoch 31 - Task A performance during Task B - validation set (without EWC): 0.7580
# Epoch 1/1, Loss: 0.0334
# Epoch 32 - Task B performance during Task B (without EWC): 0.9827
# Epoch 32 - Task B performance during Task B - validation set (without EWC): 0.9763
# Epoch 32 - Task A performance during Task B (without EWC): 0.7767
# Epoch 32 - Task A performance during Task B - validation set (without EWC): 0.7573
# Epoch 1/1, Loss: 0.0330
# Epoch 33 - Task B performance during Task B (without EWC): 0.9840
# Epoch 33 - Task B performance during Task B - validation set (without EWC): 0.9767
# Epoch 33 - Task A performance during Task B (without EWC): 0.7780
# Epoch 33 - Task A performance during Task B - validation set (without EWC): 0.7597
# Epoch 1/1, Loss: 0.0312
# Epoch 34 - Task B performance during Task B (without EWC): 0.9833
# Epoch 34 - Task B performance during Task B - validation set (without EWC): 0.9750
# Epoch 34 - Task A performance during Task B (without EWC): 0.7707
# Epoch 34 - Task A performance during Task B - validation set (without EWC): 0.7563
# Epoch 1/1, Loss: 0.0304
# Epoch 35 - Task B performance during Task B (without EWC): 0.9820
# Epoch 35 - Task B performance during Task B - validation set (without EWC): 0.9767
# Epoch 35 - Task A performance during Task B (without EWC): 0.7733
# Epoch 35 - Task A performance during Task B - validation set (without EWC): 0.7557
# Epoch 1/1, Loss: 0.0290
# Epoch 36 - Task B performance during Task B (without EWC): 0.9813
# Epoch 36 - Task B performance during Task B - validation set (without EWC): 0.9787
# Epoch 36 - Task A performance during Task B (without EWC): 0.7760
# Epoch 36 - Task A performance during Task B - validation set (without EWC): 0.7577
# Epoch 1/1, Loss: 0.0280
# Epoch 37 - Task B performance during Task B (without EWC): 0.9827
# Epoch 37 - Task B performance during Task B - validation set (without EWC): 0.9760
# Epoch 37 - Task A performance during Task B (without EWC): 0.7740
# Epoch 37 - Task A performance during Task B - validation set (without EWC): 0.7570
# Epoch 1/1, Loss: 0.0275
# Epoch 38 - Task B performance during Task B (without EWC): 0.9827
# Epoch 38 - Task B performance during Task B - validation set (without EWC): 0.9770
# Epoch 38 - Task A performance during Task B (without EWC): 0.7727
# Epoch 38 - Task A performance during Task B - validation set (without EWC): 0.7580
# Epoch 1/1, Loss: 0.0262
# Epoch 39 - Task B performance during Task B (without EWC): 0.9827
# Epoch 39 - Task B performance during Task B - validation set (without EWC): 0.9763
# Epoch 39 - Task A performance during Task B (without EWC): 0.7740
# Epoch 39 - Task A performance during Task B - validation set (without EWC): 0.7583
# Epoch 1/1, Loss: 0.0252
# Epoch 40 - Task B performance during Task B (without EWC): 0.9827
# Epoch 40 - Task B performance during Task B - validation set (without EWC): 0.9777
# Epoch 40 - Task A performance during Task B (without EWC): 0.7747
# Epoch 40 - Task A performance during Task B - validation set (without EWC): 0.7580
# Epoch 1/1, Loss: 0.0246
# Epoch 41 - Task B performance during Task B (without EWC): 0.9833
# Epoch 41 - Task B performance during Task B - validation set (without EWC): 0.9787
# Epoch 41 - Task A performance during Task B (without EWC): 0.7713
# Epoch 41 - Task A performance during Task B - validation set (without EWC): 0.7573
# Epoch 1/1, Loss: 0.0241
# Epoch 42 - Task B performance during Task B (without EWC): 0.9813
# Epoch 42 - Task B performance during Task B - validation set (without EWC): 0.9783
# Epoch 42 - Task A performance during Task B (without EWC): 0.7733
# Epoch 42 - Task A performance during Task B - validation set (without EWC): 0.7580
# Epoch 1/1, Loss: 0.0233
# Epoch 43 - Task B performance during Task B (without EWC): 0.9847
# Epoch 43 - Task B performance during Task B - validation set (without EWC): 0.9767
# Epoch 43 - Task A performance during Task B (without EWC): 0.7727
# Epoch 43 - Task A performance during Task B - validation set (without EWC): 0.7573
# Epoch 1/1, Loss: 0.0224
# Epoch 44 - Task B performance during Task B (without EWC): 0.9827
# Epoch 44 - Task B performance during Task B - validation set (without EWC): 0.9783
# Epoch 44 - Task A performance during Task B (without EWC): 0.7693
# Epoch 44 - Task A performance during Task B - validation set (without EWC): 0.7563
# Epoch 1/1, Loss: 0.0224
# Epoch 45 - Task B performance during Task B (without EWC): 0.9813
# Epoch 45 - Task B performance during Task B - validation set (without EWC): 0.9777
# Epoch 45 - Task A performance during Task B (without EWC): 0.7700
# Epoch 45 - Task A performance during Task B - validation set (without EWC): 0.7567
# Epoch 1/1, Loss: 0.0206
# Epoch 46 - Task B performance during Task B (without EWC): 0.9853
# Epoch 46 - Task B performance during Task B - validation set (without EWC): 0.9777
# Epoch 46 - Task A performance during Task B (without EWC): 0.7680
# Epoch 46 - Task A performance during Task B - validation set (without EWC): 0.7547
# Epoch 1/1, Loss: 0.0214
# Epoch 47 - Task B performance during Task B (without EWC): 0.9833
# Epoch 47 - Task B performance during Task B - validation set (without EWC): 0.9773
# Epoch 47 - Task A performance during Task B (without EWC): 0.7680
# Epoch 47 - Task A performance during Task B - validation set (without EWC): 0.7540
# Epoch 1/1, Loss: 0.0210
# Epoch 48 - Task B performance during Task B (without EWC): 0.9820
# Epoch 48 - Task B performance during Task B - validation set (without EWC): 0.9770
# Epoch 48 - Task A performance during Task B (without EWC): 0.7687
# Epoch 48 - Task A performance during Task B - validation set (without EWC): 0.7553
# Epoch 1/1, Loss: 0.0191
# Epoch 49 - Task B performance during Task B (without EWC): 0.9820
# Epoch 49 - Task B performance during Task B - validation set (without EWC): 0.9780
# Epoch 49 - Task A performance during Task B (without EWC): 0.7693
# Epoch 49 - Task A performance during Task B - validation set (without EWC): 0.7567
# Epoch 1/1, Loss: 0.0199
# Epoch 50 - Task B performance during Task B (without EWC): 0.9853
# Epoch 50 - Task B performance during Task B - validation set (without EWC): 0.9780
# Epoch 50 - Task A performance during Task B (without EWC): 0.7660
# Epoch 50 - Task A performance during Task B - validation set (without EWC): 0.7577
# Task B without EWC: Accuracy: 0.9853333333333333, Precision: 0.9853471387630582, Recall: 0.9853333333333333, Cohen's Kappa: 0.9706666666666667
# Task A after Task B without EWC: Accuracy: 0.9780, Precision: 0.9781, Recall: 0.9780, Kappa: 0.9560
# Task A - Final without EWC: Accuracy: 0.766, Precision: 0.8637948765481137, Recall: 0.766, Cohen's Kappa: 0.74
# Task A after Task B without EWC: Accuracy: 0.7577, Precision: 0.8591, Recall: 0.7577, Cohen's Kappa: 0.7310
# Run 1/1
# Epoch 50 - Task A performance during Task B (without EWC): 0.9467
# Epoch 1/1, Loss: 0.2419
# Epoch 1 - Task B performance during Task B (without EWC): 0.9273
# Epoch 1 - Task B performance during Task B - validation set (without EWC): 0.9363
# Epoch 1 - Task A performance during Task B (without EWC): 0.9173
# Epoch 1 - Task A performance during Task B - validation set (without EWC): 0.9043
# Epoch 1/1, Loss: 0.1902
# Epoch 2 - Task B performance during Task B (without EWC): 0.9380
# Epoch 2 - Task B performance during Task B - validation set (without EWC): 0.9497
# Epoch 2 - Task A performance during Task B (without EWC): 0.8827
# Epoch 2 - Task A performance during Task B - validation set (without EWC): 0.8730
# Epoch 1/1, Loss: 0.1653
# Epoch 3 - Task B performance during Task B (without EWC): 0.9413
# Epoch 3 - Task B performance during Task B - validation set (without EWC): 0.9527
# Epoch 3 - Task A performance during Task B (without EWC): 0.8593
# Epoch 3 - Task A performance during Task B - validation set (without EWC): 0.8430
# Epoch 1/1, Loss: 0.1457
# Epoch 4 - Task B performance during Task B (without EWC): 0.9500
# Epoch 4 - Task B performance during Task B - validation set (without EWC): 0.9587
# Epoch 4 - Task A performance during Task B (without EWC): 0.8353
# Epoch 4 - Task A performance during Task B - validation set (without EWC): 0.8263
# Epoch 1/1, Loss: 0.1315
# Epoch 5 - Task B performance during Task B (without EWC): 0.9587
# Epoch 5 - Task B performance during Task B - validation set (without EWC): 0.9630
# Epoch 5 - Task A performance during Task B (without EWC): 0.8193
# Epoch 5 - Task A performance during Task B - validation set (without EWC): 0.8120
# Epoch 1/1, Loss: 0.1201
# Epoch 6 - Task B performance during Task B (without EWC): 0.9640
# Epoch 6 - Task B performance during Task B - validation set (without EWC): 0.9657
# Epoch 6 - Task A performance during Task B (without EWC): 0.8067
# Epoch 6 - Task A performance during Task B - validation set (without EWC): 0.8003
# Epoch 1/1, Loss: 0.1121
# Epoch 7 - Task B performance during Task B (without EWC): 0.9640
# Epoch 7 - Task B performance during Task B - validation set (without EWC): 0.9670
# Epoch 7 - Task A performance during Task B (without EWC): 0.8060
# Epoch 7 - Task A performance during Task B - validation set (without EWC): 0.7957
# Epoch 1/1, Loss: 0.1040
# Epoch 8 - Task B performance during Task B (without EWC): 0.9653
# Epoch 8 - Task B performance during Task B - validation set (without EWC): 0.9673
# Epoch 8 - Task A performance during Task B (without EWC): 0.8000
# Epoch 8 - Task A performance during Task B - validation set (without EWC): 0.7943
# Epoch 1/1, Loss: 0.0968
# Epoch 9 - Task B performance during Task B (without EWC): 0.9693
# Epoch 9 - Task B performance during Task B - validation set (without EWC): 0.9683
# Epoch 9 - Task A performance during Task B (without EWC): 0.7993
# Epoch 9 - Task A performance during Task B - validation set (without EWC): 0.7910
# Epoch 1/1, Loss: 0.0922
# Epoch 10 - Task B performance during Task B (without EWC): 0.9693
# Epoch 10 - Task B performance during Task B - validation set (without EWC): 0.9700
# Epoch 10 - Task A performance during Task B (without EWC): 0.7973
# Epoch 10 - Task A performance during Task B - validation set (without EWC): 0.7920
# Epoch 1/1, Loss: 0.0865
# Epoch 11 - Task B performance during Task B (without EWC): 0.9720
# Epoch 11 - Task B performance during Task B - validation set (without EWC): 0.9697
# Epoch 11 - Task A performance during Task B (without EWC): 0.8007
# Epoch 11 - Task A performance during Task B - validation set (without EWC): 0.7897
# Epoch 1/1, Loss: 0.0820
# Epoch 12 - Task B performance during Task B (without EWC): 0.9713
# Epoch 12 - Task B performance during Task B - validation set (without EWC): 0.9707
# Epoch 12 - Task A performance during Task B (without EWC): 0.8000
# Epoch 12 - Task A performance during Task B - validation set (without EWC): 0.7893
# Epoch 1/1, Loss: 0.0778
# Epoch 13 - Task B performance during Task B (without EWC): 0.9760
# Epoch 13 - Task B performance during Task B - validation set (without EWC): 0.9730
# Epoch 13 - Task A performance during Task B (without EWC): 0.8007
# Epoch 13 - Task A performance during Task B - validation set (without EWC): 0.7947
# Epoch 1/1, Loss: 0.0743
# Epoch 14 - Task B performance during Task B (without EWC): 0.9773
# Epoch 14 - Task B performance during Task B - validation set (without EWC): 0.9737
# Epoch 14 - Task A performance during Task B (without EWC): 0.8007
# Epoch 14 - Task A performance during Task B - validation set (without EWC): 0.7953
# Epoch 1/1, Loss: 0.0710
# Epoch 15 - Task B performance during Task B (without EWC): 0.9780
# Epoch 15 - Task B performance during Task B - validation set (without EWC): 0.9747
# Epoch 15 - Task A performance during Task B (without EWC): 0.8013
# Epoch 15 - Task A performance during Task B - validation set (without EWC): 0.7940
# Epoch 1/1, Loss: 0.0679
# Epoch 16 - Task B performance during Task B (without EWC): 0.9773
# Epoch 16 - Task B performance during Task B - validation set (without EWC): 0.9740
# Epoch 16 - Task A performance during Task B (without EWC): 0.8067
# Epoch 16 - Task A performance during Task B - validation set (without EWC): 0.8003
# Epoch 1/1, Loss: 0.0657
# Epoch 17 - Task B performance during Task B (without EWC): 0.9773
# Epoch 17 - Task B performance during Task B - validation set (without EWC): 0.9723
# Epoch 17 - Task A performance during Task B (without EWC): 0.8107
# Epoch 17 - Task A performance during Task B - validation set (without EWC): 0.8023
# Epoch 1/1, Loss: 0.0635
# Epoch 18 - Task B performance during Task B (without EWC): 0.9807
# Epoch 18 - Task B performance during Task B - validation set (without EWC): 0.9753
# Epoch 18 - Task A performance during Task B (without EWC): 0.8113
# Epoch 18 - Task A performance during Task B - validation set (without EWC): 0.8020
# Epoch 1/1, Loss: 0.0612
# Epoch 19 - Task B performance during Task B (without EWC): 0.9780
# Epoch 19 - Task B performance during Task B - validation set (without EWC): 0.9737
# Epoch 19 - Task A performance during Task B (without EWC): 0.8253
# Epoch 19 - Task A performance during Task B - validation set (without EWC): 0.8127
# Epoch 1/1, Loss: 0.0589
# Epoch 20 - Task B performance during Task B (without EWC): 0.9807
# Epoch 20 - Task B performance during Task B - validation set (without EWC): 0.9747
# Epoch 20 - Task A performance during Task B (without EWC): 0.8367
# Epoch 20 - Task A performance during Task B - validation set (without EWC): 0.8173
# Epoch 1/1, Loss: 0.0565
# Epoch 21 - Task B performance during Task B (without EWC): 0.9793
# Epoch 21 - Task B performance during Task B - validation set (without EWC): 0.9747
# Epoch 21 - Task A performance during Task B (without EWC): 0.8373
# Epoch 21 - Task A performance during Task B - validation set (without EWC): 0.8250
# Epoch 1/1, Loss: 0.0546
# Epoch 22 - Task B performance during Task B (without EWC): 0.9813
# Epoch 22 - Task B performance during Task B - validation set (without EWC): 0.9740
# Epoch 22 - Task A performance during Task B (without EWC): 0.8387
# Epoch 22 - Task A performance during Task B - validation set (without EWC): 0.8263
# Epoch 1/1, Loss: 0.0551
# Epoch 23 - Task B performance during Task B (without EWC): 0.9800
# Epoch 23 - Task B performance during Task B - validation set (without EWC): 0.9753
# Epoch 23 - Task A performance during Task B (without EWC): 0.8500
# Epoch 23 - Task A performance during Task B - validation set (without EWC): 0.8343
# Epoch 1/1, Loss: 0.0509
# Epoch 24 - Task B performance during Task B (without EWC): 0.9820
# Epoch 24 - Task B performance during Task B - validation set (without EWC): 0.9763
# Epoch 24 - Task A performance during Task B (without EWC): 0.8527
# Epoch 24 - Task A performance during Task B - validation set (without EWC): 0.8347
# Epoch 1/1, Loss: 0.0494
# Epoch 25 - Task B performance during Task B (without EWC): 0.9827
# Epoch 25 - Task B performance during Task B - validation set (without EWC): 0.9763
# Epoch 25 - Task A performance during Task B (without EWC): 0.8533
# Epoch 25 - Task A performance during Task B - validation set (without EWC): 0.8390
# Epoch 1/1, Loss: 0.0478
# Epoch 26 - Task B performance during Task B (without EWC): 0.9787
# Epoch 26 - Task B performance during Task B - validation set (without EWC): 0.9733
# Epoch 26 - Task A performance during Task B (without EWC): 0.8547
# Epoch 26 - Task A performance during Task B - validation set (without EWC): 0.8427
# Epoch 1/1, Loss: 0.0475
# Epoch 27 - Task B performance during Task B (without EWC): 0.9800
# Epoch 27 - Task B performance during Task B - validation set (without EWC): 0.9743
# Epoch 27 - Task A performance during Task B (without EWC): 0.8627
# Epoch 27 - Task A performance during Task B - validation set (without EWC): 0.8543
# Epoch 1/1, Loss: 0.0456
# Epoch 28 - Task B performance during Task B (without EWC): 0.9827
# Epoch 28 - Task B performance during Task B - validation set (without EWC): 0.9763
# Epoch 28 - Task A performance during Task B (without EWC): 0.8627
# Epoch 28 - Task A performance during Task B - validation set (without EWC): 0.8553
# Epoch 1/1, Loss: 0.0450
# Epoch 29 - Task B performance during Task B (without EWC): 0.9833
# Epoch 29 - Task B performance during Task B - validation set (without EWC): 0.9770
# Epoch 29 - Task A performance during Task B (without EWC): 0.8687
# Epoch 29 - Task A performance during Task B - validation set (without EWC): 0.8583
# Epoch 1/1, Loss: 0.0427
# Epoch 30 - Task B performance during Task B (without EWC): 0.9813
# Epoch 30 - Task B performance during Task B - validation set (without EWC): 0.9783
# Epoch 30 - Task A performance during Task B (without EWC): 0.8720
# Epoch 30 - Task A performance during Task B - validation set (without EWC): 0.8623
# Epoch 1/1, Loss: 0.0422
# Epoch 31 - Task B performance during Task B (without EWC): 0.9833
# Epoch 31 - Task B performance during Task B - validation set (without EWC): 0.9767
# Epoch 31 - Task A performance during Task B (without EWC): 0.8747
# Epoch 31 - Task A performance during Task B - validation set (without EWC): 0.8640
# Epoch 1/1, Loss: 0.0405
# Epoch 32 - Task B performance during Task B (without EWC): 0.9813
# Epoch 32 - Task B performance during Task B - validation set (without EWC): 0.9740
# Epoch 32 - Task A performance during Task B (without EWC): 0.8733
# Epoch 32 - Task A performance during Task B - validation set (without EWC): 0.8630
# Epoch 1/1, Loss: 0.0393
# Epoch 33 - Task B performance during Task B (without EWC): 0.9840
# Epoch 33 - Task B performance during Task B - validation set (without EWC): 0.9777
# Epoch 33 - Task A performance during Task B (without EWC): 0.8800
# Epoch 33 - Task A performance during Task B - validation set (without EWC): 0.8707
# Epoch 1/1, Loss: 0.0388
# Epoch 34 - Task B performance during Task B (without EWC): 0.9820
# Epoch 34 - Task B performance during Task B - validation set (without EWC): 0.9777
# Epoch 34 - Task A performance during Task B (without EWC): 0.8820
# Epoch 34 - Task A performance during Task B - validation set (without EWC): 0.8700
# Epoch 1/1, Loss: 0.0381
# Epoch 35 - Task B performance during Task B (without EWC): 0.9820
# Epoch 35 - Task B performance during Task B - validation set (without EWC): 0.9777
# Epoch 35 - Task A performance during Task B (without EWC): 0.8893
# Epoch 35 - Task A performance during Task B - validation set (without EWC): 0.8743
# Epoch 1/1, Loss: 0.0362
# Epoch 36 - Task B performance during Task B (without EWC): 0.9813
# Epoch 36 - Task B performance during Task B - validation set (without EWC): 0.9790
# Epoch 36 - Task A performance during Task B (without EWC): 0.8920
# Epoch 36 - Task A performance during Task B - validation set (without EWC): 0.8747
# Epoch 1/1, Loss: 0.0370
# Epoch 37 - Task B performance during Task B (without EWC): 0.9800
# Epoch 37 - Task B performance during Task B - validation set (without EWC): 0.9777
# Epoch 37 - Task A performance during Task B (without EWC): 0.8927
# Epoch 37 - Task A performance during Task B - validation set (without EWC): 0.8773
# Epoch 1/1, Loss: 0.0345
# Epoch 38 - Task B performance during Task B (without EWC): 0.9847
# Epoch 38 - Task B performance during Task B - validation set (without EWC): 0.9780
# Epoch 38 - Task A performance during Task B (without EWC): 0.8927
# Epoch 38 - Task A performance during Task B - validation set (without EWC): 0.8793
# Epoch 1/1, Loss: 0.0342
# Epoch 39 - Task B performance during Task B (without EWC): 0.9833
# Epoch 39 - Task B performance during Task B - validation set (without EWC): 0.9760
# Epoch 39 - Task A performance during Task B (without EWC): 0.8947
# Epoch 39 - Task A performance during Task B - validation set (without EWC): 0.8837
# Epoch 1/1, Loss: 0.0320
# Epoch 40 - Task B performance during Task B (without EWC): 0.9827
# Epoch 40 - Task B performance during Task B - validation set (without EWC): 0.9773
# Epoch 40 - Task A performance during Task B (without EWC): 0.8967
# Epoch 40 - Task A performance during Task B - validation set (without EWC): 0.8833
# Epoch 1/1, Loss: 0.0319
# Epoch 41 - Task B performance during Task B (without EWC): 0.9807
# Epoch 41 - Task B performance during Task B - validation set (without EWC): 0.9790
# Epoch 41 - Task A performance during Task B (without EWC): 0.8980
# Epoch 41 - Task A performance during Task B - validation set (without EWC): 0.8833
# Epoch 1/1, Loss: 0.0315
# Epoch 42 - Task B performance during Task B (without EWC): 0.9840
# Epoch 42 - Task B performance during Task B - validation set (without EWC): 0.9790
# Epoch 42 - Task A performance during Task B (without EWC): 0.9007
# Epoch 42 - Task A performance during Task B - validation set (without EWC): 0.8863
# Epoch 1/1, Loss: 0.0309
# Epoch 43 - Task B performance during Task B (without EWC): 0.9800
# Epoch 43 - Task B performance during Task B - validation set (without EWC): 0.9800
# Epoch 43 - Task A performance during Task B (without EWC): 0.9000
# Epoch 43 - Task A performance during Task B - validation set (without EWC): 0.8880
# Epoch 1/1, Loss: 0.0292
# Epoch 44 - Task B performance during Task B (without EWC): 0.9840
# Epoch 44 - Task B performance during Task B - validation set (without EWC): 0.9787
# Epoch 44 - Task A performance during Task B (without EWC): 0.9000
# Epoch 44 - Task A performance during Task B - validation set (without EWC): 0.8870
# Epoch 1/1, Loss: 0.0292
# Epoch 45 - Task B performance during Task B (without EWC): 0.9833
# Epoch 45 - Task B performance during Task B - validation set (without EWC): 0.9797
# Epoch 45 - Task A performance during Task B (without EWC): 0.9033
# Epoch 45 - Task A performance during Task B - validation set (without EWC): 0.8890
# Epoch 1/1, Loss: 0.0284
# Epoch 46 - Task B performance during Task B (without EWC): 0.9833
# Epoch 46 - Task B performance during Task B - validation set (without EWC): 0.9767
# ...
# Epoch 2 - Task A performance during Task B - validation set (without EWC): 0.8453
# Epoch 1/1, Loss: 0.1665
# Epoch 3 - Task B performance during Task B (without EWC): 0.9487
# Epoch 3 - Task B performance during Task B - validation set (without EWC): 0.9513
# Epoch 3 - Task A performance during Task B (without EWC): 0.8480
# Epoch 3 - Task A performance during Task B - validation set (without EWC): 0.8327
# Epoch 1/1, Loss: 0.1482
# Epoch 4 - Task B performance during Task B (without EWC): 0.9433
# Epoch 4 - Task B performance during Task B - validation set (without EWC): 0.9537
# Epoch 4 - Task A performance during Task B (without EWC): 0.8393
# Epoch 4 - Task A performance during Task B - validation set (without EWC): 0.8263
# Epoch 1/1, Loss: 0.1344
# Epoch 5 - Task B performance during Task B (without EWC): 0.9607
# Epoch 5 - Task B performance during Task B - validation set (without EWC): 0.9640
# Epoch 5 - Task A performance during Task B (without EWC): 0.8393
# Epoch 5 - Task A performance during Task B - validation set (without EWC): 0.8253
# Epoch 1/1, Loss: 0.1233
# Epoch 6 - Task B performance during Task B (without EWC): 0.9647
# Epoch 6 - Task B performance during Task B - validation set (without EWC): 0.9670
# Epoch 6 - Task A performance during Task B (without EWC): 0.8360
# Epoch 6 - Task A performance during Task B - validation set (without EWC): 0.8210
# Epoch 1/1, Loss: 0.1148
# Epoch 7 - Task B performance during Task B (without EWC): 0.9613
# Epoch 7 - Task B performance during Task B - validation set (without EWC): 0.9663
# Epoch 7 - Task A performance during Task B (without EWC): 0.8373
# Epoch 7 - Task A performance during Task B - validation set (without EWC): 0.8257
# Epoch 1/1, Loss: 0.1067
# Epoch 8 - Task B performance during Task B (without EWC): 0.9667
# Epoch 8 - Task B performance during Task B - validation set (without EWC): 0.9677
# Epoch 8 - Task A performance during Task B (without EWC): 0.8340
# Epoch 8 - Task A performance during Task B - validation set (without EWC): 0.8230
# Epoch 1/1, Loss: 0.1015
# Epoch 9 - Task B performance during Task B (without EWC): 0.9700
# Epoch 9 - Task B performance during Task B - validation set (without EWC): 0.9693
# Epoch 9 - Task A performance during Task B (without EWC): 0.8380
# Epoch 9 - Task A performance during Task B - validation set (without EWC): 0.8257
# Epoch 1/1, Loss: 0.0939
# Epoch 10 - Task B performance during Task B (without EWC): 0.9747
# Epoch 10 - Task B performance during Task B - validation set (without EWC): 0.9703
# Epoch 10 - Task A performance during Task B (without EWC): 0.8387
# Epoch 10 - Task A performance during Task B - validation set (without EWC): 0.8280
# Epoch 1/1, Loss: 0.0904
# Epoch 11 - Task B performance during Task B (without EWC): 0.9713
# Epoch 11 - Task B performance during Task B - validation set (without EWC): 0.9710
# Epoch 11 - Task A performance during Task B (without EWC): 0.8420
# Epoch 11 - Task A performance during Task B - validation set (without EWC): 0.8280
# Epoch 1/1, Loss: 0.0855
# Epoch 12 - Task B performance during Task B (without EWC): 0.9720
# Epoch 12 - Task B performance during Task B - validation set (without EWC): 0.9713
# Epoch 12 - Task A performance during Task B (without EWC): 0.8333
# Epoch 12 - Task A performance during Task B - validation set (without EWC): 0.8240
# Epoch 1/1, Loss: 0.0817
# Epoch 13 - Task B performance during Task B (without EWC): 0.9760
# Epoch 13 - Task B performance during Task B - validation set (without EWC): 0.9723
# Epoch 13 - Task A performance during Task B (without EWC): 0.8407
# Epoch 13 - Task A performance during Task B - validation set (without EWC): 0.8300
# Epoch 1/1, Loss: 0.0775
# Epoch 14 - Task B performance during Task B (without EWC): 0.9773
# Epoch 14 - Task B performance during Task B - validation set (without EWC): 0.9730
# Epoch 14 - Task A performance during Task B (without EWC): 0.8447
# Epoch 14 - Task A performance during Task B - validation set (without EWC): 0.8307
# Epoch 1/1, Loss: 0.0736
# Epoch 15 - Task B performance during Task B (without EWC): 0.9767
# Epoch 15 - Task B performance during Task B - validation set (without EWC): 0.9733
# Epoch 15 - Task A performance during Task B (without EWC): 0.8480
# Epoch 15 - Task A performance during Task B - validation set (without EWC): 0.8330
# Epoch 1/1, Loss: 0.0711
# Epoch 16 - Task B performance during Task B (without EWC): 0.9773
# Epoch 16 - Task B performance during Task B - validation set (without EWC): 0.9717
# Epoch 16 - Task A performance during Task B (without EWC): 0.8480
# Epoch 16 - Task A performance during Task B - validation set (without EWC): 0.8343
# Epoch 1/1, Loss: 0.0684
# Epoch 17 - Task B performance during Task B (without EWC): 0.9760
# Epoch 17 - Task B performance during Task B - validation set (without EWC): 0.9723
# Epoch 17 - Task A performance during Task B (without EWC): 0.8500
# Epoch 17 - Task A performance during Task B - validation set (without EWC): 0.8387
# Epoch 1/1, Loss: 0.0665
# Epoch 18 - Task B performance during Task B (without EWC): 0.9793
# Epoch 18 - Task B performance during Task B - validation set (without EWC): 0.9733
# Epoch 18 - Task A performance during Task B (without EWC): 0.8507
# Epoch 18 - Task A performance during Task B - validation set (without EWC): 0.8370
# Epoch 1/1, Loss: 0.0636
# Epoch 19 - Task B performance during Task B (without EWC): 0.9793
# Epoch 19 - Task B performance during Task B - validation set (without EWC): 0.9737
# Epoch 19 - Task A performance during Task B (without EWC): 0.8513
# Epoch 19 - Task A performance during Task B - validation set (without EWC): 0.8387
# Epoch 1/1, Loss: 0.0627
# Epoch 20 - Task B performance during Task B (without EWC): 0.9760
# Epoch 20 - Task B performance during Task B - validation set (without EWC): 0.9750
# Epoch 20 - Task A performance during Task B (without EWC): 0.8480
# Epoch 20 - Task A performance during Task B - validation set (without EWC): 0.8333
# Epoch 1/1, Loss: 0.0604
# Epoch 21 - Task B performance during Task B (without EWC): 0.9813
# Epoch 21 - Task B performance during Task B - validation set (without EWC): 0.9753
# Epoch 21 - Task A performance during Task B (without EWC): 0.8507
# Epoch 21 - Task A performance during Task B - validation set (without EWC): 0.8377
# Epoch 1/1, Loss: 0.0568
# Epoch 22 - Task B performance during Task B (without EWC): 0.9807
# Epoch 22 - Task B performance during Task B - validation set (without EWC): 0.9760
# Epoch 22 - Task A performance during Task B (without EWC): 0.8527
# Epoch 22 - Task A performance during Task B - validation set (without EWC): 0.8377
# Epoch 1/1, Loss: 0.0578
# Epoch 23 - Task B performance during Task B (without EWC): 0.9813
# Epoch 23 - Task B performance during Task B - validation set (without EWC): 0.9757
# Epoch 23 - Task A performance during Task B (without EWC): 0.8547
# Epoch 23 - Task A performance during Task B - validation set (without EWC): 0.8427
# Epoch 1/1, Loss: 0.0552
# Epoch 24 - Task B performance during Task B (without EWC): 0.9760
# Epoch 24 - Task B performance during Task B - validation set (without EWC): 0.9763
# Epoch 24 - Task A performance during Task B (without EWC): 0.8540
# Epoch 24 - Task A performance during Task B - validation set (without EWC): 0.8380
# Epoch 1/1, Loss: 0.0535
# Epoch 25 - Task B performance during Task B (without EWC): 0.9813
# Epoch 25 - Task B performance during Task B - validation set (without EWC): 0.9750
# Epoch 25 - Task A performance during Task B (without EWC): 0.8567
# Epoch 25 - Task A performance during Task B - validation set (without EWC): 0.8420
# Epoch 1/1, Loss: 0.0509
# Epoch 26 - Task B performance during Task B (without EWC): 0.9807
# Epoch 26 - Task B performance during Task B - validation set (without EWC): 0.9763
# Epoch 26 - Task A performance during Task B (without EWC): 0.8573
# Epoch 26 - Task A performance during Task B - validation set (without EWC): 0.8423
# Epoch 1/1, Loss: 0.0493
# Epoch 27 - Task B performance during Task B (without EWC): 0.9820
# Epoch 27 - Task B performance during Task B - validation set (without EWC): 0.9753
# Epoch 27 - Task A performance during Task B (without EWC): 0.8587
# Epoch 27 - Task A performance during Task B - validation set (without EWC): 0.8443
# Epoch 1/1, Loss: 0.0510
# Epoch 28 - Task B performance during Task B (without EWC): 0.9813
# Epoch 28 - Task B performance during Task B - validation set (without EWC): 0.9737
# Epoch 28 - Task A performance during Task B (without EWC): 0.8647
# Epoch 28 - Task A performance during Task B - validation set (without EWC): 0.8490
# Epoch 1/1, Loss: 0.0465
# Epoch 29 - Task B performance during Task B (without EWC): 0.9827
# Epoch 29 - Task B performance during Task B - validation set (without EWC): 0.9760
# Epoch 29 - Task A performance during Task B (without EWC): 0.8593
# Epoch 29 - Task A performance during Task B - validation set (without EWC): 0.8430
# Epoch 1/1, Loss: 0.0465
# Epoch 30 - Task B performance during Task B (without EWC): 0.9833
# Epoch 30 - Task B performance during Task B - validation set (without EWC): 0.9757
# Epoch 30 - Task A performance during Task B (without EWC): 0.8600
# Epoch 30 - Task A performance during Task B - validation set (without EWC): 0.8473
# Epoch 1/1, Loss: 0.0445
# Epoch 31 - Task B performance during Task B (without EWC): 0.9807
# Epoch 31 - Task B performance during Task B - validation set (without EWC): 0.9770
# Epoch 31 - Task A performance during Task B (without EWC): 0.8593
# Epoch 31 - Task A performance during Task B - validation set (without EWC): 0.8447
# Epoch 1/1, Loss: 0.0437
# Epoch 32 - Task B performance during Task B (without EWC): 0.9840
# Epoch 32 - Task B performance during Task B - validation set (without EWC): 0.9763
# Epoch 32 - Task A performance during Task B (without EWC): 0.8580
# Epoch 32 - Task A performance during Task B - validation set (without EWC): 0.8443
# Epoch 1/1, Loss: 0.0426
# Epoch 33 - Task B performance during Task B (without EWC): 0.9827
# Epoch 33 - Task B performance during Task B - validation set (without EWC): 0.9777
# Epoch 33 - Task A performance during Task B (without EWC): 0.8593
# Epoch 33 - Task A performance during Task B - validation set (without EWC): 0.8447
# Epoch 1/1, Loss: 0.0406
# Epoch 34 - Task B performance during Task B (without EWC): 0.9840
# Epoch 34 - Task B performance during Task B - validation set (without EWC): 0.9770
# Epoch 34 - Task A performance during Task B (without EWC): 0.8593
# Epoch 34 - Task A performance during Task B - validation set (without EWC): 0.8463
# Epoch 1/1, Loss: 0.0396
# Epoch 35 - Task B performance during Task B (without EWC): 0.9827
# Epoch 35 - Task B performance during Task B - validation set (without EWC): 0.9767
# Epoch 35 - Task A performance during Task B (without EWC): 0.8613
# Epoch 35 - Task A performance during Task B - validation set (without EWC): 0.8460
# Epoch 1/1, Loss: 0.0395
# Epoch 36 - Task B performance during Task B (without EWC): 0.9807
# Epoch 36 - Task B performance during Task B - validation set (without EWC): 0.9773
# Epoch 36 - Task A performance during Task B (without EWC): 0.8593
# Epoch 36 - Task A performance during Task B - validation set (without EWC): 0.8473
# Epoch 1/1, Loss: 0.0387
# Epoch 37 - Task B performance during Task B (without EWC): 0.9807
# Epoch 37 - Task B performance during Task B - validation set (without EWC): 0.9770
# Epoch 37 - Task A performance during Task B (without EWC): 0.8587
# Epoch 37 - Task A performance during Task B - validation set (without EWC): 0.8450
# Epoch 1/1, Loss: 0.0383
# Epoch 38 - Task B performance during Task B (without EWC): 0.9807
# Epoch 38 - Task B performance during Task B - validation set (without EWC): 0.9777
# Epoch 38 - Task A performance during Task B (without EWC): 0.8580
# Epoch 38 - Task A performance during Task B - validation set (without EWC): 0.8440
# Epoch 1/1, Loss: 0.0366
# Epoch 39 - Task B performance during Task B (without EWC): 0.9847
# Epoch 39 - Task B performance during Task B - validation set (without EWC): 0.9770
# Epoch 39 - Task A performance during Task B (without EWC): 0.8620
# Epoch 39 - Task A performance during Task B - validation set (without EWC): 0.8487
# Epoch 1/1, Loss: 0.0353
# Epoch 40 - Task B performance during Task B (without EWC): 0.9833
# Epoch 40 - Task B performance during Task B - validation set (without EWC): 0.9757
# Epoch 40 - Task A performance during Task B (without EWC): 0.8640
# Epoch 40 - Task A performance during Task B - validation set (without EWC): 0.8503
# Epoch 1/1, Loss: 0.0351
# Epoch 41 - Task B performance during Task B (without EWC): 0.9833
# Epoch 41 - Task B performance during Task B - validation set (without EWC): 0.9797
# Epoch 41 - Task A performance during Task B (without EWC): 0.8627
# Epoch 41 - Task A performance during Task B - validation set (without EWC): 0.8470
# Epoch 1/1, Loss: 0.0340
# Epoch 42 - Task B performance during Task B (without EWC): 0.9847
# Epoch 42 - Task B performance during Task B - validation set (without EWC): 0.9780
# Epoch 42 - Task A performance during Task B (without EWC): 0.8653
# Epoch 42 - Task A performance during Task B - validation set (without EWC): 0.8487
# Epoch 1/1, Loss: 0.0335
# Epoch 43 - Task B performance during Task B (without EWC): 0.9853
# Epoch 43 - Task B performance during Task B - validation set (without EWC): 0.9790
# Epoch 43 - Task A performance during Task B (without EWC): 0.8660
# Epoch 43 - Task A performance during Task B - validation set (without EWC): 0.8500
# Epoch 1/1, Loss: 0.0326
# Epoch 44 - Task B performance during Task B (without EWC): 0.9833
# Epoch 44 - Task B performance during Task B - validation set (without EWC): 0.9810
# Epoch 44 - Task A performance during Task B (without EWC): 0.8647
# Epoch 44 - Task A performance during Task B - validation set (without EWC): 0.8487
# Epoch 1/1, Loss: 0.0314
# Epoch 45 - Task B performance during Task B (without EWC): 0.9820
# Epoch 45 - Task B performance during Task B - validation set (without EWC): 0.9780
# Epoch 45 - Task A performance during Task B (without EWC): 0.8620
# Epoch 45 - Task A performance during Task B - validation set (without EWC): 0.8480
# Epoch 1/1, Loss: 0.0310
# Epoch 46 - Task B performance during Task B (without EWC): 0.9840
# Epoch 46 - Task B performance during Task B - validation set (without EWC): 0.9803
# Epoch 46 - Task A performance during Task B (without EWC): 0.8640
# Epoch 46 - Task A performance during Task B - validation set (without EWC): 0.8490
# Epoch 1/1, Loss: 0.0311
# Epoch 47 - Task B performance during Task B (without EWC): 0.9860
# Epoch 47 - Task B performance during Task B - validation set (without EWC): 0.9807
# Epoch 47 - Task A performance during Task B (without EWC): 0.8667
# Epoch 47 - Task A performance during Task B - validation set (without EWC): 0.8503
# Epoch 1/1, Loss: 0.0292
# Epoch 48 - Task B performance during Task B (without EWC): 0.9860
# Epoch 48 - Task B performance during Task B - validation set (without EWC): 0.9793
# Epoch 48 - Task A performance during Task B (without EWC): 0.8653
# Epoch 48 - Task A performance during Task B - validation set (without EWC): 0.8490
# Epoch 1/1, Loss: 0.0292
# Epoch 49 - Task B performance during Task B (without EWC): 0.9840
# Epoch 49 - Task B performance during Task B - validation set (without EWC): 0.9757
# Epoch 49 - Task A performance during Task B (without EWC): 0.8693
# Epoch 49 - Task A performance during Task B - validation set (without EWC): 0.8517
# Epoch 1/1, Loss: 0.0287
# Epoch 50 - Task B performance during Task B (without EWC): 0.9827
# Epoch 50 - Task B performance during Task B - validation set (without EWC): 0.9807
# Epoch 50 - Task A performance during Task B (without EWC): 0.8660
# Epoch 50 - Task A performance during Task B - validation set (without EWC): 0.8487
# Task B without EWC: Accuracy: 0.9826666666666667, Precision: 0.9826975593104625, Recall: 0.9826666666666667, Cohen's Kappa: 0.9653333333333334
# Task A after Task B without EWC: Accuracy: 0.9807, Precision: 0.9807, Recall: 0.9807, Kappa: 0.9613
# Task A - Final without EWC: Accuracy: 0.866, Precision: 0.888008981578909, Recall: 0.866, Cohen's Kappa: 0.8511111111111112
# Task A after Task B without EWC: Accuracy: 0.8487, Precision: 0.8730, Recall: 0.8487, Cohen's Kappa: 0.8317

# %%
import json
# Initialize storage for results, including "Untrained_A"


# Store per-epoch values for plotting
epoch_stats_A = {
    "Initial": {"accuracy": [], "loss": []}
}

epoch_stats_B = {
    "Initial": {"accuracy": [], "loss": []}
}


for run in range(num_runs):
    print(f"Run {run + 1}/{num_runs}")
    model1_A = ConvNet(shared_dim=128, output_dim_A=10, output_dim_B=2)
    optimizer = optim.Adam(model1_A.parameters(), lr=learning_rate))
    criterion = nn.CrossEntropyLoss()


    # Store task_A_during_B as a list for this run
    task_A_run = []
    task_B_run = []


    for epoch in range(epochs):

        # Train and evaluate on Blue domain with EWC
        print("Training on Blue domain with EWC")
        ewc = EWC(model1_A, train_A_loader, importance=900000000)
        acc_A_ewc, loss_a_ewc = train_with_patience(model1_A, train_A_loader, optimizer, criterion, epochs=1,patience=50)

        # Track performance on Task B
        accuracy_taskA, _, _, _ = evaluate(model1_A, val_A_loader, criterion)
        print(f"Epoch {epoch + 1} - Task A (with EWC): {accuracy_taskA:.4f}")
        task_A_run.append(accuracy_taskA)

        # Track performance on Task B
        accuracy_taskB, _, _, _ = evaluate(model1_A, val_loader_B, criterion)
        print(f"Epoch {epoch + 1} - Task B (with EWC): {accuracy_taskB:.4f}")
        task_B_run.append(accuracy_taskB)
       
    epoch_stats_A["Initial"]["accuracy"].append(task_A_run)
    epoch_stats_B["Initial"]["accuracy"].append(task_B_run)
    
    with open('epoch_stats_B_til_bench_val.json', 'w') as f:
        json.dump(epoch_stats_B, f, indent=4)

# %%
accuracy_taskA_final_rehearsal
# Out:
# 0.9923
